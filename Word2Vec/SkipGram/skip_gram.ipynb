# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import string 
import re

from sklearn.manifold import TSNE
from nltk.corpus import stopwords
from collections import Counter
from collections import defaultdict
from datasets import load_dataset
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('stopwords')
RemoveWords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/atharvadashora/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Defining necessary functions

# %%
def softmax(x):
	e_x = np.exp(x - np.max(x))
	return e_x / e_x.sum()

# %%
def preprocess_sentences(corpus, min_word_freq=10, min_sentence_len=8):
    # Remove punctuation and numbers (Roman numerals and others)
    corpus = re.sub(r'\b[MDCLXVI]+\b|\d+', '', corpus)
    corpus = corpus.translate(str.maketrans('', '', string.punctuation))
    
    # Tokenize the corpus
    sentences = [sent.strip().split() for sent in corpus.lower().split('.')]
    
    # Filter out short sentences
    sentences = [sent for sent in sentences if len(sent) >= min_sentence_len]
    
    # Filter out rare words and short sentences
    word_freq = Counter([word for sent in sentences for word in sent])
    sentences = [[word for word in sent if word_freq[word] >= min_word_freq] for sent in sentences]
    
    return [sent for sent in sentences if len(sent) >= min_sentence_len]

# %%
class SkipGramModel(object):
    def __init__(self):
        self.Neuron = 20
        self.lr = 0.0005
        self.Context_Window = 2

        self.X_train = []
        self.y_train = []
        

        self.words = []
        self.word_index = {}
        self.vocab = {}
  
    def InitializeWeights(self,V,data):
        self.V = V
        self.W = np.random.uniform(-0.4, 0.4, (self.V, self.Neuron))
        self.W1 = np.random.uniform(-0.4, 0.4, (self.Neuron, self.V))
          
        self.words = data
        for i in range(len(data)):
            self.word_index[data[i]] = i
            
    def train(self,mytol,maxepochs=20000):
      	#initialize loss
        self.loss =0
        self.loss1 = 1 #random number 1
        itr=1
        
        while abs(self.loss1 - self.loss)>= mytol and itr <= maxepochs:
            self.loss1 = self.loss
            self.loss = 0
            for j in range(len(self.X_train)):

             		# implementing feedforward 
                self.h = np.dot(self.W.T,self.X_train[j]).reshape(self.Neuron,1)
                self.u = np.dot(self.W1.T,self.h)
                self.y = softmax(self.u)
                
                # implementation of back propogration
                error = self.y - np.asarray(self.y_train[j]).reshape(self.V,1)
                dLdW1 = np.dot(self.h,error.T)
                X = np.array(self.X_train[j]).reshape(self.V,1)
                dLdW = np.dot(X, np.dot(self.W1,error).T)

                self.W1 = self.W1 - self.lr*dLdW1
                self.W = self.W - self.lr*dLdW

                #loss Function
                C = 0
                for m in range(self.V):
                    if(self.y_train[j][m]):
                        self.loss += -1*self.u[m][0]
                        C += 1
                self.loss += C*np.log(np.sum(np.exp(self.u)))
            #Print loss
            # print("epoch ",itr, " loss = ",self.loss)
            #update adaptive alpha
            self.lr *= 1/( (1+self.lr*itr) )
            itr=itr+1
             
    def predict(self,word,number_of_predictions):
        if word in self.words:
            index = self.word_index[word]
            X = [0 for i in range(self.V)]
            X[index] = 1


            #prediction = self.feed_forward(X)
            self.h = np.dot(self.W.T,X).reshape(self.Neuron,1)
            self.u = np.dot(self.W1.T,self.h)
            self.y = softmax(self.u)
            prediction=self.y


            output = {}
            for i in range(self.V):
                output[prediction[i][0]] = i
              
            top_context_words = []
            for k in sorted(output,reverse=True):
                top_context_words.append(self.words[output[k]])
                if(len(top_context_words)>=number_of_predictions):
                    break
      
            return top_context_words
        else:
            print("Word not found")
    
    def get_embedding_matrix(self):
        """
        Returns the word embedding matrix where each row corresponds
        to the embedding of a word in the vocabulary.
        """
        return self.W 
    
    def get_word_embedding(self, word):
        """
        Returns the embedding of the given word.
        """
        if word in self.word_index:
            word_idx = self.word_index[word]
            return self.W[word_idx]  # The embedding for the word
        else:
            print(f"Word '{word}' not in vocabulary.")
            return None

# %%
class SkipGramModelNeg(object):
    def __init__(self, negative_samples=5):
        self.Neuron = 20
        self.lr = 0.005
        self.negative_samples = negative_samples
        self.words = []
        self.word_index = {}
        self.V = 0
        self.W = None
        self.W1 = None

    def InitializeWeights(self, V, data):
        self.V = V
        self.W = np.random.uniform(-0.4, 0.4, (self.V, self.Neuron))
        self.W1 = np.random.uniform(-0.4, 0.4, (self.Neuron, self.V))
        self.words = data
        for i, word in enumerate(data):
            self.word_index[word] = i

    def train(self, mytol, maxepochs=20000):
        itr = 1

        while itr <= maxepochs:
            total_loss = 0
            
            for j in range(len(self.X_train)):
                # Feedforward
                h = np.dot(self.W.T, self.X_train[j]).reshape(self.Neuron, 1)
                u = np.dot(self.W1.T, h)
                y_pred = softmax(u)

                # Prepare positive samples
                positive_indices = np.where(self.y_train[j] == 1)[0]

                # Negative sampling
                negative_samples = np.random.choice(
                    [i for i in range(self.V) if i not in positive_indices],
                    self.negative_samples,
                    replace=False
                )

                # Create labels: 1 for positive, 0 for negative
                labels = np.zeros(self.V)
                labels[positive_indices] = 1
                labels[negative_samples] = 0
                
                # Calculate error
                error = y_pred - labels.reshape(self.V, 1)

                # Gradients
                dLdW1 = np.dot(h, error.T)
                X = np.array(self.X_train[j]).reshape(self.V, 1)
                dLdW = np.dot(X, np.dot(self.W1, error).T)

                # Update weights
                self.W1 -= self.lr * dLdW1
                self.W -= self.lr * dLdW

                # Loss calculation
                positive_loss = -np.sum(labels[positive_indices] * np.log(y_pred[positive_indices] + 1e-10))
                negative_loss = -np.sum((1 - labels[negative_samples]) * np.log(1 - y_pred[negative_samples] + 1e-10))
                total_loss += positive_loss + negative_loss

            # Print loss for monitoring
            print("Epoch ", itr, " Loss = ", total_loss)
            
            # Update learning rate
            self.lr *= 1 / (1 + self.lr * itr)
            itr += 1

    def predict(self, word, number_of_predictions):
        if word in self.word_index:
            index = self.word_index[word]
            X = np.zeros(self.V)
            X[index] = 1

            h = np.dot(self.W.T, X).reshape(self.Neuron, 1)
            u = np.dot(self.W1.T, h)
            y_pred = softmax(u)

            output = {y_pred[i][0]: i for i in range(self.V)}
            top_context_words = sorted(output, reverse=True)[:number_of_predictions]
            return [self.words[i] for i in top_context_words]
        else:
            print("Word not found")
            return []

    def get_embedding_matrix(self):
        return self.W 

    def get_word_embedding(self, word):
        if word in self.word_index:
            return self.W[self.word_index[word]]
        else:
            print(f"Word '{word}' not in vocabulary.")
            return None

# %% [markdown]
# ### Importing Corpus

# %%
dataset = load_dataset("wikitext", "wikitext-2-raw-v1")
train_data = dataset['train']
val_data = dataset['validation']
test_data = dataset['test']

# %%
train_data[0]["text"]
# Out:
# ''

# %%
corpus = ""
for i in range(5000):
  corpus = corpus +"."+ train_data[i]["text"]

# %%
# corpus

# %%
corpus_Set = preprocess_sentences(corpus)
print(" number of sentences :", len(corpus_Set))
# Out:
#  number of sentences : 1

# %%
# print(corpus_Set)

# %%
# # only if we want to export corpus
# df = pd.DataFrame (corpus_Set)
# filepath = 'CorpusSet.xlsx'
# df.to_excel(filepath, index=False)

# %% [markdown]
# ### Creating Skipgram Model and vocabulary Set

# %%
def prepare_data_in_batches(sentences, window_size, vocab, batch_size):
    """
    Generator to prepare context-target word pairs in batches.
    
    Args:
    - sentences: List of tokenized sentences.
    - window_size: Size of the context window.
    - vocab: Dictionary mapping words to indices (vocabulary).
    - batch_size: Number of word-context pairs to return in each batch.
    
    Yields:
    - X_batch: A batch of one-hot encoded target words.
    - y_batch: A batch of one-hot encoded context words.
    """
    X_batch = []
    y_batch = []
    current_batch_size = 0

    for sentence in sentences:
        for i, target_word in enumerate(sentence):
            if target_word not in vocab:
                continue

            target_word_idx = vocab[target_word]
            X = np.zeros(len(vocab))
            X[target_word_idx] = 1  # One-hot encode the target word

            # Get the context words within the window size
            for j in range(max(0, i - window_size), min(len(sentence), i + window_size + 1)):
                if j != i and sentence[j] in vocab:
                    context_word_idx = vocab[sentence[j]]
                    y = np.zeros(len(vocab))
                    y[context_word_idx] = 1  # One-hot encode the context word

                    X_batch.append(X)
                    y_batch.append(y)
                    current_batch_size += 1

                    # If the current batch size matches the batch_size, yield the batch
                    if current_batch_size == batch_size:
                        yield np.array(X_batch), np.array(y_batch)
                        X_batch = []
                        y_batch = []
                        current_batch_size = 0

    # Yield the final batch if there are any remaining pairs
    if current_batch_size > 0:
        yield np.array(X_batch), np.array(y_batch)

# %%
sentences = corpus_Set

vocab = {word: idx for idx, word in enumerate(set([word for sentence in sentences for word in sentence]))}


window_size = 2
batch_size = 1000
V = len(vocab)

model = SkipGramModel()
model.InitializeWeights(V, list(vocab.keys()))
model.vocab = vocab

# Training loop
num_epochs = 2
for epoch in range(num_epochs):
    print(f"Starting epoch {epoch + 1}/{num_epochs}")
    
    # Generate word-context pairs in batches
    batch_generator = prepare_data_in_batches(sentences, window_size, vocab, batch_size)
    
    for X_batch, y_batch in batch_generator:
        model.X_train = X_batch
        model.y_train = y_batch
        
        # Perform one epoch of training on this batch
        model.train(mytol=1e-4, maxepochs=1)  # Use a small maxepochs value for batch-wise training

    print(f"Finished epoch {epoch + 1}/{num_epochs}")
# Out:
# Starting epoch 1/2
# epoch  1  loss =  7401.1307212793445
# epoch  1  loss =  7364.913050972889
# epoch  1  loss =  7398.456515716947
# epoch  1  loss =  7387.475791387325
# epoch  1  loss =  7361.165936140445
# epoch  1  loss =  7328.266333513018
# epoch  1  loss =  7338.102456367388
# epoch  1  loss =  7374.019476685849
# epoch  1  loss =  7358.576660827658
# epoch  1  loss =  7321.917123203887
# epoch  1  loss =  7356.989601327109
# epoch  1  loss =  7341.96478401344
# epoch  1  loss =  5741.430830348139
# epoch  1  loss =  5843.470300692058
# epoch  1  loss =  5738.057589898873
# epoch  1  loss =  5708.642263824473
# epoch  1  loss =  5833.592282842601
# epoch  1  loss =  5575.77328268936
# epoch  1  loss =  5653.627161968489
# epoch  1  loss =  494.8829186906813
# Finished epoch 2/2

# %%
model1 = SkipGramModelNeg()
model1.InitializeWeights(V, list(vocab.keys()))
model1.vocab = vocab

# Training loop
num_epochs = 2
for epoch in range(num_epochs):
    print(f"Starting epoch {epoch + 1}/{num_epochs}")
    
    # Generate word-context pairs in batches
    batch_generator = prepare_data_in_batches(sentences, window_size, vocab, batch_size)
    
    for X_batch, y_batch in batch_generator:
        model1.X_train = X_batch
        model1.y_train = y_batch
        
        # Perform one epoch of training on this batch
        model1.train(mytol=1e-4, maxepochs=1)  # Use a small maxepochs value for batch-wise training

    print(f"Finished epoch {epoch + 1}/{num_epochs}")
# Out:
# Starting epoch 1/2
# Epoch  1  Loss =  7340.045339706044
# Epoch  1  Loss =  7338.467535972701
# Epoch  1  Loss =  7341.8162127854375
# Epoch  1  Loss =  7337.174174056212
# Epoch  1  Loss =  7327.5667402232475
# Epoch  1  Loss =  7315.549767713357
# Epoch  1  Loss =  7311.615802086002
# Epoch  1  Loss =  7290.481786931636
# Epoch  1  Loss =  7293.573414735636
# Epoch  1  Loss =  7266.008004766331
# Epoch  1  Loss =  7280.726625393017
# Epoch  1  Loss =  7244.365868369978
# Epoch  1  Loss =  7159.939410169584
# Epoch  1  Loss =  7171.164580064096
# Epoch  1  Loss =  7183.961699431784
# Epoch  1  Loss =  7156.5086639119845
# Epoch  1  Loss =  7112.0335904558515
# Epoch  1  Loss =  7104.28547694585
# Epoch  1  Loss =  7029.744269290945
# Epoch  1  Loss =  7036.721240573735
# Epoch  1  Loss =  7085.363359817794
# Epoch  1  Loss =  6973.136697668808
# Epoch  1  Loss =  6983.6949183711895
# Epoch  1  Loss =  6946.501485711252
# Epoch  1  Loss =  6788.179942369295
# Epoch  1  Loss =  6803.631440084326
# Epoch  1  Loss =  7029.500730019544
# Epoch  1  Loss =  6925.600898806354
# Epoch  1  Loss =  6748.080738794984
# Epoch  1  Loss =  6712.471200598347
# Epoch  1  Loss =  7083.247908461099
# Epoch  1  Loss =  7032.4816778265285
# Epoch  1  Loss =  7040.275667899735
# Epoch  1  Loss =  7053.713678506081
# Epoch  1  Loss =  6999.423143632323
# Epoch  1  Loss =  6831.884387264057
# Epoch  1  Loss =  6659.343887640336
# Epoch  1  Loss =  6884.296443607978
# Epoch  1  Loss =  6864.34955107577
# Epoch  1  Loss =  6966.992044980189
# Epoch  1  Loss =  6670.549809256013
# Epoch  1  Loss =  6383.54025039063
# Epoch  1  Loss =  6420.1180352914125
# Epoch  1  Loss =  6443.898524481616
# Epoch  1  Loss =  6514.714702664962
# Epoch  1  Loss =  6807.52099100843
# Epoch  1  Loss =  6821.495096024404
# Epoch  1  Loss =  6806.171891450378
# Epoch  1  Loss =  6861.133523091279
# Epoch  1  Loss =  6506.228186823399
# Epoch  1  Loss =  5780.007136623514
# Epoch  1  Loss =  5734.867405351705
# Epoch  1  Loss =  5809.030779957445
# Epoch  1  Loss =  5586.076358477803
# Epoch  1  Loss =  5706.64424067234
# Epoch  1  Loss =  5623.221082871042
# Epoch  1  Loss =  5733.754045679283
# Epoch  1  Loss =  5903.612276945329
# Epoch  1  Loss =  5713.455234188367
# Epoch  1  Loss =  5587.127561513347
# Epoch  1  Loss =  5714.855187788423
# Epoch  1  Loss =  5576.543956657223
# Epoch  1  Loss =  5607.936067215538
# Epoch  1  Loss =  5588.22145220046
# Epoch  1  Loss =  5487.110650932534
# Epoch  1  Loss =  5669.761130187496
# Epoch  1  Loss =  5370.444124913602
# Epoch  1  Loss =  5458.451609178801
# Epoch  1  Loss =  476.5225360420432
# Finished epoch 2/2

# %%
def compute_similarity(embedding_matrix, target_vector):
    """
    Compute cosine similarity between the target vector and all word embeddings.
    """
    similarities = cosine_similarity(embedding_matrix, target_vector.reshape(1, -1)).flatten()
    return similarities

# %%
def get_rank(similarity_scores, true_index):
    """
    Get the rank of the true context word in the similarity list.
    """
    sorted_indices = np.argsort(-similarity_scores)  # Sort in descending order of similarity
    rank = np.where(sorted_indices == true_index)[0][0] + 1  # Get the rank of the true word
    return rank

# %%
def calculate_mrr_for_window(context_indices, target_embedding, embedding_matrix):
    """
    Calculate MRR for a single context window.
    """
    mrr = 0.0
    for context_idx in context_indices:
        similarity_scores = compute_similarity(embedding_matrix, target_embedding)
        rank = get_rank(similarity_scores, context_idx)
        mrr += 1 / rank
    mrr /= len(context_indices)  # Average over the context window
    return mrr

# %%
def calculate_mrr_for_dataset(test_data, embedding_matrix, word_index):
    """
    Calculate the overall MRR for the entire test dataset.
    """
    total_mrr = 0.0
    for t in test_data:
        print(t)
        target_word, context_words = t[0], t[1]
        if target_word not in word_index:
            continue  # Skip words that are not in the vocabulary
        
        target_idx = word_index[target_word]
        target_embedding = embedding_matrix[target_idx]
        
        # Get indices for all context words
        context_indices = [word_index[word] for word in context_words if word in word_index]
        
        if len(context_indices) > 0:
            mrr_window = calculate_mrr_for_window(context_indices, target_embedding, embedding_matrix)
            total_mrr += mrr_window
    
    avg_mrr = total_mrr / len(test_data)
    return avg_mrr

# %%
embedding_matrix = model1.get_embedding_matrix()
word_index = model1.word_index  # word to index mapping from the model

# avg_mrr = calculate_mrr_for_dataset(test_data, embedding_matrix, word_index)
# print(f"Mean Reciprocal Rank for test data: {avg_mrr:.4f}")

# %%
embedding_matrix
# Out:
# array([[-0.38516527,  0.0528593 , -0.37050841, ...,  0.4995249 ,
#          0.15141531, -0.32639165],
#        [-0.55062148, -0.06637911,  0.08037473, ...,  0.43831404,
#          0.05264678, -0.0468442 ],
#        [-0.40973828, -0.49045347, -0.37353193, ...,  0.30763087,
#          0.01583437, -0.27024024],
#        ...,
#        [-0.61942955, -0.12203895,  0.19670987, ...,  0.20281747,
#          0.11403295, -0.31951604],
#        [-0.19133636,  0.1899759 , -0.40461873, ...,  0.22110652,
#         -0.12172515, -0.13537633],
#        [ 0.0375472 , -0.1259747 , -0.10260936, ...,  0.44124003,
#         -0.0807507 ,  0.09002751]])

# %%
word_index
# Out:
# {'went': 0,
#  'used': 1,
#  'series': 2,
#  'offer': 3,
#  'debut': 4,
#  'appointed': 5,
#  'track': 6,
#  'above': 7,
#  'coin': 8,
#  'organization': 9,
#  'regional': 10,
#  'was': 11,
#  'support': 12,
#  'buildings': 13,
#  'few': 14,
#  'normal': 15,
#  'festival': 16,
#  'tale': 17,
#  'thomas': 18,
#  'bruins': 19,
#  'show': 20,
#  'blue': 21,
#  'because': 22,
#  'minister': 23,
#  'agreed': 24,
#  'got': 25,
#  'pope': 26,
#  'london': 27,
#  'young': 28,
#  'deities': 29,
#  'have': 30,
#  'whose': 31,
#  'house': 32,
#  'start': 33,
#  'something': 34,
#  'park': 35,
#  'cast': 36,
#  'law': 37,
#  'remaining': 38,
#  'germany': 39,
#  'popular': 40,
#  'far': 41,
#  'george': 42,
#  'sexual': 43,
#  'effort': 44,
#  'occupation': 45,
#  'deal': 46,
#  'gabbar': 47,
#  'ruler': 48,
#  'peace': 49,
#  'praised': 50,
#  'college': 51,
#  'light': 52,
#  'genus': 53,
#  'near': 54,
#  'mid': 55,
#  'date': 56,
#  'e': 57,
#  'instead': 58,
#  'h': 59,
#  'uk': 60,
#  'average': 61,
#  'jai': 62,
#  'opportunities': 63,
#  'over': 64,
#  'typically': 65,
#  'chemotherapy': 66,
#  'competition': 67,
#  'won': 68,
#  'october': 69,
#  'forms': 70,
#  'producer': 71,
#  'houston': 72,
#  'wide': 73,
#  'might': 74,
#  'missing': 75,
#  'natural': 76,
#  'heavy': 77,
#  'such': 78,
#  'below': 79,
#  'kingdom': 80,
#  'behind': 81,
#  'primarily': 82,
#  'forces': 83,
#  'ending': 84,
#  'top': 85,
#  'girl': 86,
#  'main': 87,
#  'directly': 88,
#  'covered': 89,
#  'nbc': 90,
#  'foot': 91,
#  'on': 92,
#  'get': 93,
#  'townsend': 94,
#  'must': 95,
#  'hill': 96,
#  'star': 97,
#  'free': 98,
#  'latter': 99,
#  'find': 100,
#  'n': 101,
#  'entrance': 102,
#  'attempted': 103,
#  'assassination': 104,
#  'stage': 105,
#  'shooting': 106,
#  'taking': 107,
#  'using': 108,
#  'breeding': 109,
#  'second': 110,
#  'after': 111,
#  'expected': 112,
#  'video': 113,
#  'village': 114,
#  'actions': 115,
#  'except': 116,
#  'program': 117,
#  'not': 118,
#  'title': 119,
#  'goals': 120,
#  'remained': 121,
#  'coup': 122,
#  'variety': 123,
#  'th': 124,
#  'norman': 125,
#  'association': 126,
#  'always': 127,
#  'worship': 128,
#  'career': 129,
#  'conditions': 130,
#  'former': 131,
#  'aircraft': 132,
#  'description': 133,
#  'league': 134,
#  'markgraf': 135,
#  'lad': 136,
#  'civil': 137,
#  'various': 138,
#  'engaged': 139,
#  'area': 140,
#  'came': 141,
#  'squadron': 142,
#  'years': 143,
#  'britain': 144,
#  'system': 145,
#  'shows': 146,
#  'service': 147,
#  'mass': 148,
#  'november': 149,
#  'religion': 150,
#  'deity': 151,
#  'bodies': 152,
#  'coach': 153,
#  'fernandez': 154,
#  'whom': 155,
#  'coast': 156,
#  'older': 157,
#  'neolithic': 158,
#  'worked': 159,
#  'alone': 160,
#  'revolution': 161,
#  'marilyn': 162,
#  'modern': 163,
#  'square': 164,
#  'mvp': 165,
#  'mi': 166,
#  'society': 167,
#  'provide': 168,
#  'each': 169,
#  'radio': 170,
#  'inspired': 171,
#  'historical': 172,
#  'chemical': 173,
#  'any': 174,
#  'wrapped': 175,
#  'ice': 176,
#  'best': 177,
#  'may': 178,
#  'floor': 179,
#  'constructed': 180,
#  'characters': 181,
#  'who': 182,
#  'minutes': 183,
#  'player': 184,
#  'included': 185,
#  'greater': 186,
#  'while': 187,
#  'july': 188,
#  'awards': 189,
#  'patrick': 190,
#  'meant': 191,
#  'northern': 192,
#  'audience': 193,
#  'with': 194,
#  'library': 195,
#  'stones': 196,
#  'studies': 197,
#  'twins': 198,
#  'ships': 199,
#  'aml': 200,
#  'many': 201,
#  'fits': 202,
#  'run': 203,
#  'consisted': 204,
#  'made': 205,
#  'my': 206,
#  'her': 207,
#  'columbus': 208,
#  'move': 209,
#  'individuals': 210,
#  'goddess': 211,
#  'better': 212,
#  'group': 213,
#  'risk': 214,
#  'sometimes': 215,
#  'take': 216,
#  'round': 217,
#  'live': 218,
#  'llosa': 219,
#  'sb': 220,
#  'oxford': 221,
#  'born': 222,
#  'break': 223,
#  'archaeologist': 224,
#  'across': 225,
#  'artist': 226,
#  'treaty': 227,
#  'specific': 228,
#  'training': 229,
#  'yet': 230,
#  'stated': 231,
#  'started': 232,
#  'usually': 233,
#  'died': 234,
#  'their': 235,
#  'rock': 236,
#  'historian': 237,
#  'at': 238,
#  'goat': 239,
#  'took': 240,
#  'woman': 241,
#  'culture': 242,
#  'individual': 243,
#  'short': 244,
#  'history': 245,
#  'long': 246,
#  'carolina': 247,
#  'earth': 248,
#  'are': 249,
#  'assigned': 250,
#  'via': 251,
#  'itself': 252,
#  'scored': 253,
#  'nature': 254,
#  'us': 255,
#  'today': 256,
#  'marriage': 257,
#  'palestine': 258,
#  'gold': 259,
#  'last': 260,
#  'makes': 261,
#  'never': 262,
#  'court': 263,
#  'office': 264,
#  'smaller': 265,
#  'leaving': 266,
#  'returned': 267,
#  'health': 268,
#  'race': 269,
#  'sun': 270,
#  'situation': 271,
#  'able': 272,
#  'friend': 273,
#  'atlanta': 274,
#  'ship': 275,
#  'education': 276,
#  'scoring': 277,
#  'six': 278,
#  'ultimately': 279,
#  'course': 280,
#  'hold': 281,
#  'total': 282,
#  'held': 283,
#  'minute': 284,
#  'carried': 285,
#  'excavation': 286,
#  'by': 287,
#  'regular': 288,
#  'remain': 289,
#  'appearances': 290,
#  'put': 291,
#  'language': 292,
#  'before': 293,
#  'rights': 294,
#  'if': 295,
#  'official': 296,
#  'than': 297,
#  'cup': 298,
#  'aviation': 299,
#  'process': 300,
#  'announced': 301,
#  'major': 302,
#  'largely': 303,
#  'replaced': 304,
#  'formed': 305,
#  'wrote': 306,
#  'conflict': 307,
#  'written': 308,
#  'cave': 309,
#  'member': 310,
#  'about': 311,
#  'permanent': 312,
#  'way': 313,
#  'erzherzog': 314,
#  'troops': 315,
#  'highway': 316,
#  'san': 317,
#  'invited': 318,
#  'given': 319,
#  'cullen': 320,
#  'ended': 321,
#  'low': 322,
#  'eye': 323,
#  'leukemia': 324,
#  'project': 325,
#  'building': 326,
#  'calling': 327,
#  'two': 328,
#  'work': 329,
#  'mm': 330,
#  'mark': 331,
#  'nhl': 332,
#  'goal': 333,
#  'veeru': 334,
#  'decision': 335,
#  'gulf': 336,
#  'victory': 337,
#  'wall': 338,
#  'gods': 339,
#  'struck': 340,
#  'ten': 341,
#  'felt': 342,
#  'captured': 343,
#  'caa': 344,
#  'stating': 345,
#  'lead': 346,
#  'directed': 347,
#  'case': 348,
#  'families': 349,
#  'similar': 350,
#  'visited': 351,
#  'admiral': 352,
#  'away': 353,
#  'north': 354,
#  'flower': 355,
#  'money': 356,
#  'expressed': 357,
#  'place': 358,
#  'professional': 359,
#  'promoted': 360,
#  'upper': 361,
#  'aot': 362,
#  'michael': 363,
#  'director': 364,
#  'council': 365,
#  'care': 366,
#  'reign': 367,
#  'character': 368,
#  'but': 369,
#  'stansfield': 370,
#  'every': 371,
#  'thought': 372,
#  'cancer': 373,
#  'off': 374,
#  'academic': 375,
#  'silver': 376,
#  'did': 377,
#  'newly': 378,
#  'supporting': 379,
#  'zrínyi': 380,
#  'germans': 381,
#  'york': 382,
#  'under': 383,
#  'royal': 384,
#  'airports': 385,
#  'governor': 386,
#  'crew': 387,
#  'dedicated': 388,
#  'critics': 389,
#  'side': 390,
#  'newspaper': 391,
#  'focus': 392,
#  'officer': 393,
#  'finkelstein': 394,
#  'different': 395,
#  'own': 396,
#  'three': 397,
#  'mixed': 398,
#  'paul': 399,
#  'tons': 400,
#  'interview': 401,
#  'twenty': 402,
#  'blackie': 403,
#  'la': 404,
#  'baseball': 405,
#  'baby': 406,
#  'countries': 407,
#  'should': 408,
#  'death': 409,
#  'pilot': 410,
#  'billboard': 411,
#  'past': 412,
#  'transferred': 413,
#  'secretary': 414,
#  'up': 415,
#  'version': 416,
#  'leader': 417,
#  'books': 418,
#  'both': 419,
#  'those': 420,
#  'age': 421,
#  'write': 422,
#  'monuments': 423,
#  'wife': 424,
#  'idea': 425,
#  'performances': 426,
#  'man': 427,
#  'four': 428,
#  'become': 429,
#  'value': 430,
#  'cover': 431,
#  'hands': 432,
#  'largest': 433,
#  'chamber': 434,
#  'soon': 435,
#  'lower': 436,
#  'his': 437,
#  '’': 438,
#  'commander': 439,
#  'management': 440,
#  'movement': 441,
#  'prominent': 442,
#  'beyond': 443,
#  'european': 444,
#  'site': 445,
#  'thakur': 446,
#  'thick': 447,
#  'non': 448,
#  'april': 449,
#  'academy': 450,
#  'position': 451,
#  'power': 452,
#  'influences': 453,
#  'peters': 454,
#  'france': 455,
#  'done': 456,
#  'texts': 457,
#  'operation': 458,
#  'american': 459,
#  'singh': 460,
#  'f': 461,
#  'estimated': 462,
#  'season': 463,
#  'introduced': 464,
#  'sculptures': 465,
#  'teaching': 466,
#  'policy': 467,
#  'god': 468,
#  'images': 469,
#  'battle': 470,
#  'depicting': 471,
#  'writer': 472,
#  'overall': 473,
#  'khan': 474,
#  'ground': 475,
#  'lack': 476,
#  'weeks': 477,
#  'due': 478,
#  'some': 479,
#  'often': 480,
#  'parents': 481,
#  'published': 482,
#  'love': 483,
#  'regarded': 484,
#  'significant': 485,
#  'through': 486,
#  'male': 487,
#  'sound': 488,
#  'times': 489,
#  'left': 490,
#  'performance': 491,
#  'help': 492,
#  'immediately': 493,
#  'spring': 494,
#  'figure': 495,
#  'larger': 496,
#  'primary': 497,
#  'full': 498,
#  'anti': 499,
#  'during': 500,
#  'play': 501,
#  'possible': 502,
#  're': 503,
#  'cruiser': 504,
#  'father': 505,
#  'original': 506,
#  'republic': 507,
#  'freeway': 508,
#  'certain': 509,
#  'no': 510,
#  'm': 511,
#  'vocals': 512,
#  'air': 513,
#  'face': 514,
#  'represented': 515,
#  'throughout': 516,
#  'trade': 517,
#  'texas': 518,
#  'back': 519,
#  'ali': 520,
#  'parvati': 521,
#  'wing': 522,
#  'day': 523,
#  'turned': 524,
#  'shiva': 525,
#  'into': 526,
#  'military': 527,
#  'writers': 528,
#  'planned': 529,
#  'others': 530,
#  'fragilis': 531,
#  'responsible': 532,
#  'direct': 533,
#  'third': 534,
#  'though': 535,
#  'destroyed': 536,
#  'commented': 537,
#  'limited': 538,
#  'located': 539,
#  'songs': 540,
#  'torpedo': 541,
#  'lyrics': 542,
#  'role': 543,
#  'toniná': 544,
#  'available': 545,
#  'works': 546,
#  'board': 547,
#  'flying': 548,
#  'appearance': 549,
#  'magazine': 550,
#  'attempt': 551,
#  'underground': 552,
#  'world': 553,
#  'days': 554,
#  'quickly': 555,
#  'morning': 556,
#  't': 557,
#  'among': 558,
#  'number': 559,
#  'spores': 560,
#  'include': 561,
#  'exeter': 562,
#  'access': 563,
#  'greek': 564,
#  'they': 565,
#  'road': 566,
#  'plain': 567,
#  'even': 568,
#  'owned': 569,
#  'considered': 570,
#  'john': 571,
#  'chief': 572,
#  'white': 573,
#  'caves': 574,
#  'plans': 575,
#  'piece': 576,
#  'occurred': 577,
#  'zagreb': 578,
#  'beginning': 579,
#  'franchise': 580,
#  'music': 581,
#  'change': 582,
#  'name': 583,
#  'players': 584,
#  'august': 585,
#  'between': 586,
#  'paper': 587,
#  'president': 588,
#  'period': 589,
#  'album': 590,
#  'sister': 591,
#  'indian': 592,
#  'present': 593,
#  'representative': 594,
#  'ancient': 595,
#  'bulls': 596,
#  'released': 597,
#  'will': 598,
#  'within': 599,
#  'allowing': 600,
#  'synagogue': 601,
#  'whole': 602,
#  'hired': 603,
#  'production': 604,
#  'brown': 605,
#  'told': 606,
#  'loan': 607,
#  'words': 608,
#  'medical': 609,
#  'current': 610,
#  'known': 611,
#  'r': 612,
#  'signed': 613,
#  'same': 614,
#  'company': 615,
#  'fact': 616,
#  'dominican': 617,
#  'million': 618,
#  'temple': 619,
#  'william': 620,
#  'complex': 621,
#  'it': 622,
#  'called': 623,
#  'chronicles': 624,
#  'armed': 625,
#  'christian': 626,
#  'issued': 627,
#  'relationship': 628,
#  'types': 629,
#  'right': 630,
#  'dance': 631,
#  'completed': 632,
#  'retired': 633,
#  'valkyria': 634,
#  'lost': 635,
#  'reported': 636,
#  'upon': 637,
#  'novel': 638,
#  'b': 639,
#  'minor': 640,
#  'life': 641,
#  'fairies': 642,
#  'use': 643,
#  'tot': 644,
#  'fruit': 645,
#  'amun': 646,
#  'concluded': 647,
#  'europe': 648,
#  'archaeologists': 649,
#  'british': 650,
#  'these': 651,
#  'originally': 652,
#  'response': 653,
#  'team': 654,
#  'female': 655,
#  'summer': 656,
#  'evidence': 657,
#  'port': 658,
#  'later': 659,
#  'iron': 660,
#  'reaction': 661,
#  'records': 662,
#  'least': 663,
#  'rays': 664,
#  'moral': 665,
#  'you': 666,
#  'aspects': 667,
#  'school': 668,
#  'raaf': 669,
#  'late': 670,
#  'tower': 671,
#  'commercial': 672,
#  'hard': 673,
#  'led': 674,
#  'featuring': 675,
#  'finished': 676,
#  'offered': 677,
#  'accepted': 678,
#  'recorded': 679,
#  'had': 680,
#  'followed': 681,
#  'acts': 682,
#  'black': 683,
#  'geoff': 684,
#  'commandment': 685,
#  'proposed': 686,
#  'final': 687,
#  'armor': 688,
#  'clarkson': 689,
#  'shown': 690,
#  'shell': 691,
#  'scholars': 692,
#  'that': 693,
#  'probably': 694,
#  'members': 695,
#  'soldiers': 696,
#  'region': 697,
#  'america': 698,
#  'out': 699,
#  'o': 700,
#  'to': 701,
#  'points': 702,
#  'family': 703,
#  'next': 704,
#  'chart': 705,
#  'him': 706,
#  'mostly': 707,
#  'background': 708,
#  'quality': 709,
#  'catholic': 710,
#  'ft': 711,
#  'its': 712,
#  'report': 713,
#  'acute': 714,
#  'addition': 715,
#  'sold': 716,
#  'district': 717,
#  'africa': 718,
#  'students': 719,
#  'changed': 720,
#  'another': 721,
#  'authorities': 722,
#  'elements': 723,
#  'game': 724,
#  'earlier': 725,
#  'fox': 726,
#  'gave': 727,
#  'workers': 728,
#  'higher': 729,
#  'crake': 730,
#  'states': 731,
#  'can': 732,
#  'further': 733,
#  'charles': 734,
#  'common': 735,
#  'win': 736,
#  'new': 737,
#  'nathan': 738,
#  'propaganda': 739,
#  'hot': 740,
#  'just': 741,
#  'projects': 742,
#  'going': 743,
#  'been': 744,
#  'girls': 745,
#  'creation': 746,
#  'killed': 747,
#  'fungus': 748,
#  'broken': 749,
#  'ever': 750,
#  'involved': 751,
#  'return': 752,
#  'population': 753,
#  'night': 754,
#  'roles': 755,
#  'hours': 756,
#  'england': 757,
#  'could': 758,
#  'taken': 759,
#  'king': 760,
#  'very': 761,
#  'type': 762,
#  'hygrometricus': 763,
#  'real': 764,
#  'branch': 765,
#  'grew': 766,
#  'ontario': 767,
#  'characteristics': 768,
#  'timbaland': 769,
#  '–': 770,
#  'national': 771,
#  'action': 772,
#  'well': 773,
#  'galveston': 774,
#  'for': 775,
#  'range': 776,
#  'winning': 777,
#  'nine': 778,
#  'speed': 779,
#  'together': 780,
#  'cat': 781,
#  'self': 782,
#  'body': 783,
#  'down': 784,
#  'committee': 785,
#  'especially': 786,
#  'however': 787,
#  'lives': 788,
#  'attack': 789,
#  'era': 790,
#  'complete': 791,
#  'approximately': 792,
#  'fifth': 793,
#  'officially': 794,
#  'mainly': 795,
#  'commandments': 796,
#  'playoff': 797,
#  'united': 798,
#  'conference': 799,
#  'moved': 800,
#  'review': 801,
#  'pilots': 802,
#  'development': 803,
#  'material': 804,
#  'now': 805,
#  'majority': 806,
#  'secondary': 807,
#  'manager': 808,
#  'holocaust': 809,
#  'theme': 810,
#  'allosaurus': 811,
#  'museum': 812,
#  'feet': 813,
#  'highest': 814,
#  'war': 815,
#  'saprang': 816,
#  'bone': 817,
#  'traditional': 818,
#  'brought': 819,
#  'cause': 820,
#  'smith': 821,
#  'respect': 822,
#  'produced': 823,
#  'noted': 824,
#  'vargas': 825,
#  'african': 826,
#  'double': 827,
#  'egyptian': 828,
#  'hockey': 829,
#  'how': 830,
#  'active': 831,
#  'son': 832,
#  'less': 833,
#  'government': 834,
#  'takes': 835,
#  'increase': 836,
#  'listed': 837,
#  'parts': 838,
#  'year': 839,
#  'large': 840,
#  'trujillo': 841,
#  'control': 842,
#  'eventually': 843,
#  'built': 844,
#  'airport': 845,
#  'has': 846,
#  'advanced': 847,
#  'barker': 848,
#  'scenes': 849,
#  'them': 850,
#  'mint': 851,
#  'blood': 852,
#  'contract': 853,
#  'notes': 854,
#  'established': 855,
#  'johnson': 856,
#  'de': 857,
#  'allowed': 858,
#  'again': 859,
#  'east': 860,
#  'and': 861,
#  'then': 862,
#  'street': 863,
#  'also': 864,
#  'being': 865,
#  'removed': 866,
#  'previously': 867,
#  'annual': 868,
#  'events': 869,
#  'naval': 870,
#  'special': 871,
#  'finals': 872,
#  'classic': 873,
#  'capital': 874,
#  'social': 875,
#  'championship': 876,
#  'subsequently': 877,
#  'success': 878,
#  'general': 879,
#  'tour': 880,
#  'conducted': 881,
#  'performed': 882,
#  'intended': 883,
#  'fall': 884,
#  'marked': 885,
#  'more': 886,
#  'english': 887,
#  'particularly': 888,
#  'award': 889,
#  'storm': 890,
#  'flight': 891,
#  'enough': 892,
#  'all': 893,
#  'police': 894,
#  'me': 895,
#  'time': 896,
#  'generally': 897,
#  'antimony': 898,
#  'giving': 899,
#  'referred': 900,
#  'max': 901,
#  'positive': 902,
#  'rest': 903,
#  'surrounding': 904,
#  'penalty': 905,
#  'additional': 906,
#  'features': 907,
#  'st': 908,
#  'fourth': 909,
#  'purpose': 910,
#  'point': 911,
#  'india': 912,
#  'terms': 913,
#  'numerous': 914,
#  'campaign': 915,
#  'influenced': 916,
#  'navy': 917,
#  'construction': 918,
#  'austro': 919,
#  'oil': 920,
#  'attended': 921,
#  'barrow': 922,
#  'country': 923,
#  'party': 924,
#  'this': 925,
#  'gun': 926,
#  'david': 927,
#  'once': 928,
#  'december': 929,
#  'co': 930,
#  'think': 931,
#  'daily': 932,
#  'discovery': 933,
#  'effect': 934,
#  'schools': 935,
#  'close': 936,
#  'creator': 937,
#  'serves': 938,
#  'damaged': 939,
#  'found': 940,
#  'fleet': 941,
#  'tied': 942,
#  'reviews': 943,
#  'nba': 944,
#  'so': 945,
#  'suggested': 946,
#  'temples': 947,
#  'section': 948,
#  'jewish': 949,
#  'holiday': 950,
#  'based': 951,
#  'metal': 952,
#  'anderson': 953,
#  'playoffs': 954,
#  'political': 955,
#  'p': 956,
#  'arsenal': 957,
#  'line': 958,
#  'want': 959,
#  'research': 960,
#  'wheeler': 961,
#  'leading': 962,
#  'approach': 963,
#  'formation': 964,
#  'archaeology': 965,
#  'following': 966,
#  'frank': 967,
#  'wolf': 968,
#  'artists': 969,
#  'failed': 970,
#  'size': 971,
#  'wanted': 972,
#  'related': 973,
#  'transport': 974,
#  'sea': 975,
#  'fully': 976,
#  'things': 977,
#  'fey': 978,
#  'opening': 979,
#  'institute': 980,
#  'ordered': 981,
#  'corn': 982,
#  'outside': 983,
#  'carved': 984,
#  'eaton': 985,
#  'longer': 986,
#  'strapping': 987,
#  'club': 988,
#  'numbers': 989,
#  'turn': 990,
#  'come': 991,
#  'give': 992,
#  'monument': 993,
#  'person': 994,
#  'he': 995,
#  'news': 996,
#  'polish': 997,
#  'having': 998,
#  '°': 999,
#  ...}

# %%
#This function create One hot encoding for Input word and the context words
def prepare_test_data(sentences, window_size, vocab):
    """
    Prepare test data from sentences for MRR calculation.

    Args:
    - sentences: List of sentences (each sentence is a string).
    - window_size: The context window size (c).
    - vocab: Set of valid words (usually, your model's vocabulary).

    Returns:
    - test_data: A list of (target_word, [context_words]) tuples.
    """
    test_data = []
    print(vocab)
    for sentence in sentences:
        
        # Iterate over each word in the sentence
        for i in range(window_size, len(sentence)-window_size):
            target_word = sentence[i]
            if target_word not in vocab:
                continue  # Skip words not in the vocabulary
            
            # Get the context words within the window size
            context_words = []
            for j in range(max(0, i - window_size), min(len(sentence), i + window_size + 1)):
                if j != i and sentence[j] in vocab:  # Exclude the target word itself
                    context_words.append(sentence[j])
            
            if len(context_words) > 0:
                print(target_word, context_words)
                test_data.append([target_word, context_words])
    
    return test_data

# %%
corpus_Set[:10]
# Out:
# [['valkyria',
#   'chronicles',
#   'no',
#   'valkyria',
#   'chronicles',
#   'valkyria',
#   'of',
#   'the',
#   'referred',
#   'to',
#   'as',
#   'valkyria',
#   'chronicles',
#   'outside',
#   'is',
#   'a',
#   'role',
#   'playing',
#   'video',
#   'game',
#   'developed',
#   'by',
#   'and',
#   'for',
#   'the',
#   'released',
#   'in',
#   'january',
#   'in',
#   'it',
#   'is',
#   'the',
#   'third',
#   'game',
#   'in',
#   'the',
#   'valkyria',
#   'series',
#   'the',
#   'same',
#   'of',
#   'and',
#   'real',
#   'time',
#   'as',
#   'its',
#   'the',
#   'story',
#   'to',
#   'the',
#   'first',
#   'game',
#   'and',
#   'the',
#   'a',
#   'military',
#   'unit',
#   'serving',
#   'the',
#   'nation',
#   'of',
#   'during',
#   'the',
#   'second',
#   'war',
#   'who',
#   'black',
#   'operations',
#   'and',
#   'are',
#   'against',
#   'the',
#   'unit',
#   'the',
#   'game',
#   'began',
#   'development',
#   'in',
#   'over',
#   'a',
#   'large',
#   'of',
#   'the',
#   'work',
#   'done',
#   'on',
#   'valkyria',
#   'chronicles',
#   'while',
#   'it',
#   'the',
#   'standard',
#   'features',
#   'of',
#   'the',
#   'series',
#   'it',
#   'also',
#   'such',
#   'as',
#   'making',
#   'the',
#   'game',
#   'more',
#   'for',
#   'series',
#   'character',
#   'and',
#   'both',
#   'returned',
#   'from',
#   'previous',
#   'along',
#   'with',
#   'valkyria',
#   'chronicles',
#   'director',
#   'a',
#   'large',
#   'team',
#   'of',
#   'writers',
#   'the',
#   'the',
#   'game',
#   's',
#   'opening',
#   'theme',
#   'was',
#   'by',
#   'may',
#   'n',
#   'it',
#   'met',
#   'with',
#   'positive',
#   'in',
#   'and',
#   'was',
#   'praised',
#   'by',
#   'both',
#   'and',
#   'western',
#   'critics',
#   'after',
#   'release',
#   'it',
#   'received',
#   'along',
#   'with',
#   'an',
#   'in',
#   'november',
#   'of',
#   'that',
#   'year',
#   'it',
#   'was',
#   'also',
#   'into',
#   'and',
#   'an',
#   'original',
#   'video',
#   'series',
#   'due',
#   'to',
#   'low',
#   'of',
#   'valkyria',
#   'chronicles',
#   'valkyria',
#   'chronicles',
#   'was',
#   'not',
#   'but',
#   'a',
#   'with',
#   'the',
#   'game',
#   's',
#   'was',
#   'released',
#   'in',
#   'would',
#   'return',
#   'to',
#   'the',
#   'franchise',
#   'with',
#   'the',
#   'development',
#   'of',
#   'valkyria',
#   'revolution',
#   'for',
#   'the',
#   'as',
#   'with',
#   'previous',
#   'chronicles',
#   'games',
#   'valkyria',
#   'chronicles',
#   'is',
#   'a',
#   'role',
#   'playing',
#   'game',
#   'where',
#   'players',
#   'take',
#   'control',
#   'of',
#   'a',
#   'military',
#   'unit',
#   'and',
#   'take',
#   'part',
#   'in',
#   'against',
#   'forces',
#   'are',
#   'told',
#   'through',
#   'book',
#   'like',
#   'with',
#   'character',
#   'with',
#   'characters',
#   'through',
#   'and',
#   'through',
#   'the',
#   'player',
#   'through',
#   'a',
#   'series',
#   'of',
#   'as',
#   'that',
#   'can',
#   'be',
#   'through',
#   'and',
#   'as',
#   'they',
#   'are',
#   'the',
#   'route',
#   'to',
#   'each',
#   'story',
#   'location',
#   'on',
#   'the',
#   'on',
#   'an',
#   'individual',
#   'player',
#   's',
#   'approach',
#   'when',
#   'one',
#   'is',
#   'selected',
#   'the',
#   'other',
#   'is',
#   'off',
#   'to',
#   'the',
#   'player',
#   'outside',
#   'the',
#   'player',
#   'characters',
#   'rest',
#   'in',
#   'a',
#   'where',
#   'units',
#   'can',
#   'be',
#   'and',
#   'character',
#   'growth',
#   'alongside',
#   'the',
#   'main',
#   'story',
#   'are',
#   'character',
#   'specific',
#   'to',
#   'different',
#   'members',
#   'after',
#   'the',
#   'game',
#   's',
#   'additional',
#   'are',
#   'some',
#   'of',
#   'them',
#   'having',
#   'a',
#   'higher',
#   'than',
#   'those',
#   'found',
#   'in',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'game',
#   'there',
#   'are',
#   'also',
#   'love',
#   'elements',
#   'related',
#   'to',
#   'the',
#   'game',
#   's',
#   'two',
#   'main',
#   'although',
#   'they',
#   'take',
#   'a',
#   'very',
#   'minor',
#   'role',
#   'the',
#   'game',
#   's',
#   'battle',
#   'system',
#   'the',
#   'system',
#   'is',
#   'carried',
#   'over',
#   'directly',
#   'from',
#   'chronicles',
#   'during',
#   'players',
#   'each',
#   'unit',
#   'using',
#   'a',
#   'top',
#   'down',
#   'of',
#   'the',
#   'once',
#   'a',
#   'character',
#   'is',
#   'selected',
#   'the',
#   'player',
#   'the',
#   'character',
#   'around',
#   'the',
#   'in',
#   'third',
#   'person',
#   'a',
#   'character',
#   'can',
#   'only',
#   'act',
#   'once',
#   'per',
#   'turn',
#   'but',
#   'characters',
#   'can',
#   'be',
#   'at',
#   'the',
#   'of',
#   'other',
#   'characters',
#   'each',
#   'character',
#   'has',
#   'a',
#   'field',
#   'and',
#   'of',
#   'movement',
#   'limited',
#   'by',
#   'their',
#   'action',
#   'up',
#   'to',
#   'nine',
#   'characters',
#   'can',
#   'be',
#   'assigned',
#   'to',
#   'a',
#   'single',
#   'during',
#   'characters',
#   'will',
#   'call',
#   'out',
#   'if',
#   'something',
#   'to',
#   'them',
#   'such',
#   'as',
#   'their',
#   'health',
#   'points',
#   'low',
#   'or',
#   'being',
#   'out',
#   'by',
#   'each',
#   'character',
#   'has',
#   'specific',
#   'to',
#   'each',
#   'character',
#   'they',
#   'are',
#   'divided',
#   'into',
#   'personal',
#   'which',
#   'are',
#   'that',
#   'remain',
#   'by',
#   'the',
#   'story',
#   'and',
#   'can',
#   'either',
#   'help',
#   'or',
#   'a',
#   'character',
#   'and',
#   'battle',
#   'which',
#   'are',
#   'throughout',
#   'the',
#   'game',
#   'and',
#   'always',
#   'to',
#   'a',
#   'character',
#   'to',
#   'battle',
#   'each',
#   'character',
#   'has',
#   'a',
#   'a',
#   'based',
#   'that',
#   'can',
#   'be',
#   'used',
#   'to',
#   'and',
#   'different',
#   'characters',
#   'also',
#   'have',
#   'special',
#   'that',
#   'them',
#   'on',
#   'the',
#   'can',
#   'direct',
#   'command',
#   'and',
#   'move',
#   'around',
#   'the',
#   'without',
#   'his',
#   'action',
#   'point',
#   'the',
#   'character',
#   'can',
#   'into',
#   'her',
#   'valkyria',
#   'form',
#   'and',
#   'become',
#   'while',
#   'can',
#   'units',
#   'with',
#   'her',
#   'heavy',
#   'troops',
#   'are',
#   'divided',
#   'into',
#   'five',
#   'and',
#   'can',
#   'by',
#   'their',
#   'assigned',
#   'class',
#   'does',
#   'not',
#   'the',
#   'while',
#   'in',
#   'a',
#   'previous',
#   'class',
#   'with',
#   'victory',
#   'in',
#   'battle',
#   'points',
#   'are',
#   'awarded',
#   'to',
#   'the',
#   'which',
#   'are',
#   'into',
#   'five',
#   'different',
#   'by',
#   'the',
#   'entire',
#   'a',
#   'feature',
#   'from',
#   'early',
#   'games',
#   'of',
#   'to',
#   'different',
#   'unit',
#   'types',
#   'the',
#   'game',
#   'takes',
#   'place',
#   'during',
#   'the',
#   'second',
#   'war',
#   'army',
#   'also',
#   'known',
#   'as',
#   'the',
#   'are',
#   'a',
#   'military',
#   'unit',
#   'of',
#   'and',
#   'military',
#   'whose',
#   'real',
#   'names',
#   'are',
#   'from',
#   'the',
#   'records',
#   'and',
#   'officially',
#   'referred',
#   'to',
#   'by',
#   'numbers',
#   'ordered',
#   'by',
#   'the',
#   'military',
#   'to',
#   'the',
#   'most',
#   'that',
#   'the',
#   'regular',
#   'army',
#   'and',
#   'will',
#   'not',
#   'do',
#   'they',
#   'are',
#   'up',
#   'to',
#   'the',
#   'by',
#   'their',
#   'always',
#   'the',
#   'three',
#   'main',
#   'characters',
#   'are',
#   'no',
#   'an',
#   'army',
#   'officer',
#   'of',
#   'who',
#   'to',
#   'himself',
#   'no',
#   'a',
#   'female',
#   'heavy',
#   'who',
#   'against',
#   'the',
#   'valkyria',
#   'who',
#   'destroyed',
#   'her',
#   'home',
#   'and',
#   'no',
#   'a',
#   'young',
#   'woman',
#   'who',
#   'is',
#   'a',
#   'of',
#   'the',
#   'valkyria',
#   'together',
#   'with',
#   'their',
#   'fellow',
#   'members',
#   'these',
#   'three',
#   'are',
#   'to',
#   'against',
#   'a',
#   'unit',
#   'known',
#   'as',
#   'of',
#   'mostly',
#   'soldiers',
#   'as',
#   'the',
#   'officially',
#   'do',
#   'not',
#   'the',
#   'upper',
#   'of',
#   'the',
#   'army',
#   'the',
#   'of',
#   'in',
#   'order',
#   'to',
#   'them',
#   'on',
#   'that',
#   'would',
#   'make',
#   'face',
#   'in',
#   'the',
#   'war',
#   'while',
#   'at',
#   'times',
#   'this',
#   'works',
#   'to',
#   'their',
#   'such',
#   'as',
#   'a',
#   'successful',
#   'into',
#   'territory',
#   'other',
#   'cause',
#   'certain',
#   'members',
#   'of',
#   'the',
#   'great',
#   'one',
#   'such',
#   'member',
#   'so',
#   'that',
#   'he',
#   'his',
#   'post',
#   'and',
#   'into',
#   'the',
#   'of',
#   'to',
#   'the',
#   'of',
#   'proposed',
#   'by',
#   'their',
#   'leader',
#   'at',
#   'the',
#   'same',
#   'time',
#   'elements',
#   'within',
#   'army',
#   'command',
#   'move',
#   'to',
#   'the',
#   'in',
#   'order',
#   'to',
#   'their',
#   'own',
#   'by',
#   'both',
#   'and',
#   'and',
#   'combined',
#   'with',
#   'the',
#   'of',
#   'a',
#   'within',
#   'their',
#   'the',
#   'move',
#   'to',
#   'themselves',
#   'while',
#   'at',
#   'the',
#   'same',
#   'time',
#   'to',
#   'help',
#   'the',
#   'war',
#   'effort',
#   'this',
#   'until',
#   'the',
#   's',
#   'officer',
#   'who',
#   'had',
#   'been',
#   'under',
#   'house',
#   'is',
#   'to',
#   'the',
#   'capital',
#   'city',
#   'of',
#   'in',
#   'order',
#   'to',
#   'present',
#   'evidence',
#   'the',
#   'soldiers',
#   'and',
#   'the',
#   'real',
#   'the',
#   'general',
#   'that',
#   'had',
#   'of',
#   'due',
#   'to',
#   'these',
#   'events',
#   'and',
#   'due',
#   'to',
#   'the',
#   'major',
#   'losses',
#   'in',
#   'towards',
#   'the',
#   'end',
#   'of',
#   'the',
#   'war',
#   'with',
#   'the',
#   'the',
#   'are',
#   'offered',
#   'a',
#   'position',
#   'as',
#   'a',
#   'in',
#   'the',
#   'army',
#   'rather',
#   'than',
#   'as',
#   'an',
#   'force',
#   'this',
#   'is',
#   'short',
#   'however',
#   'as',
#   'following',
#   's',
#   'and',
#   'move',
#   'to',
#   'an',
#   'ancient',
#   'within',
#   'the',
#   'by',
#   'their',
#   'without',
#   'the',
#   'support',
#   'of',
#   'or',
#   'the',
#   'to',
#   'themselves',
#   'in',
#   'the',
#   'war',
#   'with',
#   'it',
#   'is',
#   's',
#   'last',
#   'in',
#   'a',
#   'new',
#   'nation',
#   'as',
#   'an',
#   'armed',
#   'force',
#   'the',
#   'just',
#   'following',
#   'the',
#   'two',
#   'fire',
#   'would',
#   'their',
#   'peace',
#   'to',
#   'once',
#   'again',
#   'make',
#   'his',
#   'the',
#   'to',
#   'list',
#   'himself',
#   'and',
#   'all',
#   'under',
#   'his',
#   'command',
#   'as',
#   'killed',
#   'in',
#   'action',
#   'now',
#   'to',
#   'other',
#   'than',
#   'themselves',
#   'the',
#   'and',
#   'the',
#   'each',
#   'member',
#   'then',
#   'their',
#   'in',
#   'order',
#   'to',
#   'their',
#   'lives',
#   'development',
#   'work',
#   'for',
#   'valkyria',
#   'chronicles',
#   'began',
#   'after',
#   'development',
#   'finished',
#   'on',
#   'valkyria',
#   'chronicles',
#   'in',
#   'early',
#   'with',
#   'full',
#   'development',
#   'beginning',
#   'shortly',
#   'after',
#   'this',
#   'the',
#   'director',
#   'of',
#   'valkyria',
#   'chronicles',
#   'returned',
#   'to',
#   'that',
#   'role',
#   'for',
#   'valkyria',
#   'chronicles',
#   'development',
#   'work',
#   'took',
#   'approximately',
#   'one',
#   'year',
#   'after',
#   'the',
#   'release',
#   'of',
#   'valkyria',
#   'chronicles',
#   'the',
#   'staff',
#   'took',
#   'a',
#   'at',
#   'both',
#   'the',
#   'popular',
#   'response',
#   'for',
#   'the',
#   'game',
#   'and',
#   'what',
#   'they',
#   'wanted',
#   'to',
#   'do',
#   'next',
#   'for',
#   'the',
#   'series',
#   'like',
#   'its',
#   'valkyria',
#   ...]]

# %%
c_t = test_data["text"][:100]

# %%
c_t
# Out:
# ['',
#  ' = Robert Boulter = \n',
#  '',
#  ' Robert Boulter is an English film , television and theatre actor . He had a guest @-@ starring role on the television series The Bill in 2000 . This was followed by a starring role in the play Herons written by Simon Stephens , which was performed in 2001 at the Royal Court Theatre . He had a guest role in the television series Judge John Deed in 2002 . In 2004 Boulter landed a role as " Craig " in the episode " Teddy \'s Story " of the television series The Long Firm ; he starred alongside actors Mark Strong and Derek Jacobi . He was cast in the 2005 theatre productions of the Philip Ridley play Mercury Fur , which was performed at the Drum Theatre in Plymouth and the Menier Chocolate Factory in London . He was directed by John Tiffany and starred alongside Ben Whishaw , Shane Zaza , Harry Kent , Fraser Ayres , Sophie Stanton and Dominic Hall . \n',
#  ' Boulter starred in two films in 2008 , Daylight Robbery by filmmaker Paris Leonti , and Donkey Punch directed by Olly Blackburn . Boulter portrayed a character named " Sean " in Donkey Punch , who tags along with character " Josh " as the " quiet brother ... who hits it off with Tammi " . Boulter guest starred on a two @-@ part episode arc " Wounds " in May 2008 of the television series Waking the Dead as character " Jimmy Dearden " . He appeared on the television series Survivors as " Neil " in November 2008 . He had a recurring role in ten episodes of the television series Casualty in 2010 , as " Kieron Fletcher " . He portrayed an emergency physician applying for a medical fellowship . He commented on the inherent difficulties in portraying a physician on television : " Playing a doctor is a strange experience . Pretending you know what you \'re talking about when you don \'t is very bizarre but there are advisers on set who are fantastic at taking you through procedures and giving you the confidence to stand there and look like you know what you \'re doing . " Boulter starred in the 2011 film Mercenaries directed by Paris Leonti . \n',
#  '',
#  ' = = Filmography = = \n',
#  '',
#  '',
#  ' = = = Film = = = \n',
#  '',
#  '',
#  ' = = = Television = = = \n',
#  '',
#  '',
#  ' = = = Theatre = = = \n',
#  '',
#  '',
#  '',
#  ' = Du Fu = \n',
#  '',
#  ' Du Fu ( Wade – Giles : Tu Fu ; Chinese : 杜甫 ; 712 – 770 ) was a prominent Chinese poet of the Tang dynasty . Along with Li Bai ( Li Po ) , he is frequently called the greatest of the Chinese poets . His greatest ambition was to serve his country as a successful civil servant , but he proved unable to make the necessary accommodations . His life , like the whole country , was devastated by the An Lushan Rebellion of 755 , and his last 15 years were a time of almost constant unrest . \n',
#  ' Although initially he was little @-@ known to other writers , his works came to be hugely influential in both Chinese and Japanese literary culture . Of his poetic writing , nearly fifteen hundred poems have been preserved over the ages . He has been called the " Poet @-@ Historian " and the " Poet @-@ Sage " by Chinese critics , while the range of his work has allowed him to be introduced to Western readers as " the Chinese Virgil , Horace , Ovid , Shakespeare , Milton , Burns , Wordsworth , Béranger , Hugo or Baudelaire " . \n',
#  '',
#  ' = = Life = = \n',
#  '',
#  ' Traditional Chinese literary criticism emphasized the life of the author when interpreting a work , a practice which Burton Watson attributes to " the close links that traditional Chinese thought posits between art and morality " . Since many of Du Fu \'s poems feature morality and history , this practice is particularly important . Another reason , identified by the Chinese historian William Hung , is that Chinese poems are typically concise , omitting context that might be relevant , but which an informed contemporary could be assumed to know . For modern Western readers , " The less accurately we know the time , the place and the circumstances in the background , the more liable we are to imagine it incorrectly , and the result will be that we either misunderstand the poem or fail to understand it altogether " . Stephen Owen suggests a third factor particular to Du Fu , arguing that the variety of the poet \'s work required consideration of his whole life , rather than the " reductive " categorizations used for more limited poets . \n',
#  '',
#  ' = = = Early years = = = \n',
#  '',
#  " Most of what is known of Du Fu 's life comes from his poems . His paternal grandfather was Du Shenyan , a noted politician and poet during the reign of Empress Wu . Du Fu was born in 712 ; the exact birthplace is unknown , except that it was near Luoyang , Henan province ( Gong county is a favourite candidate ) . In later life , he considered himself to belong to the capital city of Chang 'an , ancestral hometown of the Du family . \n",
#  " Du Fu 's mother died shortly after he was born , and he was partially raised by his aunt . He had an elder brother , who died young . He also had three half brothers and one half sister , to whom he frequently refers in his poems , although he never mentions his stepmother . \n",
#  ' Du Fu \'s political comments are based on emotion rather than calculation : his prescriptions have been paraphrased as , " Let us all be less selfish , let us all do what we are supposed to do " . Since his views were impossible to disagree with , his forcefully expressed truisms enabled his installation as the central figure of Chinese poetic history . \n',
#  '',
#  ' = = = Moral engagement = = = \n',
#  '',
#  ' A second favourite epithet of Chinese critics is that of " poet sage " ( 詩聖 shī shèng ) , a counterpart to the philosophical sage , Confucius . One of the earliest surviving works , The Song of the Wagons ( from around 750 ) , gives voice to the sufferings of a conscript soldier in the imperial army and a clear @-@ sighted consciousness of suffering . These concerns are continuously articulated in poems on the lives of both soldiers and civilians produced by Du Fu throughout his life . \n',
#  ' Although Du Fu \'s frequent references to his own difficulties can give the impression of an all @-@ consuming solipsism , Hawkes argues that his " famous compassion in fact includes himself , viewed quite objectively and almost as an afterthought " . He therefore " lends grandeur " to the wider picture by comparing it to " his own slightly comical triviality " . \n',
#  ' Du Fu \'s compassion , for himself and for others , was part of his general broadening of the scope of poetry : he devoted many works to topics which had previously been considered unsuitable for poetic treatment . Zhang Jie wrote that for Du Fu , " everything in this world is poetry " , Du wrote extensively on subjects such as domestic life , calligraphy , paintings , animals , and other poems . \n',
#  '',
#  ' = = = Technical excellence = = = \n',
#  '',
#  ' Du Fu \'s work is notable above all for its range . Chinese critics traditionally used the term 集大成 ( jídàchéng- " complete symphony " ) , a reference to Mencius \' description of Confucius . Yuan Zhen was the first to note the breadth of Du Fu \'s achievement , writing in 813 that his predecessor , " united in his work traits which previous men had displayed only singly " . He mastered all the forms of Chinese poetry : Chou says that in every form he " either made outstanding advances or contributed outstanding examples " . Furthermore , his poems use a wide range of registers , from the direct and colloquial to the allusive and self @-@ consciously literary . This variety is manifested even within individual works : Owen identifies the , " rapid stylistic and thematic shifts " in poems which enable the poet to represent different facets of a situation , while Chou uses the term " juxtaposition " as the major analytical tool in her work . Du Fu is noted for having written more on poetics and painting than any other writer of his time . He wrote eighteen poems on painting alone , more than any other Tang poet . Du Fu \'s seemingly negative commentary on the prized horse paintings of Han Gan ignited a controversy that has persisted to the present day . \n',
#  ' The tenor of his work changed as he developed his style and adapted to his surroundings ( " chameleon @-@ like " according to Watson ) : his earliest works are in a relatively derivative , courtly style , but he came into his own in the years of the rebellion . Owen comments on the " grim simplicity " of the Qinzhou poems , which mirrors the desert landscape ; the works from his Chengdu period are " light , often finely observed " ; while the poems from the late Kuizhou period have a " density and power of vision " . \n',
#  ' Although he wrote in all poetic forms , Du Fu is best known for his lǜshi , a type of poem with strict constraints on form and content , for example : \n',
#  ' About two thirds of Du Fu \'s 1500 extant works are in this form , and he is generally considered to be its leading exponent . His best lǜshi use the parallelisms required by the form to add expressive content rather than as mere technical restrictions . Hawkes comments that , " it is amazing that Tu Fu is able to use so immensely stylized a form in so natural a manner " . \n',
#  '',
#  ' = = Influence = = \n',
#  '',
#  ' According to the Encyclopædia Britannica , Du Fu \'s writings are considered by many literary critics to be among the greatest of all time , and it states " his dense , compressed language makes use of all the connotative overtones of a phrase and of all the intonational potentials of the individual word , qualities that no translation can ever reveal . " \n',
2010 , as " Kieron Fletcher " . Boulter starred in the 2011 film Mercenaries directed by Paris Leonti . \n.. = = Career = = \n... = = = 2000 – 2005 = = = \n.. In 2000 Boulter had a guest @-@ starring role on the television series The Bill ; he portrayed " Scott Parry " in the episode , " In Safe Hands " . Boulter starred as " Scott " in the play Herons written by Simon Stephens , which was performed in 2001 at the Royal Court Theatre . A review of Boulter \'s performance in The Independent on Sunday described him as " horribly menacing " in the role , and he received critical reviews in The Herald , and Evening Standard . He appeared in the television series Judge John Deed in 2002 as " Addem Armitage " in the episode " Political Expediency " , and had a role as a different character " Toby Steele " on The Bill . \n. He had a recurring role in 2003 on two episodes of The Bill , as character " Connor Price " . In 2004 Boulter landed a role as " Craig " in the episode " Teddy \'s Story " of the television series The Long Firm ; he starred alongside actors Mark Strong and Derek Jacobi . Boulter starred as " Darren " , in the 2005 theatre productions of the Philip Ridley play Mercury Fur . It was performed at the Drum Theatre in Plymouth , and the Menier Chocolate Factory in London . He was directed by John Tiffany and starred alongside Ben Whishaw , Shane Zaza , Harry Kent , Fraser Ayres , Sophie Stanton and Dominic Hall . Boulter received a favorable review in The Daily Telegraph : " The acting is shatteringly intense , with wired performances from Ben Whishaw ( now unrecognisable from his performance as Trevor Nunn \'s Hamlet ) , Robert Boulter , Shane Zaza and Fraser Ayres . " The Guardian noted , " Ben Whishaw and Robert Boulter offer tenderness amid the savagery . " \n.. = = = 2006 – present = = = \n.. In 2006 Boulter starred in the play Citizenship written by Mark Ravenhill . The play was part of a series which featured different playwrights , titled Burn / Chatroom / Citizenship . In a 2006 interview , fellow actor Ben Whishaw identified Boulter as one of his favorite co @-@ stars : " I loved working with a guy called Robert Boulter , who was in the triple bill of Burn , Chatroom and Citizenship at the National . He played my brother in Mercury Fur . " He portrayed " Jason Tyler " on the 2006 episode of the te ...

# %%
c_t_t = preprocess_sentences(c_t_t)

# %%
c_t_t
# Out:
# [['boulter',
#   'boulter',
#   'is',
#   'an',
#   'television',
#   'and',
#   'theatre',
#   'he',
#   'had',
#   'a',
#   'role',
#   'on',
#   'the',
#   'television',
#   'series',
#   'the',
#   'in',
#   'this',
#   'was',
#   'by',
#   'a',
#   'role',
#   'in',
#   'the',
#   'by',
#   'which',
#   'was',
#   'in',
#   'at',
#   'the',
#   'theatre',
#   'he',
#   'had',
#   'a',
#   'role',
#   'in',
#   'the',
#   'television',
#   'series',
#   'in',
#   'in',
#   'boulter',
#   'a',
#   'role',
#   'as',
#   'in',
#   'the',
#   's',
#   'of',
#   'the',
#   'television',
#   'series',
#   'the',
#   'he',
#   'starred',
#   'and',
#   'he',
#   'was',
#   'in',
#   'the',
#   'theatre',
#   'of',
#   'the',
#   'which',
#   'was',
#   'at',
#   'the',
#   'theatre',
#   'in',
#   'and',
#   'the',
#   'in',
#   'he',
#   'was',
#   'by',
#   'and',
#   'starred',
#   'and',
#   'in',
#   'boulter',
#   'starred',
#   'in',
#   'the',
#   'by',
#   'he',
#   'on',
#   'a',
#   'of',
#   'the',
#   'television',
#   'series',
#   'by',
#   'a',
#   'role',
#   'in',
#   'the',
#   'theatre',
#   'of',
#   'to',
#   'by',
#   'to',
#   'was',
#   'at',
#   'theatre',
#   'in',
#   'the',
#   'of',
#   'and',
#   'boulter',
#   'starred',
#   'in',
#   'two',
#   'in',
#   'by',
#   'and',
#   'by',
#   'in',
#   'boulter',
#   'a',
#   'on',
#   'a',
#   'two',
#   'of',
#   'the',
#   'television',
#   'series',
#   'the',
#   'by',
#   'an',
#   'on',
#   'the',
#   'television',
#   'series',
#   'in',
#   'he',
#   'had',
#   'a',
#   'role',
#   'in',
#   'of',
#   'the',
#   'television',
#   'series',
#   'in',
#   'as',
#   'boulter',
#   'starred',
#   'in',
#   'the',
#   'by',
#   'in',
#   'boulter',
#   'had',
#   'a',
#   'role',
#   'on',
#   'the',
#   'television',
#   'series',
#   'the',
#   'he',
#   'in',
#   'the',
#   'in',
#   'boulter',
#   'starred',
#   'as',
#   'in',
#   'the',
#   'by',
#   'which',
#   'was',
#   'in',
#   'at',
#   'the',
#   'theatre',
#   'a',
#   'of',
#   'boulter',
#   's',
#   'in',
#   'the',
#   'on',
#   'as',
#   'in',
#   'the',
#   'role',
#   'and',
#   'he',
#   'in',
#   'the',
#   'and',
#   'he',
#   'in',
#   'the',
#   'television',
#   'series',
#   'in',
#   'as',
#   'in',
#   'the',
#   'and',
#   'had',
#   'a',
#   'role',
#   'as',
#   'a',
#   'on',
#   'the',
#   'he',
#   'had',
#   'a',
#   'role',
#   'in',
#   'on',
#   'two',
#   'of',
#   'the',
#   'as',
#   'in',
#   'boulter',
#   'a',
#   'role',
#   'as',
#   'in',
#   'the',
#   's',
#   'of',
#   'the',
#   'television',
#   'series',
#   'the',
#   'he',
#   'starred',
#   'and',
#   'boulter',
#   'starred',
#   'as',
#   'in',
#   'the',
#   'theatre',
#   'of',
#   'the',
#   'it',
#   'was',
#   'at',
#   'the',
#   'theatre',
#   'in',
#   'and',
#   'the',
#   'in',
#   'he',
#   'was',
#   'by',
#   'and',
#   'starred',
#   'and',
#   'boulter',
#   'a',
#   'in',
#   'the',
#   'the',
#   'is',
#   'with',
#   'from',
#   'from',
#   'his',
#   'as',
#   's',
#   'boulter',
#   'and',
#   'the',
#   'and',
#   'boulter',
#   'the',
#   'in',
#   'boulter',
#   'starred',
#   'in',
#   'the',
#   'by',
#   'the',
#   'was',
#   'of',
#   'a',
#   'series',
#   'which',
#   'in',
#   'a',
#   'boulter',
#   'as',
#   'one',
#   'of',
#   'his',
#   'with',
#   'a',
#   'boulter',
#   'who',
#   'was',
#   'in',
#   'the',
#   'of',
#   'and',
#   'at',
#   'the',
#   'he',
#   'in',
#   'he',
#   'on',
#   'the',
#   'of',
#   'the',
#   'television',
#   'series',
#   'boulter',
#   'starred',
#   'as',
#   'in',
#   'the',
#   'of',
#   'to',
#   'by',
#   'to',
#   'was',
#   'at',
#   'theatre',
#   'in',
#   'the',
#   'of',
#   'and',
#   'in',
#   'a',
#   'of',
#   'the',
#   'for',
#   'the',
#   'theatre',
#   'boulter',
#   'a',
#   'to',
#   'the',
#   'as',
#   'boulter',
#   'starred',
#   'in',
#   'two',
#   'in',
#   'by',
#   'and',
#   'by',
#   'boulter',
#   'a',
#   'in',
#   'who',
#   'with',
#   'as',
#   'the',
#   'who',
#   'it',
#   'with',
#   'boulter',
#   'starred',
#   'on',
#   'a',
#   'two',
#   'in',
#   'of',
#   'the',
#   'television',
#   'series',
#   'the',
#   'as',
#   'he',
#   'on',
#   'the',
#   'television',
#   'series',
#   'as',
#   'in',
#   'he',
#   'had',
#   'a',
#   'role',
#   'in',
#   'of',
#   'the',
#   'television',
#   'series',
#   'in',
#   'as',
#   'he',
#   'an',
#   'for',
#   'a',
#   'he',
#   'on',
#   'the',
#   'in',
#   'a',
#   'on',
#   'television',
#   'a',
#   'is',
#   'a',
#   'is',
#   'but',
#   'are',
#   'on',
#   'who',
#   'are',
#   'at',
#   'and',
#   'the',
#   'to',
#   'and',
#   'boulter',
#   'starred',
#   'in',
#   'the',
#   'by',
#   'television',
#   'theatre',
#   'du',
#   'fu',
#   'du',
#   'fu',
#   'fu',
#   'chinese',
#   'was',
#   'a',
#   'chinese',
#   'poet',
#   'of',
#   'the',
#   'with',
#   'he',
#   'is',
#   'the',
#   'of',
#   'the',
#   'chinese',
#   'his',
#   'was',
#   'to',
#   'his',
#   'as',
#   'a',
#   'but',
#   'he',
#   'to',
#   'the',
#   'his',
#   'life',
#   'the',
#   'was',
#   'by',
#   'the',
#   'an',
#   'of',
#   'and',
#   'his',
#   'years',
#   'a',
#   'time',
#   'of',
#   'he',
#   'was',
#   'to',
#   'his',
#   'works',
#   'to',
#   'be',
#   'in',
#   'chinese',
#   'and',
#   'of',
#   'his',
#   'poems',
#   'have',
#   'been',
#   'the',
#   'he',
#   'been',
#   'the',
#   'poet',
#   'and',
#   'the',
#   'poet',
#   'by',
#   'chinese',
#   'the',
#   'of',
#   'his',
#   'to',
#   'be',
#   'to',
#   'as',
#   'the',
#   'chinese',
#   'or',
#   'life',
#   'chinese',
#   'the',
#   'life',
#   'of',
#   'the',
#   'a',
#   'a',
#   'which',
#   'to',
#   'the',
#   'that',
#   'chinese',
#   'and',
#   'of',
#   'du',
#   'fu',
#   's',
#   'poems',
#   'and',
#   'this',
#   'is',
#   'by',
#   'the',
#   'chinese',
#   'is',
#   'that',
#   'chinese',
#   'poems',
#   'are',
#   'that',
#   'be',
#   'but',
#   'which',
#   'an',
#   'be',
#   'to',
#   'for',
#   'the',
#   'the',
#   'time',
#   'the',
#   'and',
#   'the',
#   'in',
#   'the',
#   'the',
#   'are',
#   'to',
#   'it',
#   'and',
#   'the',
#   'be',
#   'that',
#   'the',
#   'or',
#   'to',
#   'it',
#   'a',
#   'to',
#   'du',
#   'fu',
#   'that',
#   'the',
#   'of',
#   'the',
#   'poet',
#   's',
#   'of',
#   'his',
#   'life',
#   'the',
#   'for',
#   'years',
#   'of',
#   'is',
#   'of',
#   'du',
#   'fu',
#   's',
#   'life',
#   'from',
#   'his',
#   'poems',
#   'his',
#   'was',
#   'du',
#   'a',
#   'and',
#   'poet',
#   'the',
#   'of',
#   'du',
#   'fu',
#   'was',
#   'in',
#   'the',
#   'is',
#   'that',
#   'it',
#   'was',
#   'is',
#   'a',
#   'in',
#   'life',
#   'he',
#   'to',
#   'to',
#   'the',
#   'of',
#   'an',
#   'of',
#   'the',
#   'du',
#   'du',
#   'fu',
#   's',
#   'he',
#   'was',
#   'and',
#   'he',
#   'was',
#   'by',
#   'his',
#   'he',
#   'had',
#   'an',
#   'who',
#   'he',
#   'had',
#   'and',
#   'one',
#   'to',
#   'he',
#   'in',
#   'his',
#   'poems',
#   'he',
#   'his',
#   'the',
#   'of',
#   'a',
#   'his',
#   'was',
#   'on',
#   'the',
#   'of',
#   'a',
#   'and',
#   'of',
#   'the',
#   'of',
#   'and',
#   'he',
#   'to',
#   'have',
#   'poems',
#   'by',
#   'his',
#   'but',
#   'have',
#   'been',
#   'in',
#   'the',
#   's',
#   'he',
#   'in',
#   'the',
#   'his',
#   'a',
#   'is',
#   'to',
#   'from',
#   'the',
#   'of',
#   'this',
#   'in',
#   'that',
#   'he',
#   'the',
#   'in',
#   'an',
#   'he',
#   'to',
#   'his',
#   'and',
#   'that',
#   'of',
#   'of',
#   'that',
#   'he',
#   'his',
#   'at',
#   'the',
#   'time',
#   'was',
#   'and',
#   'his',
#   'to',
#   'in',
#   'the',
#   'have',
#   'been',
#   'to',
#   'this',
#   'he',
#   'to',
#   'this',
#   'time',
#   'and',
#   'his',
#   'du',
#   'fu',
#   'have',
#   'been',
#   'to',
#   'the',
#   'of',
#   'his',
#   's',
#   'but',
#   'he',
#   'is',
#   'to',
#   'have',
#   'the',
#   'in',
#   'of',
#   'one',
#   'of',
#   'his',
#   'he',
#   'the',
#   'years',
#   'in',
#   'the',
#   'his',
#   'in',
#   'in',
#   'the',
#   'of',
#   'he',
#   'for',
#   'the',
#   'time',
#   'and',
#   'the',
#   'two',
#   'a',
#   'this',
#   'as',
#   'the',
#   'in',
#   'du',
#   'fu',
#   's',
#   'it',
#   'a',
#   'of',
#   'the',
#   'poet',
#   'life',
#   'to',
#   'which',
#   'he',
#   'was',
#   'his',
#   'in',
#   'the',
#   'the',
#   'was',
#   'one',
#   'du',
#   'fu',
#   'was',
#   'by',
#   'years',
#   'the',
#   'was',
#   'a',
#   'have',
#   'poems',
#   'to',
#   'or',
#   'from',
#   'the',
#   'poet',
#   'but',
#   'one',
#   'in',
#   'the',
#   'in',
#   'in',
#   'he',
#   'to',
#   'the',
#   'in',
#   'an',
#   'to',
#   'his',
#   'he',
#   'the',
#   'a',
#   'time',
#   'the',
#   'but',
#   'all',
#   'the',
#   'by',
#   'the',
#   'in',
#   'to',
#   'the',
#   'of',
#   'he',
#   'the',
#   'the',
#   'in',
#   'and',
#   'in',
#   'he',
#   'and',
#   'by',
#   'the',
#   'had',
#   'had',
#   'and',
#   'two',
#   'but',
#   'one',
#   'of',
#   'the',
#   'in',
#   'in',
#   'from',
#   'he',
#   'to',
#   'have',
#   'the',
#   'of',
#   'a',
#   'series',
#   'of',
#   'which',
#   'for',
#   'the',
#   'of',
#   'his',
#   'life',
#   'it',
#   'was',
#   'in',
#   'that',
#   'that',
#   'du',
#   'fu',
#   'was',
#   'to',
#   'his',
#   'to',
#   'the',
#   'of',
#   'a',
#   'by',
#   'in',
#   'the',
#   'in',
#   'he',
#   'an',
#   'as',
#   'of',
#   'the',
#   's',
#   'of',
#   'the',
#   's',
#   'this',
#   'was',
#   'a',
#   'in',
#   'it',
#   'have',
#   'been',
#   'at',
#   'the',
#   'of',
#   'an',
#   'he',
#   'had',
#   'the',
#   'was',
#   'by',
#   'the',
#   'an',
#   'in',
#   'and',
#   'was',
#   'for',
#   'years',
#   'it',
#   'to',
#   'chinese',
#   'the',
#   'of',
#   'but',
#   'years',
#   'the',
#   'the',
#   'been',
#   'or',
#   'this',
#   'time',
#   'du',
#   'fu',
#   'a',
#   'life',
#   'by',
#   'and',
#   'this',
#   'of',
#   'was',
#   'the',
#   'of',
#   'du',
#   'fu',
#   'as',
#   'a',
#   'poet',
#   'that',
#   'he',
#   'the',
#   'of',
#   'his',
#   'and',
#   'he',
#   'and',
#   'he',
#   'for',
#   'or',
#   'from',
#   'the',
#   'of',
#   'the',
#   'of',
#   'his',
#   'he',
#   'of',
#   'the',
#   'of',
#   'his',
#   'he',
#   'to',
#   'the',
#   'of',
#   'in',
#   'his',
#   'of',
#   'his',
#   'du',
#   'fu',
#   'wrote',
#   'on',
#   'have',
#   'the',
#   'be',
#   'by',
#   'the',
#   'in',
#   'was',
#   'to',
#   'the',
#   'and',
#   'du',
#   'fu',
#   'who',
#   'had',
#   'been',
#   'from',
#   'the',
#   'his',
#   'to',
#   'a',
#   'of',
#   'and',
#   'to',
#   'the',
#   'of',
#   'the',
#   'but',
#   'he',
#   'was',
#   'by',
#   'the',
#   'and',
#   'to',
#   'an',
#   'in',
#   'the',
#   'his',
#   ...]]

# %%
test_try = prepare_test_data(c_t_t, 2, vocab)
# Out:
# {'went': 0, 'used': 1, 'series': 2, 'offer': 3, 'debut': 4, 'appointed': 5, 'track': 6, 'above': 7, 'coin': 8, 'organization': 9, 'regional': 10, 'was': 11, 'support': 12, 'buildings': 13, 'few': 14, 'normal': 15, 'festival': 16, 'tale': 17, 'thomas': 18, 'bruins': 19, 'show': 20, 'blue': 21, 'because': 22, 'minister': 23, 'agreed': 24, 'got': 25, 'pope': 26, 'london': 27, 'young': 28, 'deities': 29, 'have': 30, 'whose': 31, 'house': 32, 'start': 33, 'something': 34, 'park': 35, 'cast': 36, 'law': 37, 'remaining': 38, 'germany': 39, 'popular': 40, 'far': 41, 'george': 42, 'sexual': 43, 'effort': 44, 'occupation': 45, 'deal': 46, 'gabbar': 47, 'ruler': 48, 'peace': 49, 'praised': 50, 'college': 51, 'light': 52, 'genus': 53, 'near': 54, 'mid': 55, 'date': 56, 'e': 57, 'instead': 58, 'h': 59, 'uk': 60, 'average': 61, 'jai': 62, 'opportunities': 63, 'over': 64, 'typically': 65, 'chemotherapy': 66, 'competition': 67, 'won': 68, 'october': 69, 
# is ['an', 'television']
# an ['is', 'television', 'and']
# television ['is', 'an', 'and']
# and ['an', 'television', 'he']
# he ['and', 'had', 'a']
# had ['he', 'a', 'role']
# a ['he', 'had', 'role', 'on']
# role ['had', 'a', 'on', 'the']
# on ['a', 'role', 'the', 'television']
# the ['role', 'on', 'television', 'series']
# television ['on', 'the', 'series', 'the']
# series ['the', 'television', 'the', 'in']
# the ['television', 'series', 'in', 'this']
# in ['series', 'the', 'this', 'was']
# this ['the', 'in', 'was', 'by']
# was ['in', 'this', 'by', 'a']
# by ['this', 'was', 'a', 'role']
# a ['was', 'by', 'role', 'in']
# role ['by', 'a', 'in', 'the']
# in ['a', 'role', 'the', 'by']
# the ['role', 'in', 'by', 'which']
# by ['in', 'the', 'which', 'was']
# which ['the', 'by', 'was', 'in']
# was ['by', 'which', 'in', 'at']
# in ['which', 'was', 'at', 'the']
# at ['was', 'in', 'the']
# the ['in', 'at', 'he']
# he ['the', 'had', 'a']
# had ['he', 'a', 'role']
# a ['he', 'had', 'role', 'in']
# role ['had', 'a', 'in', 'the']
# in ['a', 'role', 'the', 'television']
# the ['role', 'in', 'television', 'series']
# television ['in', 'the', 'series', 'in']
# series ['the', 'television', 'in', 'in']
# in ['television', 'series', 'in']
# in ['series', 'in', 'a']
# a ['in', 'role', 'as']
# role ['a', 'as', 'in']
# as ['a', 'role', 'in', 'the']
# in ['role', 'as', 'the', 's']
# the ['as', 'in', 's', 'of']
# s ['in', 'the', 'of', 'the']
# of ['the', 's', 'the', 'television']
# the ['s', 'of', 'television', 'series']
# television ['of', 'the', 'series', 'the']
# series ['the', 'television', 'the', 'he']
# the ['television', 'series', 'he']
# he ['series', 'the', 'and']
# and ['he', 'he', 'was']
# he ['and', 'was', 'in']
# was ['and', 'he', 'in', 'the']
# in ['he', 'was', 'the']
# the ['was', 'in', 'of']
# of ['the', 'the', 'which']
# the ['of', 'which', 'was']
# which ['of', 'the', 'was', 'at']
# was ['the', 'which', 'at', 'the']
# at ['which', 'was', 'the']
# the ['was', 'at', 'in']
# in ['the', 'and', 'the']
# and ['in', 'the', 'in']
# the ['in', 'and', 'in', 'he']
# in ['and', 'the', 'he', 'was']
# he ['the', 'in', 'was', 'by']
# was ['in', 'he', 'by', 'and']
# by ['he', 'was', 'and']
# and ['was', 'by', 'and']
# and ['and', 'in']
# in ['and']
# in ['the', 'by']
# the ['in', 'by', 'he']
# by ['in', 'the', 'he', 'on']
# he ['the', 'by', 'on', 'a']
# on ['by', 'he', 'a', 'of']
# a ['he', 'on', 'of', 'the']
# of ['on', 'a', 'the', 'television']
# the ['a', 'of', 'television', 'series']
# television ['of', 'the', 'series', 'by']
# series ['the', 'television', 'by', 'a']
# by ['television', 'series', 'a', 'role']
# a ['series', 'by', 'role', 'in']
# role ['by', 'a', 'in', 'the']
# in ['a', 'role', 'the']
# the ['role', 'in', 'of']
# of ['the', 'to', 'by']
# to ['of', 'by', 'to']
# by ['of', 'to', 'to', 'was']
# to ['to', 'by', 'was', 'at']
# was ['by', 'to', 'at']
# at ['to', 'was', 'in']
# in ['at', 'the', 'of']
# the ['in', 'of', 'and']
# of ['in', 'the', 'and']
# and ['the', 'of']
# in ['two', 'in']
# two ['in', 'in', 'by']
# in ['in', 'two', 'by', 'and']
# by ['two', 'in', 'and', 'by']
# and ['in', 'by', 'by', 'in']
# by ['by', 'and', 'in']
# in ['and', 'by', 'a']
# a ['in', 'on', 'a']
# on ['a', 'a', 'two']
# a ['a', 'on', 'two', 'of']
# two ['on', 'a', 'of', 'the']
# of ['a', 'two', 'the', 'television']
# the ['two', 'of', 'television', 'series']
# television ['of', 'the', 'series', 'the']
# series ['the', 'television', 'the', 'by']
# the ['television', 'series', 'by', 'an']
# by ['series', 'the', 'an', 'on']
# an ['the', 'by', 'on', 'the']
# on ['by', 'an', 'the', 'television']
# the ['an', 'on', 'television', 'series']
# television ['on', 'the', 'series', 'in']
# series ['the', 'television', 'in', 'he']
# in ['television', 'series', 'he', 'had']
# he ['series', 'in', 'had', 'a']
# had ['in', 'he', 'a', 'role']
# a ['he', 'had', 'role', 'in']
# role ['had', 'a', 'in', 'of']
# in ['a', 'role', 'of', 'the']
# of ['role', 'in', 'the', 'television']
# the ['in', 'of', 'television', 'series']
# television ['of', 'the', 'series', 'in']
# series ['the', 'television', 'in', 'as']
# in ['television', 'series', 'as']
# as ['series', 'in']
# in ['the', 'by']
# the ['in', 'by', 'in']
# by ['in', 'the', 'in']
# in ['the', 'by', 'had']
# had ['in', 'a', 'role']
# a ['had', 'role', 'on']
# role ['had', 'a', 'on', 'the']
# on ['a', 'role', 'the', 'television']
# the ['role', 'on', 'television', 'series']
# television ['on', 'the', 'series', 'the']
# series ['the', 'television', 'the', 'he']
# the ['television', 'series', 'he', 'in']
# he ['series', 'the', 'in', 'the']
# in ['the', 'he', 'the', 'in']
# the ['he', 'in', 'in']
# in ['in', 'the']
# as ['in', 'the']
# in ['as', 'the', 'by']
# the ['as', 'in', 'by', 'which']
# by ['in', 'the', 'which', 'was']
# which ['the', 'by', 'was', 'in']
# was ['by', 'which', 'in', 'at']
# in ['which', 'was', 'at', 'the']
# at ['was', 'in', 'the']
# the ['in', 'at', 'a']
# a ['the', 'of']
# of ['a', 's']
# s ['of', 'in', 'the']
# in ['s', 'the', 'on']
# the ['s', 'in', 'on', 'as']
# on ['in', 'the', 'as', 'in']
# as ['the', 'on', 'in', 'the']
# in ['on', 'as', 'the', 'role']
# the ['as', 'in', 'role', 'and']
# role ['in', 'the', 'and', 'he']
# and ['the', 'role', 'he', 'in']
# he ['role', 'and', 'in', 'the']
# in ['and', 'he', 'the', 'and']
# the ['he', 'in', 'and', 'he']
# and ['in', 'the', 'he', 'in']
# he ['the', 'and', 'in', 'the']
# in ['and', 'he', 'the', 'television']
# the ['he', 'in', 'television', 'series']
# television ['in', 'the', 'series', 'in']
# series ['the', 'television', 'in', 'as']
# in ['television', 'series', 'as', 'in']
# as ['series', 'in', 'in', 'the']
# in ['in', 'as', 'the', 'and']
# the ['as', 'in', 'and', 'had']
# and ['in', 'the', 'had', 'a']
# had ['the', 'and', 'a', 'role']
# a ['and', 'had', 'role', 'as']
# role ['had', 'a', 'as', 'a']
# as ['a', 'role', 'a', 'on']
# a ['role', 'as', 'on', 'the']
# on ['as', 'a', 'the', 'he']
# the ['a', 'on', 'he', 'had']
# he ['on', 'the', 'had', 'a']
# had ['the', 'he', 'a', 'role']
# a ['he', 'had', 'role', 'in']
# role ['had', 'a', 'in', 'on']
# in ['a', 'role', 'on', 'two']
# on ['role', 'in', 'two', 'of']
# two ['in', 'on', 'of', 'the']
# of ['on', 'two', 'the', 'as']
# the ['two', 'of', 'as', 'in']
# as ['of', 'the', 'in']
# in ['the', 'as', 'a']
# a ['in', 'role', 'as']
# role ['a', 'as', 'in']
# as ['a', 'role', 'in', 'the']
# in ['role', 'as', 'the', 's']
# the ['as', 'in', 's', 'of']
# s ['in', 'the', 'of', 'the']
# of ['the', 's', 'the', 'television']
# the ['s', 'of', 'television', 'series']
# television ['of', 'the', 'series', 'the']
# series ['the', 'television', 'the', 'he']
# the ['television', 'series', 'he']
# he ['series', 'the', 'and']
# and ['he']
# as ['in', 'the']
# in ['as', 'the']
# the ['as', 'in', 'of']
# of ['the', 'the', 'it']
# the ['of', 'it', 'was']
# it ['of', 'the', 'was', 'at']
# was ['the', 'it', 'at', 'the']
# at ['it', 'was', 'the']
# the ['was', 'at', 'in']
# in ['the', 'and', 'the']
# and ['in', 'the', 'in']
# the ['in', 'and', 'in', 'he']
# in ['and', 'the', 'he', 'was']
# he ['the', 'in', 'was', 'by']
# was ['in', 'he', 'by', 'and']
# by ['he', 'was', 'and']
# and ['was', 'by', 'and']
# and ['and', 'a']
# a ['and', 'in', 'the']
# in ['a', 'the', 'the']
# the ['a', 'in', 'the', 'is']
# the ['in', 'the', 'is', 'with']
# is ['the', 'the', 'with', 'from']
# with ['the', 'is', 'from', 'from']
# from ['is', 'with', 'from', 'his']
# from ['with', 'from', 'his', 'as']
# his ['from', 'from', 'as', 's']
# as ['from', 'his', 's']
# s ['his', 'as', 'and']
# and ['s', 'the', 'and']
# the ['and', 'and']
# and ['and', 'the', 'the']
# the ['and', 'in']
# in ['the']
# in ['the', 'by']
# the ['in', 'by', 'the']
# by ['in', 'the', 'the', 'was']
# the ['the', 'by', 'was', 'of']
# was ['by', 'the', 'of', 'a']
# of ['the', 'was', 'a', 'series']
# a ['was', 'of', 'series', 'which']
# series ['of', 'a', 'which', 'in']
# which ['a', 'series', 'in', 'a']
# in ['series', 'which', 'a']
# a ['which', 'in', 'as']
# as ['a', 'one', 'of']
# one ['as', 'of', 'his']
# of ['as', 'one', 'his', 'with']
# his ['one', 'of', 'with', 'a']
# with ['of', 'his', 'a']
# a ['his', 'with', 'who']
# who ['a', 'was', 'in']
# was ['who', 'in', 'the']
# in ['who', 'was', 'the', 'of']
# the ['was', 'in', 'of', 'and']
# of ['in', 'the', 'and', 'at']
# and ['the', 'of', 'at', 'the']
# at ['of', 'and', 'the', 'he']
# the ['and', 'at', 'he', 'in']
# he ['at', 'the', 'in', 'he']
# in ['the', 'he', 'he', 'on']
# he ['he', 'in', 'on', 'the']
# on ['in', 'he', 'the', 'of']
# the ['he', 'on', 'of', 'the']
# of ['on', 'the', 'the', 'television']
# the ['the', 'of', 'television', 'series']
# television ['of', 'the', 'series']
# series ['the', 'television']
# as ['in', 'the']
# in ['as', 'the', 'of']
# the ['as', 'in', 'of', 'to']
# of ['in', 'the', 'to', 'by']
# to ['the', 'of', 'by', 'to']
# by ['of', 'to', 'to', 'was']
# to ['to', 'by', 'was', 'at']
# was ['by', 'to', 'at']
# at ['to', 'was', 'in']
# in ['at', 'the', 'of']
# the ['in', 'of', 'and']
# of ['in', 'the', 'and', 'in']
# and ['the', 'of', 'in', 'a']
# in ['of', 'and', 'a', 'of']
# a ['and', 'in', 'of', 'the']
# of ['in', 'a', 'the', 'for']
# the ['a', 'of', 'for', 'the']
# for ['of', 'the', 'the']
# the ['the', 'for']
# a ['to', 'the']
# to ['a', 'the', 'as']
# the ['a', 'to', 'as']
# as ['to', 'the']
# in ['two', 'in']
# two ['in', 'in', 'by']
# in ['in', 'two', 'by', 'and']
# by ['two', 'in', 'and', 'by']
# and ['in', 'by', 'by']
# by ['by', 'and', 'a']
# a ['by', 'in', 'who']
# in ['a', 'who', 'with']
# who ['a', 'in', 'with', 'as']
# with ['in', 'who', 'as', 'the']
# as ['who', 'with', 'the', 'who']
# the ['with', 'as', 'who', 'it']
# who ['as', 'the', 'it', 'with']
# it ['the', 'who', 'with']
# with ['who', 'it']
# on ['a', 'two']
# a ['on', 'two', 'in']
# two ['on', 'a', 'in', 'of']
# in ['a', 'two', 'of', 'the']
# of ['two', 'in', 'the', 'television']
# the ['in', 'of', 'television', 'series']
# television ['of', 'the', 'series', 'the']
# series ['the', 'television', 'the', 'as']
# the ['television', 'series', 'as', 'he']
# as ['series', 'the', 'he', 'on']
# he ['the', 'as', 'on', 'the']
# on ['as', 'he', 'the', 'television']
# the ['he', 'on', 'television', 'series']
# television ['on', 'the', 'series', 'as']
# series ['the', 'television', 'as', 'in']
# as ['television', 'series', 'in', 'he']
# in ['series', 'as', 'he', 'had']
# he ['as', 'in', 'had', 'a']
# had ['in', 'he', 'a', 'role']
# a ['he', 'had', 'role', 'in']
# role ['had', 'a', 'in', 'of']
# in ['a', 'role', 'of', 'the']
# of ['role', 'in', 'the', 'television']
# the ['in', 'of', 'television', 'series']
# television ['of', 'the', 'series', 'in']
# series ['the', 'television', 'in', 'as']
# in ['television', 'series', 'as', 'he']
# as ['series', 'in', 'he', 'an']
# he ['in', 'as', 'an', 'for']
# an ['as', 'he', 'for', 'a']
# for ['he', 'an', 'a', 'he']
# a ['an', 'for', 'he', 'on']
# he ['for', 'a', 'on', 'the']
# on ['a', 'he', 'the', 'in']
# the ['he', 'on', 'in', 'a']
# in ['on', 'the', 'a', 'on']
# a ['the', 'in', 'on', 'television']
# on ['in', 'a', 'television', 'a']
# television ['a', 'on', 'a', 'is']
# a ['on', 'television', 'is', 'a']
# is ['television', 'a', 'a', 'is']
# a ['a', 'is', 'is', 'but']
# is ['is', 'a', 'but', 'are']
# but ['a', 'is', 'are', 'on']
# are ['is', 'but', 'on', 'who']
# on ['but', 'are', 'who', 'are']
# who ['are', 'on', 'are', 'at']
# are ['on', 'who', 'at', 'and']
# at ['who', 'are', 'and', 'the']
# and ['are', 'at', 'the', 'to']
# the ['at', 'and', 'to', 'and']
# to ['and', 'the', 'and']
# and ['the', 'to']
# in ['the', 'by']
# the ['in', 'by', 'television']
# by ['in', 'the', 'television']
# television ['the', 'by']
# was ['a']
# a ['was']
# of ['the', 'with']
# the ['of', 'with', 'he']
# with ['of', 'the', 'he', 'is']
# he ['the', 'with', 'is', 'the']
# is ['with', 'he', 'the', 'of']
# the ['he', 'is', 'of', 'the']
# of ['is', 'the', 'the']
# the ['the', 'of', 'his']
# his ['the', 'was', 'to']
# was ['his', 'to', 'his']
# to ['his', 'was', 'his', 'as']
# his ['was', 'to', 'as', 'a']
# as ['to', 'his', 'a', 'but']
# a ['his', 'as', 'but', 'he']
# but ['as', 'a', 'he', 'to']
# he ['a', 'but', 'to', 'the']
# to ['but', 'he', 'the', 'his']
# the ['he', 'to', 'his', 'life']
# his ['to', 'the', 'life', 'the']
# life ['the', 'his', 'the', 'was']
# the ['his', 'life', 'was', 'by']
# was ['life', 'the', 'by', 'the']
# by ['the', 'was', 'the', 'an']
# the ['was', 'by', 'an', 'of']
# an ['by', 'the', 'of', 'and']
# of ['the', 'an', 'and', 'his']
# and ['an', 'of', 'his', 'years']
# his ['of', 'and', 'years', 'a']
# years ['and', 'his', 'a', 'time']
# a ['his', 'years', 'time', 'of']
# time ['years', 'a', 'of', 'he']
# of ['a', 'time', 'he', 'was']
# he ['time', 'of', 'was', 'to']
# was ['of', 'he', 'to', 'his']
# to ['he', 'was', 'his', 'works']
# his ['was', 'to', 'works', 'to']
# works ['to', 'his', 'to', 'be']
# to ['his', 'works', 'be', 'in']
# be ['works', 'to', 'in']
# in ['to', 'be', 'and']
# and ['in', 'of', 'his']
# of ['and', 'his']
# his ['and', 'of', 'have']
# have ['his', 'been', 'the']
# been ['have', 'the', 'he']
# the ['have', 'been', 'he', 'been']
# he ['been', 'the', 'been', 'the']
# been ['the', 'he', 'the']
# the ['he', 'been', 'and']
# and ['the', 'the']
# the ['and', 'by']
# by ['the', 'the']
# the ['by', 'of', 'his']
# of ['the', 'his', 'to']
# his ['the', 'of', 'to', 'be']
# to ['of', 'his', 'be', 'to']
# be ['his', 'to', 'to', 'as']
# to ['to', 'be', 'as', 'the']
# as ['be', 'to', 'the']
# the ['to', 'as', 'or']
# or ['the', 'life']
# life ['or', 'the']
# the ['life', 'life', 'of']
# life ['the', 'of', 'the']
# of ['the', 'life', 'the', 'a']
# the ['life', 'of', 'a', 'a']
# a ['of', 'the', 'a', 'which']
# a ['the', 'a', 'which', 'to']
# which ['a', 'a', 'to', 'the']
# to ['a', 'which', 'the', 'that']
# the ['which', 'to', 'that']
# that ['to', 'the', 'and']
# and ['that', 'of']
# of ['and']
# s ['and']
# and ['s', 'this', 'is']
# this ['and', 'is', 'by']
# is ['and', 'this', 'by', 'the']
# by ['this', 'is', 'the']
# the ['is', 'by', 'is']
# is ['the', 'that']
# that ['is']
# are ['that', 'be']
# that ['are', 'be', 'but']
# be ['are', 'that', 'but', 'which']
# but ['that', 'be', 'which', 'an']
# which ['be', 'but', 'an', 'be']
# an ['but', 'which', 'be', 'to']
# be ['which', 'an', 'to', 'for']
# to ['an', 'be', 'for', 'the']
# for ['be', 'to', 'the', 'the']
# the ['to', 'for', 'the', 'time']
# the ['for', 'the', 'time', 'the']
# time ['the', 'the', 'the', 'and']
# the ['the', 'time', 'and', 'the']
# and ['time', 'the', 'the', 'in']
# the ['the', 'and', 'in', 'the']
# in ['and', 'the', 'the', 'the']
# the ['the', 'in', 'the', 'are']
# the ['in', 'the', 'are', 'to']
# are ['the', 'the', 'to', 'it']
# to ['the', 'are', 'it', 'and']
# it ['are', 'to', 'and', 'the']
# and ['to', 'it', 'the', 'be']
# the ['it', 'and', 'be', 'that']
# be ['and', 'the', 'that', 'the']
# that ['the', 'be', 'the', 'or']
# the ['be', 'that', 'or', 'to']
# or ['that', 'the', 'to', 'it']
# to ['the', 'or', 'it', 'a']
# it ['or', 'to', 'a', 'to']
# a ['to', 'it', 'to']
# to ['it', 'a']
# that ['the', 'of']
# the ['that', 'of', 'the']
# of ['that', 'the', 'the']
# the ['the', 'of', 's']
# s ['the', 'of', 'his']
# of ['s', 'his', 'life']
# his ['s', 'of', 'life', 'the']
# life ['of', 'his', 'the', 'for']
# the ['his', 'life', 'for', 'years']
# for ['life', 'the', 'years', 'of']
# years ['the', 'for', 'of', 'is']
# of ['for', 'years', 'is', 'of']
# is ['years', 'of', 'of']
# of ['of', 'is']
# s ['life', 'from']
# life ['s', 'from', 'his']
# from ['s', 'life', 'his']
# his ['life', 'from', 'his']
# his ['his', 'was']
# was ['his', 'a']
# a ['was', 'and']
# and ['a', 'the']
# the ['and', 'of']
# of ['the']
# was ['in', 'the']
# in ['was', 'the', 'is']
# the ['was', 'in', 'is', 'that']
# is ['in', 'the', 'that', 'it']
# that ['the', 'is', 'it', 'was']
# it ['is', 'that', 'was', 'is']
# was ['that', 'it', 'is', 'a']
# is ['it', 'was', 'a', 'in']
# a ['was', 'is', 'in', 'life']
# in ['is', 'a', 'life', 'he']
# life ['a', 'in', 'he', 'to']
# he ['in', 'life', 'to', 'to']
# to ['life', 'he', 'to', 'the']
# to ['he', 'to', 'the', 'of']
# the ['to', 'to', 'of', 'an']
# of ['to', 'the', 'an', 'of']
# an ['the', 'of', 'of', 'the']
# of ['of', 'an', 'the']
# the ['an', 'of']
# s ['he', 'was']
# he ['s', 'was', 'and']
# was ['s', 'he', 'and', 'he']
# and ['he', 'was', 'he', 'was']
# he ['was', 'and', 'was', 'by']
# was ['and', 'he', 'by', 'his']
# by ['he', 'was', 'his', 'he']
# his ['was', 'by', 'he', 'had']
# he ['by', 'his', 'had', 'an']
# had ['his', 'he', 'an', 'who']
# an ['he', 'had', 'who', 'he']
# who ['had', 'an', 'he', 'had']
# he ['an', 'who', 'had', 'and']
# had ['who', 'he', 'and', 'one']
# and ['he', 'had', 'one', 'to']
# one ['had', 'and', 'to', 'he']
# to ['and', 'one', 'he', 'in']
# he ['one', 'to', 'in', 'his']
# in ['to', 'he', 'his']
# his ['he', 'in', 'he']
# he ['his', 'his', 'the']
# his ['he', 'the', 'of']
# the ['he', 'his', 'of', 'a']
# of ['his', 'the', 'a', 'his']
# a ['the', 'of', 'his', 'was']
# his ['of', 'a', 'was', 'on']
# was ['a', 'his', 'on', 'the']
# on ['his', 'was', 'the', 'of']
# the ['was', 'on', 'of', 'a']
# of ['on', 'the', 'a', 'and']
# a ['the', 'of', 'and', 'of']
# and ['of', 'a', 'of', 'the']
# of ['a', 'and', 'the', 'of']
# the ['and', 'of', 'of', 'and']
# of ['of', 'the', 'and', 'he']
# and ['the', 'of', 'he', 'to']
# he ['of', 'and', 'to', 'have']
# to ['and', 'he', 'have']
# have ['he', 'to', 'by']
# by ['have', 'his', 'but']
# his ['by', 'but', 'have']
# but ['by', 'his', 'have', 'been']
# have ['his', 'but', 'been', 'in']
# been ['but', 'have', 'in', 'the']
# in ['have', 'been', 'the', 's']
# the ['been', 'in', 's', 'he']
# s ['in', 'the', 'he', 'in']
# he ['the', 's', 'in', 'the']
# in ['s', 'he', 'the', 'his']
# the ['he', 'in', 'his', 'a']
# his ['in', 'the', 'a', 'is']
# a ['the', 'his', 'is', 'to']
# is ['his', 'a', 'to', 'from']
# to ['a', 'is', 'from', 'the']
# from ['is', 'to', 'the', 'of']
# the ['to', 'from', 'of', 'this']
# of ['from', 'the', 'this', 'in']
# this ['the', 'of', 'in', 'that']
# in ['of', 'this', 'that', 'he']
# that ['this', 'in', 'he', 'the']
# he ['in', 'that', 'the', 'in']
# the ['that', 'he', 'in', 'an']
# in ['he', 'the', 'an', 'he']
# an ['the', 'in', 'he', 'to']
# he ['in', 'an', 'to', 'his']
# to ['an', 'he', 'his', 'and']
# his ['he', 'to', 'and', 'that']
# and ['to', 'his', 'that', 'of']
# that ['his', 'and', 'of', 'of']
# of ['and', 'that', 'of', 'that']
# of ['that', 'of', 'that', 'he']
# that ['of', 'of', 'he', 'his']
# he ['of', 'that', 'his', 'at']
# his ['that', 'he', 'at', 'the']
# at ['he', 'his', 'the', 'time']
# the ['his', 'at', 'time', 'was']
# time ['at', 'the', 'was', 'and']
# was ['the', 'time', 'and', 'his']
# and ['time', 'was', 'his', 'to']
# his ['was', 'and', 'to', 'in']
# to ['and', 'his', 'in', 'the']
# in ['his', 'to', 'the', 'have']
# the ['to', 'in', 'have', 'been']
# have ['in', 'the', 'been', 'to']
# been ['the', 'have', 'to', 'this']
# to ['have', 'been', 'this', 'he']
# this ['been', 'to', 'he', 'to']
# he ['to', 'this', 'to', 'this']
# to ['this', 'he', 'this', 'time']
# this ['he', 'to', 'time', 'and']
# time ['to', 'this', 'and', 'his']
# and ['this', 'time', 'his']
# his ['time', 'and']
# have ['been', 'to']
# been ['have', 'to', 'the']
# to ['have', 'been', 'the', 'of']
# the ['been', 'to', 'of', 'his']
# of ['to', 'the', 'his', 's']
# his ['the', 'of', 's', 'but']
# s ['of', 'his', 'but', 'he']
# but ['his', 's', 'he', 'is']
# he ['s', 'but', 'is', 'to']
# is ['but', 'he', 'to', 'have']
# to ['he', 'is', 'have', 'the']
# have ['is', 'to', 'the', 'in']
# the ['to', 'have', 'in', 'of']
# in ['have', 'the', 'of', 'one']
# of ['the', 'in', 'one', 'of']
# one ['in', 'of', 'of', 'his']
# of ['of', 'one', 'his', 'he']
# his ['one', 'of', 'he', 'the']
# he ['of', 'his', 'the', 'years']
# the ['his', 'he', 'years', 'in']
# years ['he', 'the', 'in', 'the']
# in ['the', 'years', 'the', 'his']
# the ['years', 'in', 'his', 'in']
# his ['in', 'the', 'in', 'in']
# in ['the', 'his', 'in', 'the']
# in ['his', 'in', 'the', 'of']
# the ['in', 'in', 'of', 'he']
# of ['in', 'the', 'he', 'for']
# he ['the', 'of', 'for', 'the']
# for ['of', 'he', 'the', 'time']
# the ['he', 'for', 'time', 'and']
# time ['for', 'the', 'and', 'the']
# and ['the', 'time', 'the', 'two']
# the ['time', 'and', 'two', 'a']
# two ['and', 'the', 'a', 'this']
# a ['the', 'two', 'this', 'as']
# this ['two', 'a', 'as', 'the']
# as ['a', 'this', 'the', 'in']
# the ['this', 'as', 'in']
# in ['as', 'the']
# s ['it', 'a']
# it ['s', 'a', 'of']
# a ['s', 'it', 'of', 'the']
# of ['it', 'a', 'the']
# the ['a', 'of', 'life']
# life ['the', 'to', 'which']
# to ['life', 'which', 'he']
# which ['life', 'to', 'he', 'was']
# he ['to', 'which', 'was', 'his']
# was ['which', 'he', 'his', 'in']
# his ['he', 'was', 'in', 'the']
# in ['was', 'his', 'the', 'the']
# the ['his', 'in', 'the', 'was']
# the ['in', 'the', 'was', 'one']
# was ['the', 'the', 'one']
# one ['the', 'was']
# was ['by', 'years']
# by ['was', 'years', 'the']
# years ['was', 'by', 'the', 'was']
# the ['by', 'years', 'was', 'a']
# was ['years', 'the', 'a', 'have']
# a ['the', 'was', 'have']
# have ['was', 'a', 'to']
# to ['have', 'or', 'from']
# or ['to', 'from', 'the']
# from ['to', 'or', 'the']
# the ['or', 'from', 'but']
# but ['the', 'one', 'in']
# one ['but', 'in', 'the']
# in ['but', 'one', 'the', 'in']
# the ['one', 'in', 'in', 'in']
# in ['in', 'the', 'in', 'he']
# in ['the', 'in', 'he', 'to']
# he ['in', 'in', 'to', 'the']
# to ['in', 'he', 'the', 'in']
# the ['he', 'to', 'in', 'an']
# in ['to', 'the', 'an', 'to']
# an ['the', 'in', 'to', 'his']
# to ['in', 'an', 'his', 'he']
# his ['an', 'to', 'he', 'the']
# he ['to', 'his', 'the', 'a']
# the ['his', 'he', 'a', 'time']
# a ['he', 'the', 'time', 'the']
# time ['the', 'a', 'the', 'but']
# the ['a', 'time', 'but', 'all']
# but ['time', 'the', 'all', 'the']
# all ['the', 'but', 'the', 'by']
# the ['but', 'all', 'by', 'the']
# by ['all', 'the', 'the', 'in']
# the ['the', 'by', 'in', 'to']
# in ['by', 'the', 'to', 'the']
# to ['the', 'in', 'the', 'of']
# the ['in', 'to', 'of', 'he']
# of ['to', 'the', 'he', 'the']
# he ['the', 'of', 'the', 'the']
# the ['of', 'he', 'the', 'in']
# the ['he', 'the', 'in', 'and']
# in ['the', 'the', 'and', 'in']
# and ['the', 'in', 'in', 'he']
# in ['in', 'and', 'he', 'and']
# he ['and', 'in', 'and', 'by']
# and ['in', 'he', 'by', 'the']
# by ['he', 'and', 'the', 'had']
# the ['and', 'by', 'had', 'had']
# had ['by', 'the', 'had', 'and']
# had ['the', 'had', 'and', 'two']
# and ['had', 'had', 'two', 'but']
# two ['had', 'and', 'but', 'one']
# but ['and', 'two', 'one', 'of']
# one ['two', 'but', 'of', 'the']
# of ['but', 'one', 'the', 'in']
# the ['one', 'of', 'in', 'in']
# in ['of', 'the', 'in', 'from']
# in ['the', 'in', 'from', 'he']
# from ['in', 'in', 'he', 'to']
# he ['in', 'from', 'to', 'have']
# to ['from', 'he', 'have', 'the']
# have ['he', 'to', 'the', 'of']
# the ['to', 'have', 'of', 'a']
# of ['have', 'the', 'a', 'series']
# a ['the', 'of', 'series', 'of']
# series ['of', 'a', 'of', 'which']
# of ['a', 'series', 'which', 'for']
# which ['series', 'of', 'for', 'the']
# for ['of', 'which', 'the', 'of']
# the ['which', 'for', 'of', 'his']
# of ['for', 'the', 'his', 'life']
# his ['the', 'of', 'life', 'it']
# life ['of', 'his', 'it', 'was']
# it ['his', 'life', 'was', 'in']
# was ['life', 'it', 'in', 'that']
# in ['it', 'was', 'that', 'that']
# that ['was', 'in', 'that']
# that ['in', 'that']
# was ['to', 'his']
# to ['was', 'his', 'to']
# his ['was', 'to', 'to', 'the']
# to ['to', 'his', 'the', 'of']
# the ['his', 'to', 'of', 'a']
# of ['to', 'the', 'a', 'by']
# a ['the', 'of', 'by', 'in']
# by ['of', 'a', 'in', 'the']
# in ['a', 'by', 'the', 'in']
# the ['by', 'in', 'in', 'he']
# in ['in', 'the', 'he', 'an']
# he ['the', 'in', 'an', 'as']
# an ['in', 'he', 'as', 'of']
# as ['he', 'an', 'of', 'the']
# of ['an', 'as', 'the', 's']
# the ['as', 'of', 's', 'of']
# s ['of', 'the', 'of', 'the']
# of ['the', 's', 'the', 's']
# the ['s', 'of', 's', 'this']
# s ['of', 'the', 'this', 'was']
# this ['the', 's', 'was', 'a']
# was ['s', 'this', 'a', 'in']
# a ['this', 'was', 'in', 'it']
# in ['was', 'a', 'it', 'have']
# it ['a', 'in', 'have', 'been']
# have ['in', 'it', 'been', 'at']
# been ['it', 'have', 'at', 'the']
# at ['have', 'been', 'the', 'of']
# the ['been', 'at', 'of', 'an']
# of ['at', 'the', 'an', 'he']
# an ['the', 'of', 'he', 'had']
# he ['of', 'an', 'had', 'the']
# had ['an', 'he', 'the', 'was']
# the ['he', 'had', 'was', 'by']
# was ['had', 'the', 'by', 'the']
# by ['the', 'was', 'the', 'an']
# the ['was', 'by', 'an', 'in']
# an ['by', 'the', 'in', 'and']
# in ['the', 'an', 'and', 'was']
# and ['an', 'in', 'was', 'for']
# was ['in', 'and', 'for', 'years']
# for ['and', 'was', 'years', 'it']
# years ['was', 'for', 'it', 'to']
# it ['for', 'years', 'to']
# to ['years', 'it', 'the']
# the ['to', 'of', 'but']
# of ['the', 'but', 'years']
# but ['the', 'of', 'years', 'the']
# years ['of', 'but', 'the', 'the']
# the ['but', 'years', 'the', 'been']
# the ['years', 'the', 'been', 'or']
# been ['the', 'the', 'or', 'this']
# or ['the', 'been', 'this', 'time']
# this ['been', 'or', 'time']
# time ['or', 'this']
# a ['life', 'by']
# life ['a', 'by', 'and']
# by ['a', 'life', 'and', 'this']
# and ['life', 'by', 'this', 'of']
# this ['by', 'and', 'of', 'was']
# of ['and', 'this', 'was', 'the']
# was ['this', 'of', 'the', 'of']
# the ['of', 'was', 'of']
# of ['was', 'the']
# as ['a']
# a ['as', 'that']
# that ['a', 'he', 'the']
# he ['that', 'the', 'of']
# the ['that', 'he', 'of', 'his']
# of ['he', 'the', 'his', 'and']
# his ['the', 'of', 'and', 'he']
# and ['of', 'his', 'he', 'and']
# he ['his', 'and', 'and', 'he']
# and ['and', 'he', 'he', 'for']
# he ['he', 'and', 'for', 'or']
# for ['and', 'he', 'or', 'from']
# or ['he', 'for', 'from', 'the']
# from ['for', 'or', 'the', 'of']
# the ['or', 'from', 'of', 'the']
# of ['from', 'the', 'the', 'of']
# the ['the', 'of', 'of', 'his']
# of ['of', 'the', 'his', 'he']
# his ['the', 'of', 'he', 'of']
# he ['of', 'his', 'of', 'the']
# of ['his', 'he', 'the', 'of']
# the ['he', 'of', 'of', 'his']
# of ['of', 'the', 'his', 'he']
# his ['the', 'of', 'he', 'to']
# he ['of', 'his', 'to', 'the']
# to ['his', 'he', 'the', 'of']
# the ['he', 'to', 'of', 'in']
# of ['to', 'the', 'in', 'his']
# in ['the', 'of', 'his', 'of']
# his ['of', 'in', 'of', 'his']
# of ['in', 'his', 'his']
# his ['his', 'of']
# wrote ['on', 'have']
# on ['wrote', 'have', 'the']
# have ['wrote', 'on', 'the', 'be']
# the ['on', 'have', 'be', 'by']
# be ['have', 'the', 'by', 'the']
# by ['the', 'be', 'the', 'in']
# the ['be', 'by', 'in', 'was']
# in ['by', 'the', 'was', 'to']
# was ['the', 'in', 'to', 'the']
# to ['in', 'was', 'the', 'and']
# the ['was', 'to', 'and']
# and ['to', 'the']
# who ['had', 'been']
# had ['who', 'been', 'from']
# been ['who', 'had', 'from', 'the']
# from ['had', 'been', 'the', 'his']
# the ['been', 'from', 'his', 'to']
# his ['from', 'the', 'to', 'a']
# to ['the', 'his', 'a', 'of']
# a ['his', 'to', 'of', 'and']
# of ['to', 'a', 'and', 'to']
# and ['a', 'of', 'to', 'the']
# to ['of', 'and', 'the', 'of']
# the ['and', 'to', 'of', 'the']
# of ['to', 'the', 'the', 'but']
# the ['the', 'of', 'but', 'he']
# but ['of', 'the', 'he', 'was']
# he ['the', 'but', 'was', 'by']
# was ['but', 'he', 'by', 'the']
# by ['he', 'was', 'the', 'and']
# the ['was', 'by', 'and', 'to']
# and ['by', 'the', 'to', 'an']
# to ['the', 'and', 'an', 'in']
# an ['and', 'to', 'in', 'the']
# in ['to', 'an', 'the', 'his']
# the ['an', 'in', 'his']
# his ['in', 'the', 'was']
# was ['his', 'this', 'time']
# this ['was', 'time']
# time ['was', 'this']
# is ['to', 'have']
# to ['is', 'have', 'he']
# have ['is', 'to', 'he', 'from']
# he ['to', 'have', 'from', 'an']
# from ['have', 'he', 'an', 'the']
# an ['he', 'from', 'the', 'and']
# the ['from', 'an', 'and', 'was']
# and ['an', 'the', 'was', 'he']
# was ['the', 'and', 'he', 'the']
# he ['and', 'was', 'the', 'in']
# the ['was', 'he', 'in', 'this']
# in ['he', 'the', 'this', 'to']
# this ['the', 'in', 'to', 'the']
# to ['in', 'this', 'the', 'but']
# the ['this', 'to', 'but', 'was']
# but ['to', 'the', 'was']
# was ['the', 'but']
# s ['to', 'to']
# to ['s', 'to', 'of']
# to ['s', 'to', 'of', 'it']
# of ['to', 'to', 'it', 'he']
# it ['to', 'of', 'he', 'for']
# he ['of', 'it', 'for', 'by']
# for ['it', 'he', 'by', 'the']
# by ['he', 'for', 'the', 'of']
# the ['for', 'by', 'of', 'his']
# of ['by', 'the', 'his', 'and']
# his ['the', 'of', 'and', 'on']
# and ['of', 'his', 'on', 'a']
# on ['his', 'and', 'a', 'he']
# a ['and', 'on', 'he', 'was']
# he ['on', 'a', 'was', 'but']
# was ['a', 'he', 'but', 'was']
# but ['he', 'was', 'was', 'in']
# was ['was', 'but', 'in', 'he']
# in ['but', 'was', 'he', 'was']
# he ['was', 'in', 'was', 'to']
# was ['in', 'he', 'to', 'his']
# to ['he', 'was', 'his', 'in']
# his ['was', 'to', 'in', 'but']
# in ['to', 'his', 'but', 'he']
# but ['his', 'in', 'he', 'the']
# he ['in', 'but', 'the', 'and']
# the ['but', 'he', 'and', 'on']
# and ['he', 'the', 'on', 'he']
# on ['the', 'and', 'he', 'to']
# he ['and', 'on', 'to', 'an']
# to ['on', 'he', 'an', 'with']
# an ['he', 'to', 'with', 'the']
# with ['to', 'an', 'the', 'by']
# the ['an', 'with', 'by', 'his']
# by ['with', 'the', 'his', 'to']
# his ['the', 'by', 'to', 'be']
# to ['by', 'his', 'be', 'and']
# be ['his', 'to', 'and', 'in']
# and ['to', 'be', 'in', 'the']
# in ['be', 'and', 'the', 'of']
# the ['and', 'in', 'of', 'he']
# of ['in', 'the', 'he', 'was']
# he ['the', 'of', 'was', 'to']
# was ['of', 'he', 'to', 'a']
# to ['he', 'was', 'a', 'as']
# a ['was', 'to', 'as', 'of']
# as ['to', 'a', 'of', 'in']
# of ['a', 'as', 'in', 'the']
# in ['as', 'of', 'the', 'was']
# the ['of', 'in', 'was', 'to']
# was ['in', 'the', 'to', 'his']
# to ['the', 'was', 'his', 'in']
# his ['was', 'to', 'in', 'one']
# in ['to', 'his', 'one', 'he']
# one ['his', 'in', 'he', 'wrote']
# he ['in', 'one', 'wrote', 'to']
# wrote ['one', 'he', 'to', 'in']
# to ['he', 'wrote', 'in', 'the']
# in ['wrote', 'to', 'the', 'to']
# the ['to', 'in', 'to', 'on']
# to ['in', 'the', 'on', 'he']
# on ['the', 'to', 'he', 'on']
# he ['to', 'on', 'on', 'in']
# on ['on', 'he', 'in', 'the']
# in ['he', 'on', 'the', 'of']
# the ['on', 'in', 'of', 'this']
# of ['in', 'the', 'this', 'been']
# this ['the', 'of', 'been', 'to']
# been ['of', 'this', 'to', 'but']
# to ['this', 'been', 'but', 'that']
# but ['been', 'to', 'that', 'is']
# that ['to', 'but', 'is', 'a']
# is ['but', 'that', 'a', 'he']
# a ['that', 'is', 'he', 'in']
# he ['is', 'a', 'in', 'he']
# in ['a', 'he', 'he', 'wrote']
# he ['he', 'in', 'wrote']
# wrote ['in', 'he', 'in']
# in ['wrote', 'he', 'in']
# he ['in', 'in', 'he']
# in ['in', 'he', 'he', 'on']
# he ['he', 'in', 'on', 'for']
# on ['in', 'he', 'for', 'he']
# for ['he', 'on', 'he', 'was']
# he ['on', 'for', 'was', 'by']
# was ['for', 'he', 'by', 'and']
# by ['he', 'was', 'and']
# and ['was', 'by']
# in ['for', 'of']
# for ['in', 'of', 'the']
# of ['in', 'for', 'the', 'years']
# the ['for', 'of', 'years', 'by']
# years ['of', 'the', 'by', 'the']
# by ['the', 'years', 'the', 'of']
# the ['years', 'by', 'of', 'that']
# of ['by', 'the', 'that', 'he']
# that ['the', 'of', 'he', 'was']
# he ['of', 'that', 'was', 'in']
# was ['that', 'he', 'in', 'and']
# in ['he', 'was', 'and']
# and ['was', 'in', 'to']
# to ['and', 'he', 'was']
# he ['to', 'was', 'by']
# was ['to', 'he', 'by', 'a']
# by ['he', 'was', 'a', 'and']
# a ['was', 'by', 'and', 'who']
# and ['by', 'a', 'who', 'was']
# who ['a', 'and', 'was', 'at']
# was ['and', 'who', 'at', 'his']
# at ['who', 'was', 'his', 'this']
# his ['was', 'at', 'this', 'was']
# this ['at', 'his', 'was', 'one']
# was ['his', 'this', 'one', 'of']
# one ['this', 'was', 'of', 'the']
# of ['was', 'one', 'the', 'and']
# the ['one', 'of', 'and', 'of']
# and ['of', 'the', 'of', 'his']
# of ['the', 'and', 'his', 'life']
# his ['and', 'of', 'life', 'of']
# life ['of', 'his', 'of']
# of ['his', 'life', 's']
# s ['of', 'from']
# from ['s', 'this', 'are']
# this ['from', 'are', 'of']
# are ['from', 'this', 'of', 'his']
# of ['this', 'are', 'his', 'life']
# his ['are', 'of', 'life', 'at']
# life ['of', 'his', 'at', 'in']
# at ['his', 'life', 'in', 'he']
# in ['life', 'at', 'he', 'the']
# he ['at', 'in', 'the', 'to']
# the ['in', 'he', 'to', 'a']
# to ['he', 'the', 'a', 'but']
# a ['the', 'to', 'but', 'he']
# but ['to', 'a', 'he', 'in']
# he ['a', 'but', 'in', 'he']
# in ['but', 'he', 'he', 'was']
# he ['he', 'in', 'was', 'an']
# was ['in', 'he', 'an', 'to']
# an ['he', 'was', 'to', 'who']
# to ['was', 'an', 'who', 'was']
# who ['an', 'to', 'was', 'in']
# was ['to', 'who', 'in', 'the']
# in ['who', 'was', 'the', 'years']
# the ['was', 'in', 'years', 'the']
# years ['in', 'the', 'the', 'of']
# the ['the', 'years', 'of', 'his']
# of ['years', 'the', 'his', 'was']
# his ['the', 'of', 'was', 'by']
# was ['of', 'his', 'by', 'in']
# by ['his', 'was', 'in', 'the']
# in ['was', 'by', 'the', 'of']
# the ['by', 'in', 'of', 'and']
# of ['in', 'the', 'and', 'in']
# and ['the', 'of', 'in', 'the']
# in ['of', 'and', 'the', 'of']
# the ['and', 'in', 'of']
# of ['in', 'the']
# and ['his', 'the']
# his ['and', 'the', 'with']
# the ['and', 'his', 'with', 'the']
# with ['his', 'the', 'the', 'of']
# the ['the', 'with', 'of', 'by']
# of ['with', 'the', 'by', 'his']
# by ['the', 'of', 'his', 'by']
# his ['of', 'by', 'by', 'this']
# by ['by', 'his', 'this', 'time']
# this ['his', 'by', 'time', 'he']
# time ['by', 'this', 'he', 'was']
# he ['this', 'time', 'was', 'from']
# was ['time', 'he', 'from', 'and']
# from ['he', 'was', 'and', 'in']
# and ['was', 'from', 'in', 'to']
# in ['from', 'and', 'to', 'his']
# to ['and', 'in', 'his', 'in']
# his ['in', 'to', 'in', 'in']
# in ['to', 'his', 'in', 'is']
# in ['his', 'in', 'is', 'at']
# is ['in', 'in', 'at', 'the']
# at ['in', 'is', 'the', 'to']
# the ['is', 'at', 'to', 'the']
# to ['at', 'the', 'the', 'for']
# the ['the', 'to', 'for', 'two']
# for ['to', 'the', 'two', 'years']
# two ['the', 'for', 'years', 'from']
# years ['for', 'two', 'from', 'this']
# from ['two', 'years', 'this', 'was']
# this ['years', 'from', 'was']
# was ['from', 'this']
# s ['and', 'he']
# and ['s', 'he', 'wrote']
# he ['s', 'and', 'wrote']
# wrote ['and', 'he', 'in']
# in ['wrote', 'his', 'in']
# his ['in', 'in', 'of']
# in ['in', 'his', 'of', 'the']
# of ['his', 'in', 'the', 'he']
# the ['in', 'of', 'he']
# he ['of', 'the']
# and ['as', 'his']
# as ['and', 'his', 'in']
# his ['and', 'as', 'in', 'he']
# in ['as', 'his', 'he', 'his']
# he ['his', 'in', 'his', 'and']
# his ['in', 'he', 'and', 'as']
# and ['he', 'his', 'as', 'as']
# as ['his', 'and', 'as', 'he']
# as ['and', 'as', 'he', 'in']
# he ['as', 'as', 'in', 'in']
# in ['as', 'he', 'in', 'or']
# in ['he', 'in', 'or', 'in']
# or ['in', 'in', 'in', 'his']
# in ['in', 'or', 'his', 'he']
# his ['or', 'in', 'he', 'was']
# he ['in', 'his', 'was', 'by']
# was ['his', 'he', 'by', 'his']
# by ['he', 'was', 'his', 'and']
# his ['was', 'by', 'and', 'two']
# and ['by', 'his', 'two', 'who']
# two ['his', 'and', 'who', 'in']
# who ['and', 'two', 'in', 'the']
# in ['two', 'who', 'the', 'for']
# the ['who', 'in', 'for', 'years']
# for ['in', 'the', 'years', 'at']
# years ['the', 'for', 'at', 'his']
# at ['for', 'years', 'his', 'is']
# his ['years', 'at', 'is', 'a']
# is ['at', 'his', 'a', 'who']
# a ['his', 'is', 'who', 'a']
# who ['is', 'a', 'a', 'for']
# a ['a', 'who', 'for', 'the']
# for ['who', 'a', 'the']
# the ['a', 'for', 'from']
# from ['the', 'in', 'his']
# in ['from', 'his', 'life']
# his ['from', 'in', 'life', 'by']
# life ['in', 'his', 'by', 'that']
# by ['his', 'life', 'that', 'he']
# that ['life', 'by', 'he', 'to']
# he ['by', 'that', 'to', 'be']
# to ['that', 'he', 'be', 'a']
# be ['he', 'to', 'a', 'an']
# a ['to', 'be', 'an', 'a']
# an ['be', 'a', 'a', 'a']
# a ['a', 'an', 'a', 'a']
# a ['an', 'a', 'a', 'a']
# a ['a', 'a', 'a', 'and']
# a ['a', 'a', 'and', 'a']
# and ['a', 'a', 'a', 'is']
# a ['a', 'and', 'is', 'an']
# is ['and', 'a', 'an', 'of']
# an ['a', 'is', 'of', 'one']
# of ['is', 'an', 'one', 'of']
# one ['an', 'of', 'of']
# of ['of', 'one']
# s ['works', 'to']
# works ['s', 'to']
# to ['s', 'works']
# in ['the', 'it']
# the ['in', 'it', 'the']
# it ['in', 'the', 'the', 'of']
# the ['the', 'it', 'of', 'a']
# of ['it', 'the', 'a', 'which']
# a ['the', 'of', 'which', 'was']
# which ['of', 'a', 'was', 'to']
# was ['a', 'which', 'to', 'to']
# to ['which', 'was', 'to', 'the']
# to ['was', 'to', 'the', 'works']
# the ['to', 'to', 'works', 'of']
# works ['to', 'the', 'of']
# of ['the', 'works']
# s ['works', 'on']
# works ['s', 'on', 'his']
# on ['s', 'works', 'his', 'of']
# his ['works', 'on', 'of', 'his']
# of ['on', 'his', 'his', 'and']
# his ['his', 'of', 'and', 'his']
# and ['of', 'his', 'his', 'the']
# his ['his', 'and', 'the', 'have']
# the ['and', 'his', 'have']
# have ['his', 'the']
# the ['the']
# the ['the', 'of', 'his']
# of ['the', 'his']
# his ['the', 'of', 'are']
# are ['his', 'on', 'or']
# on ['are', 'or', 'the']
# or ['are', 'on', 'the', 'and']
# the ['on', 'or', 'and', 'of']
# and ['or', 'the', 'of', 'the']
# of ['the', 'and', 'the', 'or']
# the ['and', 'of', 'or', 'the']
# or ['of', 'the', 'the']
# the ['the', 'or', 'of']
# of ['the', 'which', 'he']
# which ['of', 'he', 'wrote']
# he ['of', 'which', 'wrote', 'to']
# wrote ['which', 'he', 'to', 'the']
# to ['he', 'wrote', 'the', 'he']
# the ['wrote', 'to', 'he', 'wrote']
# he ['to', 'the', 'wrote', 'the']
# wrote ['the', 'he', 'the', 'of']
# the ['he', 'wrote', 'of', 'the']
# of ['wrote', 'the', 'the', 'in']
# the ['the', 'of', 'in', 'which']
# in ['of', 'the', 'which', 'he']
# which ['the', 'in', 'he', 'on']
# he ['in', 'which', 'on', 'and']
# on ['which', 'he', 'and', 'on']
# and ['he', 'on', 'on', 'the']
# on ['on', 'and', 'the', 'of']
# the ['and', 'on', 'of', 'as']
# of ['on', 'the', 'as', 'this']
# as ['the', 'of', 'this', 'is']
# this ['of', 'as', 'is', 'of']
# is ['as', 'this', 'of', 'a']
# of ['this', 'is', 'a', 'in']
# a ['is', 'of', 'in', 'the']
# in ['of', 'a', 'the', 'of']
# the ['a', 'in', 'of', 'the']
# of ['in', 'the', 'the']
# the ['the', 'of']
# s ['are', 'on']
# are ['s', 'on', 'his']
# on ['s', 'are', 'his', 'have']
# his ['are', 'on', 'have', 'been']
# have ['on', 'his', 'been', 'as']
# been ['his', 'have', 'as', 'all']
# as ['have', 'been', 'all', 'be']
# all ['been', 'as', 'be', 'all']
# be ['as', 'all', 'all', 'are']
# all ['all', 'be', 'are', 'to']
# are ['be', 'all', 'to', 'his']
# to ['all', 'are', 'his', 'to']
# his ['are', 'to', 'to', 'with']
# to ['to', 'his', 'with', 'his']
# with ['his', 'to', 'his', 'his']
# his ['to', 'with', 'his', 'as']
# his ['with', 'his', 'as', 'the']
# as ['his', 'his', 'the', 'of']
# the ['his', 'as', 'of']
# of ['as', 'the', 'a']
# a ['of', 'of']
# of ['a', 'is']
# is ['of', 'that', 'of']
# that ['is', 'of']
# of ['is', 'that', 'a']
# a ['of', 'to', 'the']
# to ['a', 'the', 'one']
# the ['a', 'to', 'one', 'of']
# one ['to', 'the', 'of', 'the']
# of ['the', 'one', 'the', 'works']
# the ['one', 'of', 'works', 'the']
# works ['of', 'the', 'the', 'of']
# the ['the', 'works', 'of', 'the']
# of ['works', 'the', 'the', 'from']
# the ['the', 'of', 'from', 'to']
# from ['of', 'the', 'to', 'the']
# to ['the', 'from', 'the', 'of']
# the ['from', 'to', 'of', 'a']
# of ['to', 'the', 'a', 'in']
# a ['the', 'of', 'in', 'the']
# in ['of', 'a', 'the', 'and']
# the ['a', 'in', 'and', 'a']
# and ['in', 'the', 'a', 'of']
# a ['the', 'and', 'of', 'are']
# of ['and', 'a', 'are', 'in']
# are ['a', 'of', 'in']
# in ['of', 'are', 'on']
# on ['in', 'the', 'of']
# the ['on', 'of', 'and']
# of ['on', 'the', 'and', 'by']
# and ['the', 'of', 'by']
# by ['of', 'and']
# his ['life']
# life ['his']
# s ['to', 'his']
# to ['s', 'his', 'the']
# his ['s', 'to', 'the', 'of']
# the ['to', 'his', 'of', 'an']
# of ['his', 'the', 'an', 'all']
# an ['the', 'of', 'all', 'that']
# all ['of', 'an', 'that', 'his']
# that ['an', 'all', 'his', 'in']
# his ['all', 'that', 'in', 'and']
# in ['that', 'his', 'and', 'as']
# and ['his', 'in', 'as', 'an']
# as ['in', 'and', 'an', 'he']
# an ['and', 'as', 'he', 'to']
# he ['as', 'an', 'to', 'the']
# to ['an', 'he', 'the', 'by']
# the ['he', 'to', 'by', 'it']
# by ['to', 'the', 'it', 'to']
# it ['the', 'by', 'to', 'his']
# to ['by', 'it', 'his']
# his ['it', 'to']
# s ['for', 'and']
# for ['s', 'and', 'for']
# and ['s', 'for', 'for', 'was']
# for ['for', 'and', 'was', 'of']
# was ['and', 'for', 'of', 'his']
# of ['for', 'was', 'his', 'of']
# his ['was', 'of', 'of', 'the']
# of ['of', 'his', 'the', 'of']
# the ['his', 'of', 'of', 'he']
# of ['of', 'the', 'he', 'works']
# he ['the', 'of', 'works', 'to']
# works ['of', 'he', 'to', 'which']
# to ['he', 'works', 'which', 'had']
# which ['works', 'to', 'had', 'been']
# had ['to', 'which', 'been', 'for']
# been ['which', 'had', 'for', 'wrote']
# for ['had', 'been', 'wrote', 'that']
# wrote ['been', 'for', 'that', 'for']
# that ['for', 'wrote', 'for']
# for ['wrote', 'that']
# in ['this', 'is']
# this ['in', 'is']
# is ['in', 'this', 'wrote']
# wrote ['is', 'on', 'as']
# on ['wrote', 'as', 'life']
# as ['wrote', 'on', 'life', 'and']
# life ['on', 'as', 'and']
# and ['as', 'life']
# s ['is', 'all']
# is ['s', 'all', 'for']
# all ['s', 'is', 'for']
# for ['is', 'all', 'the']
# the ['for', 'a', 'to']
# a ['the', 'to', 'of']
# to ['the', 'a', 'of', 'was']
# of ['a', 'to', 'was', 'the']
# was ['to', 'of', 'the', 'to']
# the ['of', 'was', 'to', 'the']
# to ['was', 'the', 'the', 'of']
# the ['the', 'to', 'of']
# of ['to', 'the']
# s ['in', 'that']
# in ['s', 'that', 'his']
# that ['s', 'in', 'his', 'in']
# his ['in', 'that', 'in', 'his']
# in ['that', 'his', 'his', 'which']
# his ['his', 'in', 'which', 'had']
# which ['in', 'his', 'had', 'he']
# had ['his', 'which', 'he', 'all']
# he ['which', 'had', 'all', 'the']
# all ['had', 'he', 'the', 'of']
# the ['he', 'all', 'of']
# of ['all', 'the', 'that']
# that ['of', 'in', 'he']
# in ['that', 'he', 'or']
# he ['that', 'in', 'or', 'his']
# or ['in', 'he', 'his']
# his ['he', 'or', 'a']
# a ['his', 'of', 'from']
# of ['a', 'from', 'the']
# from ['a', 'of', 'the', 'and']
# the ['of', 'from', 'and', 'to']
# and ['from', 'the', 'to', 'the']
# to ['the', 'and', 'the', 'and']
# the ['and', 'to', 'and', 'this']
# and ['to', 'the', 'this', 'is']
# this ['the', 'and', 'is', 'works']
# is ['and', 'this', 'works', 'the']
# works ['this', 'is', 'the', 'and']
# the ['is', 'works', 'and', 'in']
# and ['works', 'the', 'in']
# in ['the', 'and', 'which']
# which ['in', 'the']
# the ['which', 'to']
# to ['the', 'of', 'a']
# of ['to', 'a', 'the']
# a ['to', 'of', 'the', 'as']
# the ['of', 'a', 'as', 'the']
# as ['a', 'the', 'the', 'in']
# the ['the', 'as', 'in']
# in ['as', 'the']
# is ['for', 'on']
# for ['is', 'on', 'and']
# on ['is', 'for', 'and', 'of']
# and ['for', 'on', 'of', 'his']
# of ['on', 'and', 'his', 'time']
# his ['and', 'of', 'time', 'he']
# time ['of', 'his', 'he', 'wrote']
# he ['his', 'time', 'wrote']
# wrote ['time', 'he', 'on']
# on ['wrote']
# s ['on', 'the']
# on ['s', 'the', 'of']
# the ['s', 'on', 'of', 'a']
# of ['on', 'the', 'a', 'that']
# a ['the', 'of', 'that', 'to']
# that ['of', 'a', 'to', 'the']
# to ['a', 'that', 'the', 'the']
# the ['that', 'to', 'the', 'of']
# the ['to', 'the', 'of', 'his']
# of ['the', 'the', 'his', 'as']
# his ['the', 'of', 'as', 'he']
# as ['of', 'his', 'he', 'his']
# he ['his', 'as', 'his', 'and']
# his ['as', 'he', 'and', 'to']
# and ['he', 'his', 'to', 'his']
# to ['his', 'and', 'his', 'to']
# his ['and', 'to', 'to', 'his']
# to ['to', 'his', 'his', 'works']
# his ['his', 'to', 'works', 'are']
# works ['to', 'his', 'are', 'in']
# are ['his', 'works', 'in', 'a']
# in ['works', 'are', 'a', 'but']
# a ['are', 'in', 'but', 'he']
# but ['in', 'a', 'he', 'his']
# he ['a', 'but', 'his', 'in']
# his ['but', 'he', 'in', 'the']
# in ['he', 'his', 'the', 'years']
# the ['his', 'in', 'years', 'of']
# years ['in', 'the', 'of', 'the']
# of ['the', 'years', 'the', 'on']
# the ['years', 'of', 'on', 'the']
# on ['of', 'the', 'the', 'of']
# the ['the', 'on', 'of', 'the']
# of ['on', 'the', 'the']
# the ['the', 'of', 'which']
# which ['the', 'the', 'the']
# the ['which', 'the', 'works']
# the ['which', 'the', 'works', 'from']
# works ['the', 'the', 'from', 'his']
# from ['the', 'works', 'his', 'are']
# his ['works', 'from', 'are', 'the']
# are ['from', 'his', 'the']
# the ['his', 'are', 'from']
# from ['the', 'the', 'have']
# the ['from', 'have', 'a']
# have ['from', 'the', 'a', 'and']
# a ['the', 'have', 'and', 'of']
# and ['have', 'a', 'of', 'he']
# of ['a', 'and', 'he', 'wrote']
# he ['and', 'of', 'wrote', 'in']
# wrote ['of', 'he', 'in', 'all']
# in ['he', 'wrote', 'all']
# all ['wrote', 'in']
# is ['for', 'his']
# for ['is', 'his', 'a']
# his ['is', 'for', 'a', 'of']
# a ['for', 'his', 'of', 'with']
# of ['his', 'a', 'with', 'on']
# with ['a', 'of', 'on', 'and']
# on ['of', 'with', 'and', 'for']
# and ['with', 'on', 'for', 'two']
# for ['on', 'and', 'two', 'of']
# two ['and', 'for', 'of']
# of ['for', 'two']
# s ['works', 'are']
# works ['s', 'are', 'in']
# are ['s', 'works', 'in', 'this']
# in ['works', 'are', 'this', 'and']
# this ['are', 'in', 'and', 'he']
# and ['in', 'this', 'he', 'is']
# he ['this', 'and', 'is', 'to']
# is ['and', 'he', 'to', 'be']
# to ['he', 'is', 'be', 'his']
# be ['is', 'to', 'his', 'the']
# his ['to', 'be', 'the', 'by']
# the ['be', 'his', 'by', 'the']
# by ['his', 'the', 'the', 'to']
# the ['the', 'by', 'to', 'as']
# to ['by', 'the', 'as', 'that']
# as ['the', 'to', 'that', 'it']
# that ['to', 'as', 'it', 'is']
# it ['as', 'that', 'is', 'that']
# is ['that', 'it', 'that']
# that ['it', 'is', 'is']
# is ['that', 'to', 'a']
# to ['is', 'a', 'in']
# a ['is', 'to', 'in', 'a']
# in ['to', 'a', 'a', 'to']
# a ['a', 'in', 'to', 'the']
# to ['in', 'a', 'the']
# the ['a', 'to']
# s ['are', 'by']
# are ['s', 'by', 'to']
# by ['s', 'are', 'to', 'be']
# to ['are', 'by', 'be', 'the']
# be ['by', 'to', 'the', 'of']
# the ['to', 'be', 'of', 'all']
# of ['be', 'the', 'all', 'time']
# all ['the', 'of', 'time', 'and']
# time ['of', 'all', 'and', 'it']
# and ['all', 'time', 'it', 'his']
# it ['time', 'and', 'his', 'of']
# his ['and', 'it', 'of', 'all']
# of ['it', 'his', 'all', 'the']
# all ['his', 'of', 'the', 'of']
# the ['of', 'all', 'of', 'a']
# of ['all', 'the', 'a', 'and']
# a ['the', 'of', 'and', 'of']
# and ['of', 'a', 'of', 'all']
# of ['a', 'and', 'all', 'the']
# all ['and', 'of', 'the', 'of']
# the ['of', 'all', 'of', 'the']
# of ['all', 'the', 'the', 'that']
# the ['the', 'of', 'that', 'in']
# that ['of', 'the', 'in', 'his']
# in ['the', 'that', 'his', 'and']
# his ['that', 'in', 'and', 'his']
# and ['in', 'his', 'his']
# his ['his', 'and']
# was ['in', 'this']
# in ['was', 'this', 'be']
# this ['was', 'in', 'be', 'to']
# be ['in', 'this', 'to', 'his']
# to ['this', 'be', 'his', 'and']
# his ['be', 'to', 'and', 'of']
# and ['to', 'his', 'of', 'which']
# of ['his', 'and', 'which', 'are']
# which ['and', 'of', 'are', 'and']
# are ['of', 'which', 'and', 'by']
# and ['which', 'are', 'by']
# by ['are', 'and', 'are']
# are ['by', 'to']
# to ['are', 'from']
# from ['to', 'and', 'in']
# and ['from', 'in', 'of']
# in ['from', 'and', 'of', 'but']
# of ['and', 'in', 'but', 'as']
# but ['in', 'of', 'as', 'a']
# as ['of', 'but', 'a', 'of']
# a ['but', 'as', 'of', 'or']
# of ['as', 'a', 'or']
# or ['a', 'of']
# is ['in', 'of']
# in ['is', 'of', 'as']
# of ['is', 'in', 'as', 'he']
# as ['in', 'of', 'he', 'is']
# he ['of', 'as', 'is', 'the']
# is ['as', 'he', 'the']
# the ['he', 'is']
# with ['time', 'and']
# time ['with', 'and', 'his']
# and ['with', 'time', 'his', 'works']
# his ['time', 'and', 'works', 'to']
# works ['and', 'his', 'to', 'in']
# to ['his', 'works', 'in', 'in']
# in ['works', 'to', 'in', 'the']
# in ['to', 'in', 'the', 'from']
# the ['in', 'in', 'from', 'who']
# from ['in', 'the', 'who', 'the']
# who ['the', 'from', 'the', 'of']
# the ['from', 'who', 'of', 'of']
# of ['who', 'the', 'of']
# of ['the', 'of']
# s ['works', 'he']
# works ['s', 'he', 'in']
# he ['s', 'works', 'in', 'a']
# in ['works', 'he', 'a', 'of']
# a ['he', 'in', 'of', 'the']
# of ['in', 'a', 'the']
# the ['a', 'of', 'and']
# and ['the', 'from', 'who']
# from ['and', 'who', 'wrote']
# who ['and', 'from', 'wrote', 'a']
# wrote ['from', 'who', 'a']
# a ['who', 'wrote']
# and ['on', 'from']
# on ['and', 'from', 'the']
# from ['and', 'on', 'the', 'of']
# the ['on', 'from', 'of']
# of ['from', 'the']
# in ['by', 'the']
# by ['in', 'the', 'of']
# the ['in', 'by', 'of', 'the']
# of ['by', 'the', 'the', 'the']
# the ['the', 'of', 'the', 'of']
# the ['of', 'the', 'of', 'his']
# of ['the', 'the', 'his', 'in']
# his ['the', 'of', 'in', 'it']
# in ['of', 'his', 'it', 'was']
# it ['his', 'in', 'was', 'in']
# was ['in', 'it', 'in', 'the']
# in ['it', 'was', 'the', 'the']
# the ['was', 'in', 'the', 'that']
# the ['in', 'the', 'that']
# that ['the', 'the']
# s ['in', 'this']
# in ['s', 'this', 'a']
# this ['s', 'in', 'a', 'of']
# a ['in', 'this', 'of', 'in']
# of ['this', 'a', 'in', 'which']
# in ['a', 'of', 'which', 'and']
# which ['of', 'in', 'and']
# and ['in', 'which']
# to ['be', 'as']
# be ['to', 'as', 'the']
# as ['to', 'be', 'the', 'and']
# the ['be', 'as', 'and', 'of']
# and ['as', 'the', 'of']
# of ['the', 'and', 'at']
# at ['of', 'the', 'time']
# the ['at', 'time', 'the']
# time ['at', 'the', 'the', 'of']
# the ['the', 'time', 'of', 'that']
# of ['time', 'the', 'that']
# that ['the', 'of']
# as ['the', 'this']
# the ['as', 'this', 'he']
# this ['as', 'the', 'he', 'wrote']
# he ['the', 'this', 'wrote', 'that']
# wrote ['this', 'he', 'that']
# that ['he', 'wrote']
# was ['all', 'his']
# all ['was', 'his', 'he']
# his ['was', 'all', 'he', 'for']
# he ['all', 'his', 'for', 'the']
# for ['his', 'he', 'the', 'of']
# the ['he', 'for', 'of', 'a']
# of ['for', 'the', 'a', 'his']
# a ['the', 'of', 'his', 'his']
# his ['of', 'a', 'his', 'was']
# his ['a', 'his', 'was', 'by']
# was ['his', 'his', 'by', 'his']
# by ['his', 'was', 'his', 'to']
# his ['was', 'by', 'to', 'by']
# to ['by', 'his', 'by', 'his']
# by ['his', 'to', 'his', 'to']
# his ['to', 'by', 'to', 'the']
# to ['by', 'his', 'the', 'his']
# the ['his', 'to', 'his', 'for']
# his ['to', 'the', 'for', 'the']
# for ['the', 'his', 'the', 'to']
# the ['his', 'for', 'to', 'his']
# to ['for', 'the', 'his', 'by']
# his ['the', 'to', 'by', 'his']
# by ['to', 'his', 'his', 'the']
# his ['his', 'by', 'the', 'of']
# the ['by', 'his', 'of', 'the']
# of ['his', 'the', 'the', 's']
# the ['the', 'of', 's', 'of']
# s ['of', 'the', 'of']
# of ['the', 's']
# s ['to', 'the']
# to ['s', 'the', 'and']
# the ['s', 'to', 'and', 'for']
# and ['to', 'the', 'for', 'the']
# for ['the', 'and', 'the', 'have']
# the ['and', 'for', 'have', 'been']
# have ['for', 'the', 'been', 'as']
# been ['the', 'have', 'as', 'and']
# as ['have', 'been', 'and', 'and']
# and ['been', 'as', 'and', 'he']
# and ['as', 'and', 'he', 'been']
# he ['and', 'and', 'been', 'for']
# been ['and', 'he', 'for', 'his']
# for ['he', 'been', 'his', 'of']
# his ['been', 'for', 'of', 's']

# %%
test_try
# Out:
# [['is', ['an', 'television']],
#  ['an', ['is', 'television', 'and']],
#  ['television', ['is', 'an', 'and']],
#  ['and', ['an', 'television', 'he']],
#  ['he', ['and', 'had', 'a']],
#  ['had', ['he', 'a', 'role']],
#  ['a', ['he', 'had', 'role', 'on']],
#  ['role', ['had', 'a', 'on', 'the']],
#  ['on', ['a', 'role', 'the', 'television']],
#  ['the', ['role', 'on', 'television', 'series']],
#  ['television', ['on', 'the', 'series', 'the']],
#  ['series', ['the', 'television', 'the', 'in']],
#  ['the', ['television', 'series', 'in', 'this']],
#  ['in', ['series', 'the', 'this', 'was']],
#  ['this', ['the', 'in', 'was', 'by']],
#  ['was', ['in', 'this', 'by', 'a']],
#  ['by', ['this', 'was', 'a', 'role']],
#  ['a', ['was', 'by', 'role', 'in']],
#  ['role', ['by', 'a', 'in', 'the']],
#  ['in', ['a', 'role', 'the', 'by']],
#  ['the', ['role', 'in', 'by', 'which']],
#  ['by', ['in', 'the', 'which', 'was']],
#  ['which', ['the', 'by', 'was', 'in']],
#  ['was', ['by', 'which', 'in', 'at']],
#  ['in', ['which', 'was', 'at', 'the']],
#  ['at', ['was', 'in', 'the']],
#  ['the', ['in', 'at', 'he']],
#  ['he', ['the', 'had', 'a']],
#  ['had', ['he', 'a', 'role']],
#  ['a', ['he', 'had', 'role', 'in']],
#  ['role', ['had', 'a', 'in', 'the']],
#  ['in', ['a', 'role', 'the', 'television']],
#  ['the', ['role', 'in', 'television', 'series']],
#  ['television', ['in', 'the', 'series', 'in']],
#  ['series', ['the', 'television', 'in', 'in']],
#  ['in', ['television', 'series', 'in']],
#  ['in', ['series', 'in', 'a']],
#  ['a', ['in', 'role', 'as']],
#  ['role', ['a', 'as', 'in']],
#  ['as', ['a', 'role', 'in', 'the']],
#  ['in', ['role', 'as', 'the', 's']],
#  ['the', ['as', 'in', 's', 'of']],
#  ['s', ['in', 'the', 'of', 'the']],
#  ['of', ['the', 's', 'the', 'television']],
#  ['the', ['s', 'of', 'television', 'series']],
#  ['television', ['of', 'the', 'series', 'the']],
#  ['series', ['the', 'television', 'the', 'he']],
#  ['the', ['television', 'series', 'he']],
#  ['he', ['series', 'the', 'and']],
#  ['and', ['he', 'he', 'was']],
#  ['he', ['and', 'was', 'in']],
#  ['was', ['and', 'he', 'in', 'the']],
#  ['in', ['he', 'was', 'the']],
#  ['the', ['was', 'in', 'of']],
#  ['of', ['the', 'the', 'which']],
#  ['the', ['of', 'which', 'was']],
#  ['which', ['of', 'the', 'was', 'at']],
#  ['was', ['the', 'which', 'at', 'the']],
#  ['at', ['which', 'was', 'the']],
#  ['the', ['was', 'at', 'in']],
#  ['in', ['the', 'and', 'the']],
#  ['and', ['in', 'the', 'in']],
#  ['the', ['in', 'and', 'in', 'he']],
#  ['in', ['and', 'the', 'he', 'was']],
#  ['he', ['the', 'in', 'was', 'by']],
#  ['was', ['in', 'he', 'by', 'and']],
#  ['by', ['he', 'was', 'and']],
#  ['and', ['was', 'by', 'and']],
#  ['and', ['and', 'in']],
#  ['in', ['and']],
#  ['in', ['the', 'by']],
#  ['the', ['in', 'by', 'he']],
#  ['by', ['in', 'the', 'he', 'on']],
#  ['he', ['the', 'by', 'on', 'a']],
#  ['on', ['by', 'he', 'a', 'of']],
#  ['a', ['he', 'on', 'of', 'the']],
#  ['of', ['on', 'a', 'the', 'television']],
#  ['the', ['a', 'of', 'television', 'series']],
#  ['television', ['of', 'the', 'series', 'by']],
#  ['series', ['the', 'television', 'by', 'a']],
#  ['by', ['television', 'series', 'a', 'role']],
#  ['a', ['series', 'by', 'role', 'in']],
#  ['role', ['by', 'a', 'in', 'the']],
#  ['in', ['a', 'role', 'the']],
#  ['the', ['role', 'in', 'of']],
#  ['of', ['the', 'to', 'by']],
#  ['to', ['of', 'by', 'to']],
#  ['by', ['of', 'to', 'to', 'was']],
#  ['to', ['to', 'by', 'was', 'at']],
#  ['was', ['by', 'to', 'at']],
#  ['at', ['to', 'was', 'in']],
#  ['in', ['at', 'the', 'of']],
#  ['the', ['in', 'of', 'and']],
#  ['of', ['in', 'the', 'and']],
#  ['and', ['the', 'of']],
#  ['in', ['two', 'in']],
#  ['two', ['in', 'in', 'by']],
#  ['in', ['in', 'two', 'by', 'and']],
#  ['by', ['two', 'in', 'and', 'by']],
#  ['and', ['in', 'by', 'by', 'in']],
#  ['by', ['by', 'and', 'in']],
#  ['in', ['and', 'by', 'a']],
#  ['a', ['in', 'on', 'a']],
#  ['on', ['a', 'a', 'two']],
#  ['a', ['a', 'on', 'two', 'of']],
#  ['two', ['on', 'a', 'of', 'the']],
#  ['of', ['a', 'two', 'the', 'television']],
#  ['the', ['two', 'of', 'television', 'series']],
#  ['television', ['of', 'the', 'series', 'the']],
#  ['series', ['the', 'television', 'the', 'by']],
#  ['the', ['television', 'series', 'by', 'an']],
#  ['by', ['series', 'the', 'an', 'on']],
#  ['an', ['the', 'by', 'on', 'the']],
#  ['on', ['by', 'an', 'the', 'television']],
#  ['the', ['an', 'on', 'television', 'series']],
#  ['television', ['on', 'the', 'series', 'in']],
#  ['series', ['the', 'television', 'in', 'he']],
#  ['in', ['television', 'series', 'he', 'had']],
#  ['he', ['series', 'in', 'had', 'a']],
#  ['had', ['in', 'he', 'a', 'role']],
#  ['a', ['he', 'had', 'role', 'in']],
#  ['role', ['had', 'a', 'in', 'of']],
#  ['in', ['a', 'role', 'of', 'the']],
#  ['of', ['role', 'in', 'the', 'television']],
#  ['the', ['in', 'of', 'television', 'series']],
#  ['television', ['of', 'the', 'series', 'in']],
#  ['series', ['the', 'television', 'in', 'as']],
#  ['in', ['television', 'series', 'as']],
#  ['as', ['series', 'in']],
#  ['in', ['the', 'by']],
#  ['the', ['in', 'by', 'in']],
#  ['by', ['in', 'the', 'in']],
#  ['in', ['the', 'by', 'had']],
#  ['had', ['in', 'a', 'role']],
#  ['a', ['had', 'role', 'on']],
#  ['role', ['had', 'a', 'on', 'the']],
#  ['on', ['a', 'role', 'the', 'television']],
#  ['the', ['role', 'on', 'television', 'series']],
#  ['television', ['on', 'the', 'series', 'the']],
#  ['series', ['the', 'television', 'the', 'he']],
#  ['the', ['television', 'series', 'he', 'in']],
#  ['he', ['series', 'the', 'in', 'the']],
#  ['in', ['the', 'he', 'the', 'in']],
#  ['the', ['he', 'in', 'in']],
#  ['in', ['in', 'the']],
#  ['as', ['in', 'the']],
#  ['in', ['as', 'the', 'by']],
#  ['the', ['as', 'in', 'by', 'which']],
#  ['by', ['in', 'the', 'which', 'was']],
#  ['which', ['the', 'by', 'was', 'in']],
#  ['was', ['by', 'which', 'in', 'at']],
#  ['in', ['which', 'was', 'at', 'the']],
#  ['at', ['was', 'in', 'the']],
#  ['the', ['in', 'at', 'a']],
#  ['a', ['the', 'of']],
#  ['of', ['a', 's']],
#  ['s', ['of', 'in', 'the']],
#  ['in', ['s', 'the', 'on']],
#  ['the', ['s', 'in', 'on', 'as']],
#  ['on', ['in', 'the', 'as', 'in']],
#  ['as', ['the', 'on', 'in', 'the']],
#  ['in', ['on', 'as', 'the', 'role']],
#  ['the', ['as', 'in', 'role', 'and']],
#  ['role', ['in', 'the', 'and', 'he']],
#  ['and', ['the', 'role', 'he', 'in']],
#  ['he', ['role', 'and', 'in', 'the']],
#  ['in', ['and', 'he', 'the', 'and']],
#  ['the', ['he', 'in', 'and', 'he']],
#  ['and', ['in', 'the', 'he', 'in']],
#  ['he', ['the', 'and', 'in', 'the']],
#  ['in', ['and', 'he', 'the', 'television']],
#  ['the', ['he', 'in', 'television', 'series']],
#  ['television', ['in', 'the', 'series', 'in']],
#  ['series', ['the', 'television', 'in', 'as']],
#  ['in', ['television', 'series', 'as', 'in']],
#  ['as', ['series', 'in', 'in', 'the']],
#  ['in', ['in', 'as', 'the', 'and']],
#  ['the', ['as', 'in', 'and', 'had']],
#  ['and', ['in', 'the', 'had', 'a']],
#  ['had', ['the', 'and', 'a', 'role']],
#  ['a', ['and', 'had', 'role', 'as']],
#  ['role', ['had', 'a', 'as', 'a']],
#  ['as', ['a', 'role', 'a', 'on']],
#  ['a', ['role', 'as', 'on', 'the']],
#  ['on', ['as', 'a', 'the', 'he']],
#  ['the', ['a', 'on', 'he', 'had']],
#  ['he', ['on', 'the', 'had', 'a']],
#  ['had', ['the', 'he', 'a', 'role']],
#  ['a', ['he', 'had', 'role', 'in']],
#  ['role', ['had', 'a', 'in', 'on']],
#  ['in', ['a', 'role', 'on', 'two']],
#  ['on', ['role', 'in', 'two', 'of']],
#  ['two', ['in', 'on', 'of', 'the']],
#  ['of', ['on', 'two', 'the', 'as']],
#  ['the', ['two', 'of', 'as', 'in']],
#  ['as', ['of', 'the', 'in']],
#  ['in', ['the', 'as', 'a']],
#  ['a', ['in', 'role', 'as']],
#  ['role', ['a', 'as', 'in']],
#  ['as', ['a', 'role', 'in', 'the']],
#  ['in', ['role', 'as', 'the', 's']],
#  ['the', ['as', 'in', 's', 'of']],
#  ['s', ['in', 'the', 'of', 'the']],
#  ['of', ['the', 's', 'the', 'television']],
#  ['the', ['s', 'of', 'television', 'series']],
#  ['television', ['of', 'the', 'series', 'the']],
#  ['series', ['the', 'television', 'the', 'he']],
#  ['the', ['television', 'series', 'he']],
#  ['he', ['series', 'the', 'and']],
#  ['and', ['he']],
#  ['as', ['in', 'the']],
#  ['in', ['as', 'the']],
#  ['the', ['as', 'in', 'of']],
#  ['of', ['the', 'the', 'it']],
#  ['the', ['of', 'it', 'was']],
#  ['it', ['of', 'the', 'was', 'at']],
#  ['was', ['the', 'it', 'at', 'the']],
#  ['at', ['it', 'was', 'the']],
#  ['the', ['was', 'at', 'in']],
#  ['in', ['the', 'and', 'the']],
#  ['and', ['in', 'the', 'in']],
#  ['the', ['in', 'and', 'in', 'he']],
#  ['in', ['and', 'the', 'he', 'was']],
#  ['he', ['the', 'in', 'was', 'by']],
#  ['was', ['in', 'he', 'by', 'and']],
#  ['by', ['he', 'was', 'and']],
#  ['and', ['was', 'by', 'and']],
#  ['and', ['and', 'a']],
#  ['a', ['and', 'in', 'the']],
#  ['in', ['a', 'the', 'the']],
#  ['the', ['a', 'in', 'the', 'is']],
#  ['the', ['in', 'the', 'is', 'with']],
#  ['is', ['the', 'the', 'with', 'from']],
#  ['with', ['the', 'is', 'from', 'from']],
#  ['from', ['is', 'with', 'from', 'his']],
#  ['from', ['with', 'from', 'his', 'as']],
#  ['his', ['from', 'from', 'as', 's']],
#  ['as', ['from', 'his', 's']],
#  ['s', ['his', 'as', 'and']],
#  ['and', ['s', 'the', 'and']],
#  ['the', ['and', 'and']],
#  ['and', ['and', 'the', 'the']],
#  ['the', ['and', 'in']],
#  ['in', ['the']],
#  ['in', ['the', 'by']],
#  ['the', ['in', 'by', 'the']],
#  ['by', ['in', 'the', 'the', 'was']],
#  ['the', ['the', 'by', 'was', 'of']],
#  ['was', ['by', 'the', 'of', 'a']],
#  ['of', ['the', 'was', 'a', 'series']],
#  ['a', ['was', 'of', 'series', 'which']],
#  ['series', ['of', 'a', 'which', 'in']],
#  ['which', ['a', 'series', 'in', 'a']],
#  ['in', ['series', 'which', 'a']],
#  ['a', ['which', 'in', 'as']],
#  ['as', ['a', 'one', 'of']],
#  ['one', ['as', 'of', 'his']],
#  ['of', ['as', 'one', 'his', 'with']],
#  ['his', ['one', 'of', 'with', 'a']],
#  ['with', ['of', 'his', 'a']],
#  ['a', ['his', 'with', 'who']],
#  ['who', ['a', 'was', 'in']],
#  ['was', ['who', 'in', 'the']],
#  ['in', ['who', 'was', 'the', 'of']],
#  ['the', ['was', 'in', 'of', 'and']],
#  ['of', ['in', 'the', 'and', 'at']],
#  ['and', ['the', 'of', 'at', 'the']],
#  ['at', ['of', 'and', 'the', 'he']],
#  ['the', ['and', 'at', 'he', 'in']],
#  ['he', ['at', 'the', 'in', 'he']],
#  ['in', ['the', 'he', 'he', 'on']],
#  ['he', ['he', 'in', 'on', 'the']],
#  ['on', ['in', 'he', 'the', 'of']],
#  ['the', ['he', 'on', 'of', 'the']],
#  ['of', ['on', 'the', 'the', 'television']],
#  ['the', ['the', 'of', 'television', 'series']],
#  ['television', ['of', 'the', 'series']],
#  ['series', ['the', 'television']],
#  ['as', ['in', 'the']],
#  ['in', ['as', 'the', 'of']],
#  ['the', ['as', 'in', 'of', 'to']],
#  ['of', ['in', 'the', 'to', 'by']],
#  ['to', ['the', 'of', 'by', 'to']],
#  ['by', ['of', 'to', 'to', 'was']],
#  ['to', ['to', 'by', 'was', 'at']],
#  ['was', ['by', 'to', 'at']],
#  ['at', ['to', 'was', 'in']],
#  ['in', ['at', 'the', 'of']],
#  ['the', ['in', 'of', 'and']],
#  ['of', ['in', 'the', 'and', 'in']],
#  ['and', ['the', 'of', 'in', 'a']],
#  ['in', ['of', 'and', 'a', 'of']],
#  ['a', ['and', 'in', 'of', 'the']],
#  ['of', ['in', 'a', 'the', 'for']],
#  ['the', ['a', 'of', 'for', 'the']],
#  ['for', ['of', 'the', 'the']],
#  ['the', ['the', 'for']],
#  ['a', ['to', 'the']],
#  ['to', ['a', 'the', 'as']],
#  ['the', ['a', 'to', 'as']],
#  ['as', ['to', 'the']],
#  ['in', ['two', 'in']],
#  ['two', ['in', 'in', 'by']],
#  ['in', ['in', 'two', 'by', 'and']],
#  ['by', ['two', 'in', 'and', 'by']],
#  ['and', ['in', 'by', 'by']],
#  ['by', ['by', 'and', 'a']],
#  ['a', ['by', 'in', 'who']],
#  ['in', ['a', 'who', 'with']],
#  ['who', ['a', 'in', 'with', 'as']],
#  ['with', ['in', 'who', 'as', 'the']],
#  ['as', ['who', 'with', 'the', 'who']],
#  ['the', ['with', 'as', 'who', 'it']],
#  ['who', ['as', 'the', 'it', 'with']],
#  ['it', ['the', 'who', 'with']],
#  ['with', ['who', 'it']],
#  ['on', ['a', 'two']],
#  ['a', ['on', 'two', 'in']],
#  ['two', ['on', 'a', 'in', 'of']],
#  ['in', ['a', 'two', 'of', 'the']],
#  ['of', ['two', 'in', 'the', 'television']],
#  ['the', ['in', 'of', 'television', 'series']],
#  ['television', ['of', 'the', 'series', 'the']],
#  ['series', ['the', 'television', 'the', 'as']],
#  ['the', ['television', 'series', 'as', 'he']],
#  ['as', ['series', 'the', 'he', 'on']],
#  ['he', ['the', 'as', 'on', 'the']],
#  ['on', ['as', 'he', 'the', 'television']],
#  ['the', ['he', 'on', 'television', 'series']],
#  ['television', ['on', 'the', 'series', 'as']],
#  ['series', ['the', 'television', 'as', 'in']],
#  ['as', ['television', 'series', 'in', 'he']],
#  ['in', ['series', 'as', 'he', 'had']],
#  ['he', ['as', 'in', 'had', 'a']],
#  ['had', ['in', 'he', 'a', 'role']],
#  ['a', ['he', 'had', 'role', 'in']],
#  ['role', ['had', 'a', 'in', 'of']],
#  ['in', ['a', 'role', 'of', 'the']],
#  ['of', ['role', 'in', 'the', 'television']],
#  ['the', ['in', 'of', 'television', 'series']],
#  ['television', ['of', 'the', 'series', 'in']],
#  ['series', ['the', 'television', 'in', 'as']],
#  ['in', ['television', 'series', 'as', 'he']],
#  ['as', ['series', 'in', 'he', 'an']],
#  ['he', ['in', 'as', 'an', 'for']],
#  ['an', ['as', 'he', 'for', 'a']],
#  ['for', ['he', 'an', 'a', 'he']],
#  ['a', ['an', 'for', 'he', 'on']],
#  ['he', ['for', 'a', 'on', 'the']],
#  ['on', ['a', 'he', 'the', 'in']],
#  ['the', ['he', 'on', 'in', 'a']],
#  ['in', ['on', 'the', 'a', 'on']],
#  ['a', ['the', 'in', 'on', 'television']],
#  ['on', ['in', 'a', 'television', 'a']],
#  ['television', ['a', 'on', 'a', 'is']],
#  ['a', ['on', 'television', 'is', 'a']],
#  ['is', ['television', 'a', 'a', 'is']],
#  ['a', ['a', 'is', 'is', 'but']],
#  ['is', ['is', 'a', 'but', 'are']],
#  ['but', ['a', 'is', 'are', 'on']],
#  ['are', ['is', 'but', 'on', 'who']],
#  ['on', ['but', 'are', 'who', 'are']],
#  ['who', ['are', 'on', 'are', 'at']],
#  ['are', ['on', 'who', 'at', 'and']],
#  ['at', ['who', 'are', 'and', 'the']],
#  ['and', ['are', 'at', 'the', 'to']],
#  ['the', ['at', 'and', 'to', 'and']],
#  ['to', ['and', 'the', 'and']],
#  ['and', ['the', 'to']],
#  ['in', ['the', 'by']],
#  ['the', ['in', 'by', 'television']],
#  ['by', ['in', 'the', 'television']],
#  ['television', ['the', 'by']],
#  ['was', ['a']],
#  ['a', ['was']],
#  ['of', ['the', 'with']],
#  ['the', ['of', 'with', 'he']],
#  ['with', ['of', 'the', 'he', 'is']],
#  ['he', ['the', 'with', 'is', 'the']],
#  ['is', ['with', 'he', 'the', 'of']],
#  ['the', ['he', 'is', 'of', 'the']],
#  ['of', ['is', 'the', 'the']],
#  ['the', ['the', 'of', 'his']],
#  ['his', ['the', 'was', 'to']],
#  ['was', ['his', 'to', 'his']],
#  ['to', ['his', 'was', 'his', 'as']],
#  ['his', ['was', 'to', 'as', 'a']],
#  ['as', ['to', 'his', 'a', 'but']],
#  ['a', ['his', 'as', 'but', 'he']],
#  ['but', ['as', 'a', 'he', 'to']],
#  ['he', ['a', 'but', 'to', 'the']],
#  ['to', ['but', 'he', 'the', 'his']],
#  ['the', ['he', 'to', 'his', 'life']],
#  ['his', ['to', 'the', 'life', 'the']],
#  ['life', ['the', 'his', 'the', 'was']],
#  ['the', ['his', 'life', 'was', 'by']],
#  ['was', ['life', 'the', 'by', 'the']],
#  ['by', ['the', 'was', 'the', 'an']],
#  ['the', ['was', 'by', 'an', 'of']],
#  ['an', ['by', 'the', 'of', 'and']],
#  ['of', ['the', 'an', 'and', 'his']],
#  ['and', ['an', 'of', 'his', 'years']],
#  ['his', ['of', 'and', 'years', 'a']],
#  ['years', ['and', 'his', 'a', 'time']],
#  ['a', ['his', 'years', 'time', 'of']],
#  ['time', ['years', 'a', 'of', 'he']],
#  ['of', ['a', 'time', 'he', 'was']],
#  ['he', ['time', 'of', 'was', 'to']],
#  ['was', ['of', 'he', 'to', 'his']],
#  ['to', ['he', 'was', 'his', 'works']],
#  ['his', ['was', 'to', 'works', 'to']],
#  ['works', ['to', 'his', 'to', 'be']],
#  ['to', ['his', 'works', 'be', 'in']],
#  ['be', ['works', 'to', 'in']],
#  ['in', ['to', 'be', 'and']],
#  ['and', ['in', 'of', 'his']],
#  ['of', ['and', 'his']],
#  ['his', ['and', 'of', 'have']],
#  ['have', ['his', 'been', 'the']],
#  ['been', ['have', 'the', 'he']],
#  ['the', ['have', 'been', 'he', 'been']],
#  ['he', ['been', 'the', 'been', 'the']],
#  ['been', ['the', 'he', 'the']],
#  ['the', ['he', 'been', 'and']],
#  ['and', ['the', 'the']],
#  ['the', ['and', 'by']],
#  ['by', ['the', 'the']],
#  ['the', ['by', 'of', 'his']],
#  ['of', ['the', 'his', 'to']],
#  ['his', ['the', 'of', 'to', 'be']],
#  ['to', ['of', 'his', 'be', 'to']],
#  ['be', ['his', 'to', 'to', 'as']],
#  ['to', ['to', 'be', 'as', 'the']],
#  ['as', ['be', 'to', 'the']],
#  ['the', ['to', 'as', 'or']],
#  ['or', ['the', 'life']],
#  ['life', ['or', 'the']],
#  ['the', ['life', 'life', 'of']],
#  ['life', ['the', 'of', 'the']],
#  ['of', ['the', 'life', 'the', 'a']],
#  ['the', ['life', 'of', 'a', 'a']],
#  ['a', ['of', 'the', 'a', 'which']],
#  ['a', ['the', 'a', 'which', 'to']],
#  ['which', ['a', 'a', 'to', 'the']],
#  ['to', ['a', 'which', 'the', 'that']],
#  ['the', ['which', 'to', 'that']],
#  ['that', ['to', 'the', 'and']],
#  ['and', ['that', 'of']],
#  ['of', ['and']],
#  ['s', ['and']],
#  ['and', ['s', 'this', 'is']],
#  ['this', ['and', 'is', 'by']],
#  ['is', ['and', 'this', 'by', 'the']],
#  ['by', ['this', 'is', 'the']],
#  ['the', ['is', 'by', 'is']],
#  ['is', ['the', 'that']],
#  ['that', ['is']],
#  ['are', ['that', 'be']],
#  ['that', ['are', 'be', 'but']],
#  ['be', ['are', 'that', 'but', 'which']],
#  ['but', ['that', 'be', 'which', 'an']],
#  ['which', ['be', 'but', 'an', 'be']],
#  ['an', ['but', 'which', 'be', 'to']],
#  ['be', ['which', 'an', 'to', 'for']],
#  ['to', ['an', 'be', 'for', 'the']],
#  ['for', ['be', 'to', 'the', 'the']],
#  ['the', ['to', 'for', 'the', 'time']],
#  ['the', ['for', 'the', 'time', 'the']],
#  ['time', ['the', 'the', 'the', 'and']],
#  ['the', ['the', 'time', 'and', 'the']],
#  ['and', ['time', 'the', 'the', 'in']],
#  ['the', ['the', 'and', 'in', 'the']],
#  ['in', ['and', 'the', 'the', 'the']],
#  ['the', ['the', 'in', 'the', 'are']],
#  ['the', ['in', 'the', 'are', 'to']],
#  ['are', ['the', 'the', 'to', 'it']],
#  ['to', ['the', 'are', 'it', 'and']],
#  ['it', ['are', 'to', 'and', 'the']],
#  ['and', ['to', 'it', 'the', 'be']],
#  ['the', ['it', 'and', 'be', 'that']],
#  ['be', ['and', 'the', 'that', 'the']],
#  ['that', ['the', 'be', 'the', 'or']],
#  ['the', ['be', 'that', 'or', 'to']],
#  ['or', ['that', 'the', 'to', 'it']],
#  ['to', ['the', 'or', 'it', 'a']],
#  ['it', ['or', 'to', 'a', 'to']],
#  ['a', ['to', 'it', 'to']],
#  ['to', ['it', 'a']],
#  ['that', ['the', 'of']],
#  ['the', ['that', 'of', 'the']],
#  ['of', ['that', 'the', 'the']],
#  ['the', ['the', 'of', 's']],
#  ['s', ['the', 'of', 'his']],
#  ['of', ['s', 'his', 'life']],
#  ['his', ['s', 'of', 'life', 'the']],
#  ['life', ['of', 'his', 'the', 'for']],
#  ['the', ['his', 'life', 'for', 'years']],
#  ['for', ['life', 'the', 'years', 'of']],
#  ['years', ['the', 'for', 'of', 'is']],
#  ['of', ['for', 'years', 'is', 'of']],
#  ['is', ['years', 'of', 'of']],
#  ['of', ['of', 'is']],
#  ['s', ['life', 'from']],
#  ['life', ['s', 'from', 'his']],
#  ['from', ['s', 'life', 'his']],
#  ['his', ['life', 'from', 'his']],
#  ['his', ['his', 'was']],
#  ['was', ['his', 'a']],
#  ['a', ['was', 'and']],
#  ['and', ['a', 'the']],
#  ['the', ['and', 'of']],
#  ['of', ['the']],
#  ['was', ['in', 'the']],
#  ['in', ['was', 'the', 'is']],
#  ['the', ['was', 'in', 'is', 'that']],
#  ['is', ['in', 'the', 'that', 'it']],
#  ['that', ['the', 'is', 'it', 'was']],
#  ['it', ['is', 'that', 'was', 'is']],
#  ['was', ['that', 'it', 'is', 'a']],
#  ['is', ['it', 'was', 'a', 'in']],
#  ['a', ['was', 'is', 'in', 'life']],
#  ['in', ['is', 'a', 'life', 'he']],
#  ['life', ['a', 'in', 'he', 'to']],
#  ['he', ['in', 'life', 'to', 'to']],
#  ['to', ['life', 'he', 'to', 'the']],
#  ['to', ['he', 'to', 'the', 'of']],
#  ['the', ['to', 'to', 'of', 'an']],
#  ['of', ['to', 'the', 'an', 'of']],
#  ['an', ['the', 'of', 'of', 'the']],
#  ['of', ['of', 'an', 'the']],
#  ['the', ['an', 'of']],
#  ['s', ['he', 'was']],
#  ['he', ['s', 'was', 'and']],
#  ['was', ['s', 'he', 'and', 'he']],
#  ['and', ['he', 'was', 'he', 'was']],
#  ['he', ['was', 'and', 'was', 'by']],
#  ['was', ['and', 'he', 'by', 'his']],
#  ['by', ['he', 'was', 'his', 'he']],
#  ['his', ['was', 'by', 'he', 'had']],
#  ['he', ['by', 'his', 'had', 'an']],
#  ['had', ['his', 'he', 'an', 'who']],
#  ['an', ['he', 'had', 'who', 'he']],
#  ['who', ['had', 'an', 'he', 'had']],
#  ['he', ['an', 'who', 'had', 'and']],
#  ['had', ['who', 'he', 'and', 'one']],
#  ['and', ['he', 'had', 'one', 'to']],
#  ['one', ['had', 'and', 'to', 'he']],
#  ['to', ['and', 'one', 'he', 'in']],
#  ['he', ['one', 'to', 'in', 'his']],
#  ['in', ['to', 'he', 'his']],
#  ['his', ['he', 'in', 'he']],
#  ['he', ['his', 'his', 'the']],
#  ['his', ['he', 'the', 'of']],
#  ['the', ['he', 'his', 'of', 'a']],
#  ['of', ['his', 'the', 'a', 'his']],
#  ['a', ['the', 'of', 'his', 'was']],
#  ['his', ['of', 'a', 'was', 'on']],
#  ['was', ['a', 'his', 'on', 'the']],
#  ['on', ['his', 'was', 'the', 'of']],
#  ['the', ['was', 'on', 'of', 'a']],
#  ['of', ['on', 'the', 'a', 'and']],
#  ['a', ['the', 'of', 'and', 'of']],
#  ['and', ['of', 'a', 'of', 'the']],
#  ['of', ['a', 'and', 'the', 'of']],
#  ['the', ['and', 'of', 'of', 'and']],
#  ['of', ['of', 'the', 'and', 'he']],
#  ['and', ['the', 'of', 'he', 'to']],
#  ['he', ['of', 'and', 'to', 'have']],
#  ['to', ['and', 'he', 'have']],
#  ['have', ['he', 'to', 'by']],
#  ['by', ['have', 'his', 'but']],
#  ['his', ['by', 'but', 'have']],
#  ['but', ['by', 'his', 'have', 'been']],
#  ['have', ['his', 'but', 'been', 'in']],
#  ['been', ['but', 'have', 'in', 'the']],
#  ['in', ['have', 'been', 'the', 's']],
#  ['the', ['been', 'in', 's', 'he']],
#  ['s', ['in', 'the', 'he', 'in']],
#  ['he', ['the', 's', 'in', 'the']],
#  ['in', ['s', 'he', 'the', 'his']],
#  ['the', ['he', 'in', 'his', 'a']],
#  ['his', ['in', 'the', 'a', 'is']],
#  ['a', ['the', 'his', 'is', 'to']],
#  ['is', ['his', 'a', 'to', 'from']],
#  ['to', ['a', 'is', 'from', 'the']],
#  ['from', ['is', 'to', 'the', 'of']],
#  ['the', ['to', 'from', 'of', 'this']],
#  ['of', ['from', 'the', 'this', 'in']],
#  ['this', ['the', 'of', 'in', 'that']],
#  ['in', ['of', 'this', 'that', 'he']],
#  ['that', ['this', 'in', 'he', 'the']],
#  ['he', ['in', 'that', 'the', 'in']],
#  ['the', ['that', 'he', 'in', 'an']],
#  ['in', ['he', 'the', 'an', 'he']],
#  ['an', ['the', 'in', 'he', 'to']],
#  ['he', ['in', 'an', 'to', 'his']],
#  ['to', ['an', 'he', 'his', 'and']],
#  ['his', ['he', 'to', 'and', 'that']],
#  ['and', ['to', 'his', 'that', 'of']],
#  ['that', ['his', 'and', 'of', 'of']],
#  ['of', ['and', 'that', 'of', 'that']],
#  ['of', ['that', 'of', 'that', 'he']],
#  ['that', ['of', 'of', 'he', 'his']],
#  ['he', ['of', 'that', 'his', 'at']],
#  ['his', ['that', 'he', 'at', 'the']],
#  ['at', ['he', 'his', 'the', 'time']],
#  ['the', ['his', 'at', 'time', 'was']],
#  ['time', ['at', 'the', 'was', 'and']],
#  ['was', ['the', 'time', 'and', 'his']],
#  ['and', ['time', 'was', 'his', 'to']],
#  ['his', ['was', 'and', 'to', 'in']],
#  ['to', ['and', 'his', 'in', 'the']],
#  ['in', ['his', 'to', 'the', 'have']],
#  ['the', ['to', 'in', 'have', 'been']],
#  ['have', ['in', 'the', 'been', 'to']],
#  ['been', ['the', 'have', 'to', 'this']],
#  ['to', ['have', 'been', 'this', 'he']],
#  ['this', ['been', 'to', 'he', 'to']],
#  ['he', ['to', 'this', 'to', 'this']],
#  ['to', ['this', 'he', 'this', 'time']],
#  ['this', ['he', 'to', 'time', 'and']],
#  ['time', ['to', 'this', 'and', 'his']],
#  ['and', ['this', 'time', 'his']],
#  ['his', ['time', 'and']],
#  ['have', ['been', 'to']],
#  ['been', ['have', 'to', 'the']],
#  ['to', ['have', 'been', 'the', 'of']],
#  ['the', ['been', 'to', 'of', 'his']],
#  ['of', ['to', 'the', 'his', 's']],
#  ['his', ['the', 'of', 's', 'but']],
#  ['s', ['of', 'his', 'but', 'he']],
#  ['but', ['his', 's', 'he', 'is']],
#  ['he', ['s', 'but', 'is', 'to']],
#  ['is', ['but', 'he', 'to', 'have']],
#  ['to', ['he', 'is', 'have', 'the']],
#  ['have', ['is', 'to', 'the', 'in']],
#  ['the', ['to', 'have', 'in', 'of']],
#  ['in', ['have', 'the', 'of', 'one']],
#  ['of', ['the', 'in', 'one', 'of']],
#  ['one', ['in', 'of', 'of', 'his']],
#  ['of', ['of', 'one', 'his', 'he']],
#  ['his', ['one', 'of', 'he', 'the']],
#  ['he', ['of', 'his', 'the', 'years']],
#  ['the', ['his', 'he', 'years', 'in']],
#  ['years', ['he', 'the', 'in', 'the']],
#  ['in', ['the', 'years', 'the', 'his']],
#  ['the', ['years', 'in', 'his', 'in']],
#  ['his', ['in', 'the', 'in', 'in']],
#  ['in', ['the', 'his', 'in', 'the']],
#  ['in', ['his', 'in', 'the', 'of']],
#  ['the', ['in', 'in', 'of', 'he']],
#  ['of', ['in', 'the', 'he', 'for']],
#  ['he', ['the', 'of', 'for', 'the']],
#  ['for', ['of', 'he', 'the', 'time']],
#  ['the', ['he', 'for', 'time', 'and']],
#  ['time', ['for', 'the', 'and', 'the']],
#  ['and', ['the', 'time', 'the', 'two']],
#  ['the', ['time', 'and', 'two', 'a']],
#  ['two', ['and', 'the', 'a', 'this']],
#  ['a', ['the', 'two', 'this', 'as']],
#  ['this', ['two', 'a', 'as', 'the']],
#  ['as', ['a', 'this', 'the', 'in']],
#  ['the', ['this', 'as', 'in']],
#  ['in', ['as', 'the']],
#  ['s', ['it', 'a']],
#  ['it', ['s', 'a', 'of']],
#  ['a', ['s', 'it', 'of', 'the']],
#  ['of', ['it', 'a', 'the']],
#  ['the', ['a', 'of', 'life']],
#  ['life', ['the', 'to', 'which']],
#  ['to', ['life', 'which', 'he']],
#  ['which', ['life', 'to', 'he', 'was']],
#  ['he', ['to', 'which', 'was', 'his']],
#  ['was', ['which', 'he', 'his', 'in']],
#  ['his', ['he', 'was', 'in', 'the']],
#  ['in', ['was', 'his', 'the', 'the']],
#  ['the', ['his', 'in', 'the', 'was']],
#  ['the', ['in', 'the', 'was', 'one']],
#  ['was', ['the', 'the', 'one']],
#  ['one', ['the', 'was']],
#  ['was', ['by', 'years']],
#  ['by', ['was', 'years', 'the']],
#  ['years', ['was', 'by', 'the', 'was']],
#  ['the', ['by', 'years', 'was', 'a']],
#  ['was', ['years', 'the', 'a', 'have']],
#  ['a', ['the', 'was', 'have']],
#  ['have', ['was', 'a', 'to']],
#  ['to', ['have', 'or', 'from']],
#  ['or', ['to', 'from', 'the']],
#  ['from', ['to', 'or', 'the']],
#  ['the', ['or', 'from', 'but']],
#  ['but', ['the', 'one', 'in']],
#  ['one', ['but', 'in', 'the']],
#  ['in', ['but', 'one', 'the', 'in']],
#  ['the', ['one', 'in', 'in', 'in']],
#  ['in', ['in', 'the', 'in', 'he']],
#  ['in', ['the', 'in', 'he', 'to']],
#  ['he', ['in', 'in', 'to', 'the']],
#  ['to', ['in', 'he', 'the', 'in']],
#  ['the', ['he', 'to', 'in', 'an']],
#  ['in', ['to', 'the', 'an', 'to']],
#  ['an', ['the', 'in', 'to', 'his']],
#  ['to', ['in', 'an', 'his', 'he']],
#  ['his', ['an', 'to', 'he', 'the']],
#  ['he', ['to', 'his', 'the', 'a']],
#  ['the', ['his', 'he', 'a', 'time']],
#  ['a', ['he', 'the', 'time', 'the']],
#  ['time', ['the', 'a', 'the', 'but']],
#  ['the', ['a', 'time', 'but', 'all']],
#  ['but', ['time', 'the', 'all', 'the']],
#  ['all', ['the', 'but', 'the', 'by']],
#  ['the', ['but', 'all', 'by', 'the']],
#  ['by', ['all', 'the', 'the', 'in']],
#  ['the', ['the', 'by', 'in', 'to']],
#  ['in', ['by', 'the', 'to', 'the']],
#  ['to', ['the', 'in', 'the', 'of']],
#  ['the', ['in', 'to', 'of', 'he']],
#  ['of', ['to', 'the', 'he', 'the']],
#  ['he', ['the', 'of', 'the', 'the']],
#  ['the', ['of', 'he', 'the', 'in']],
#  ['the', ['he', 'the', 'in', 'and']],
#  ['in', ['the', 'the', 'and', 'in']],
#  ['and', ['the', 'in', 'in', 'he']],
#  ['in', ['in', 'and', 'he', 'and']],
#  ['he', ['and', 'in', 'and', 'by']],
#  ['and', ['in', 'he', 'by', 'the']],
#  ['by', ['he', 'and', 'the', 'had']],
#  ['the', ['and', 'by', 'had', 'had']],
#  ['had', ['by', 'the', 'had', 'and']],
#  ['had', ['the', 'had', 'and', 'two']],
#  ['and', ['had', 'had', 'two', 'but']],
#  ['two', ['had', 'and', 'but', 'one']],
#  ['but', ['and', 'two', 'one', 'of']],
#  ['one', ['two', 'but', 'of', 'the']],
#  ['of', ['but', 'one', 'the', 'in']],
#  ['the', ['one', 'of', 'in', 'in']],
#  ['in', ['of', 'the', 'in', 'from']],
#  ['in', ['the', 'in', 'from', 'he']],
#  ['from', ['in', 'in', 'he', 'to']],
#  ['he', ['in', 'from', 'to', 'have']],
#  ['to', ['from', 'he', 'have', 'the']],
#  ['have', ['he', 'to', 'the', 'of']],
#  ['the', ['to', 'have', 'of', 'a']],
#  ['of', ['have', 'the', 'a', 'series']],
#  ['a', ['the', 'of', 'series', 'of']],
#  ['series', ['of', 'a', 'of', 'which']],
#  ['of', ['a', 'series', 'which', 'for']],
#  ['which', ['series', 'of', 'for', 'the']],
#  ['for', ['of', 'which', 'the', 'of']],
#  ['the', ['which', 'for', 'of', 'his']],
#  ['of', ['for', 'the', 'his', 'life']],
#  ['his', ['the', 'of', 'life', 'it']],
#  ['life', ['of', 'his', 'it', 'was']],
#  ['it', ['his', 'life', 'was', 'in']],
#  ['was', ['life', 'it', 'in', 'that']],
#  ['in', ['it', 'was', 'that', 'that']],
#  ['that', ['was', 'in', 'that']],
#  ['that', ['in', 'that']],
#  ['was', ['to', 'his']],
#  ['to', ['was', 'his', 'to']],
#  ['his', ['was', 'to', 'to', 'the']],
#  ['to', ['to', 'his', 'the', 'of']],
#  ['the', ['his', 'to', 'of', 'a']],
#  ['of', ['to', 'the', 'a', 'by']],
#  ['a', ['the', 'of', 'by', 'in']],
#  ['by', ['of', 'a', 'in', 'the']],
#  ['in', ['a', 'by', 'the', 'in']],
#  ['the', ['by', 'in', 'in', 'he']],
#  ['in', ['in', 'the', 'he', 'an']],
#  ['he', ['the', 'in', 'an', 'as']],
#  ['an', ['in', 'he', 'as', 'of']],
#  ['as', ['he', 'an', 'of', 'the']],
#  ['of', ['an', 'as', 'the', 's']],
#  ['the', ['as', 'of', 's', 'of']],
#  ['s', ['of', 'the', 'of', 'the']],
#  ['of', ['the', 's', 'the', 's']],
#  ['the', ['s', 'of', 's', 'this']],
#  ['s', ['of', 'the', 'this', 'was']],
#  ['this', ['the', 's', 'was', 'a']],
#  ['was', ['s', 'this', 'a', 'in']],
#  ['a', ['this', 'was', 'in', 'it']],
#  ['in', ['was', 'a', 'it', 'have']],
#  ['it', ['a', 'in', 'have', 'been']],
#  ['have', ['in', 'it', 'been', 'at']],
#  ['been', ['it', 'have', 'at', 'the']],
#  ['at', ['have', 'been', 'the', 'of']],
#  ['the', ['been', 'at', 'of', 'an']],
#  ['of', ['at', 'the', 'an', 'he']],
#  ['an', ['the', 'of', 'he', 'had']],
#  ['he', ['of', 'an', 'had', 'the']],
#  ['had', ['an', 'he', 'the', 'was']],
#  ['the', ['he', 'had', 'was', 'by']],
#  ['was', ['had', 'the', 'by', 'the']],
#  ['by', ['the', 'was', 'the', 'an']],
#  ['the', ['was', 'by', 'an', 'in']],
#  ['an', ['by', 'the', 'in', 'and']],
#  ['in', ['the', 'an', 'and', 'was']],
#  ['and', ['an', 'in', 'was', 'for']],
#  ['was', ['in', 'and', 'for', 'years']],
#  ['for', ['and', 'was', 'years', 'it']],
#  ['years', ['was', 'for', 'it', 'to']],
#  ['it', ['for', 'years', 'to']],
#  ['to', ['years', 'it', 'the']],
#  ['the', ['to', 'of', 'but']],
#  ['of', ['the', 'but', 'years']],
#  ['but', ['the', 'of', 'years', 'the']],
#  ['years', ['of', 'but', 'the', 'the']],
#  ['the', ['but', 'years', 'the', 'been']],
#  ['the', ['years', 'the', 'been', 'or']],
#  ['been', ['the', 'the', 'or', 'this']],
#  ['or', ['the', 'been', 'this', 'time']],
#  ['this', ['been', 'or', 'time']],
#  ['time', ['or', 'this']],
#  ['a', ['life', 'by']],
#  ['life', ['a', 'by', 'and']],
#  ['by', ['a', 'life', 'and', 'this']],
#  ['and', ['life', 'by', 'this', 'of']],
#  ['this', ['by', 'and', 'of', 'was']],
#  ['of', ['and', 'this', 'was', 'the']],
#  ['was', ['this', 'of', 'the', 'of']],
#  ['the', ['of', 'was', 'of']],
#  ['of', ['was', 'the']],
#  ['as', ['a']],
#  ['a', ['as', 'that']],
#  ['that', ['a', 'he', 'the']],
#  ['he', ['that', 'the', 'of']],
#  ['the', ['that', 'he', 'of', 'his']],
#  ['of', ['he', 'the', 'his', 'and']],
#  ['his', ['the', 'of', 'and', 'he']],
#  ['and', ['of', 'his', 'he', 'and']],
#  ['he', ['his', 'and', 'and', 'he']],
#  ['and', ['and', 'he', 'he', 'for']],
#  ['he', ['he', 'and', 'for', 'or']],
#  ['for', ['and', 'he', 'or', 'from']],
#  ['or', ['he', 'for', 'from', 'the']],
#  ['from', ['for', 'or', 'the', 'of']],
#  ['the', ['or', 'from', 'of', 'the']],
#  ['of', ['from', 'the', 'the', 'of']],
#  ['the', ['the', 'of', 'of', 'his']],
#  ['of', ['of', 'the', 'his', 'he']],
#  ['his', ['the', 'of', 'he', 'of']],
#  ['he', ['of', 'his', 'of', 'the']],
#  ['of', ['his', 'he', 'the', 'of']],
#  ['the', ['he', 'of', 'of', 'his']],
#  ['of', ['of', 'the', 'his', 'he']],
#  ['his', ['the', 'of', 'he', 'to']],
#  ['he', ['of', 'his', 'to', 'the']],
#  ['to', ['his', 'he', 'the', 'of']],
#  ['the', ['he', 'to', 'of', 'in']],
#  ['of', ['to', 'the', 'in', 'his']],
#  ['in', ['the', 'of', 'his', 'of']],
#  ['his', ['of', 'in', 'of', 'his']],
#  ['of', ['in', 'his', 'his']],
#  ['his', ['his', 'of']],
#  ['wrote', ['on', 'have']],
#  ['on', ['wrote', 'have', 'the']],
#  ['have', ['wrote', 'on', 'the', 'be']],
#  ['the', ['on', 'have', 'be', 'by']],
#  ['be', ['have', 'the', 'by', 'the']],
#  ['by', ['the', 'be', 'the', 'in']],
#  ['the', ['be', 'by', 'in', 'was']],
#  ['in', ['by', 'the', 'was', 'to']],
#  ['was', ['the', 'in', 'to', 'the']],
#  ['to', ['in', 'was', 'the', 'and']],
#  ['the', ['was', 'to', 'and']],
#  ['and', ['to', 'the']],
#  ['who', ['had', 'been']],
#  ['had', ['who', 'been', 'from']],
#  ['been', ['who', 'had', 'from', 'the']],
#  ['from', ['had', 'been', 'the', 'his']],
#  ['the', ['been', 'from', 'his', 'to']],
#  ['his', ['from', 'the', 'to', 'a']],
#  ['to', ['the', 'his', 'a', 'of']],
#  ['a', ['his', 'to', 'of', 'and']],
#  ['of', ['to', 'a', 'and', 'to']],
#  ['and', ['a', 'of', 'to', 'the']],
#  ['to', ['of', 'and', 'the', 'of']],
#  ['the', ['and', 'to', 'of', 'the']],
#  ['of', ['to', 'the', 'the', 'but']],
#  ['the', ['the', 'of', 'but', 'he']],
#  ['but', ['of', 'the', 'he', 'was']],
#  ['he', ['the', 'but', 'was', 'by']],
#  ['was', ['but', 'he', 'by', 'the']],
#  ['by', ['he', 'was', 'the', 'and']],
#  ['the', ['was', 'by', 'and', 'to']],
#  ['and', ['by', 'the', 'to', 'an']],
#  ['to', ['the', 'and', 'an', 'in']],
#  ['an', ['and', 'to', 'in', 'the']],
#  ['in', ['to', 'an', 'the', 'his']],
#  ['the', ['an', 'in', 'his']],
#  ['his', ['in', 'the', 'was']],
#  ['was', ['his', 'this', 'time']],
#  ['this', ['was', 'time']],
#  ['time', ['was', 'this']],
#  ['is', ['to', 'have']],
#  ['to', ['is', 'have', 'he']],
#  ['have', ['is', 'to', 'he', 'from']],
#  ['he', ['to', 'have', 'from', 'an']],
#  ['from', ['have', 'he', 'an', 'the']],
#  ['an', ['he', 'from', 'the', 'and']],
#  ['the', ['from', 'an', 'and', 'was']],
#  ['and', ['an', 'the', 'was', 'he']],
#  ['was', ['the', 'and', 'he', 'the']],
#  ['he', ['and', 'was', 'the', 'in']],
#  ['the', ['was', 'he', 'in', 'this']],
#  ['in', ['he', 'the', 'this', 'to']],
#  ['this', ['the', 'in', 'to', 'the']],
#  ['to', ['in', 'this', 'the', 'but']],
#  ['the', ['this', 'to', 'but', 'was']],
#  ['but', ['to', 'the', 'was']],
#  ['was', ['the', 'but']],
#  ['s', ['to', 'to']],
#  ['to', ['s', 'to', 'of']],
#  ['to', ['s', 'to', 'of', 'it']],
#  ['of', ['to', 'to', 'it', 'he']],
#  ['it', ['to', 'of', 'he', 'for']],
#  ['he', ['of', 'it', 'for', 'by']],
#  ['for', ['it', 'he', 'by', 'the']],
#  ['by', ['he', 'for', 'the', 'of']],
#  ['the', ['for', 'by', 'of', 'his']],
#  ['of', ['by', 'the', 'his', 'and']],
#  ['his', ['the', 'of', 'and', 'on']],
#  ['and', ['of', 'his', 'on', 'a']],
#  ['on', ['his', 'and', 'a', 'he']],
#  ['a', ['and', 'on', 'he', 'was']],
#  ['he', ['on', 'a', 'was', 'but']],
#  ['was', ['a', 'he', 'but', 'was']],
#  ['but', ['he', 'was', 'was', 'in']],
#  ['was', ['was', 'but', 'in', 'he']],
#  ['in', ['but', 'was', 'he', 'was']],
#  ['he', ['was', 'in', 'was', 'to']],
#  ['was', ['in', 'he', 'to', 'his']],
#  ['to', ['he', 'was', 'his', 'in']],
#  ['his', ['was', 'to', 'in', 'but']],
#  ['in', ['to', 'his', 'but', 'he']],
#  ['but', ['his', 'in', 'he', 'the']],
#  ['he', ['in', 'but', 'the', 'and']],
#  ['the', ['but', 'he', 'and', 'on']],
#  ['and', ['he', 'the', 'on', 'he']],
#  ['on', ['the', 'and', 'he', 'to']],
#  ['he', ['and', 'on', 'to', 'an']],
#  ['to', ['on', 'he', 'an', 'with']],
#  ['an', ['he', 'to', 'with', 'the']],
#  ['with', ['to', 'an', 'the', 'by']],
#  ['the', ['an', 'with', 'by', 'his']],
#  ['by', ['with', 'the', 'his', 'to']],
#  ['his', ['the', 'by', 'to', 'be']],
#  ['to', ['by', 'his', 'be', 'and']],
#  ['be', ['his', 'to', 'and', 'in']],
#  ['and', ['to', 'be', 'in', 'the']],
#  ['in', ['be', 'and', 'the', 'of']],
#  ['the', ['and', 'in', 'of', 'he']],
#  ['of', ['in', 'the', 'he', 'was']],
#  ['he', ['the', 'of', 'was', 'to']],
#  ['was', ['of', 'he', 'to', 'a']],
#  ['to', ['he', 'was', 'a', 'as']],
#  ['a', ['was', 'to', 'as', 'of']],
#  ['as', ['to', 'a', 'of', 'in']],
#  ['of', ['a', 'as', 'in', 'the']],
#  ['in', ['as', 'of', 'the', 'was']],
#  ['the', ['of', 'in', 'was', 'to']],
#  ['was', ['in', 'the', 'to', 'his']],
#  ['to', ['the', 'was', 'his', 'in']],
#  ['his', ['was', 'to', 'in', 'one']],
#  ['in', ['to', 'his', 'one', 'he']],
#  ['one', ['his', 'in', 'he', 'wrote']],
#  ['he', ['in', 'one', 'wrote', 'to']],
#  ['wrote', ['one', 'he', 'to', 'in']],
#  ['to', ['he', 'wrote', 'in', 'the']],
#  ['in', ['wrote', 'to', 'the', 'to']],
#  ['the', ['to', 'in', 'to', 'on']],
#  ['to', ['in', 'the', 'on', 'he']],
#  ['on', ['the', 'to', 'he', 'on']],
#  ['he', ['to', 'on', 'on', 'in']],
#  ['on', ['on', 'he', 'in', 'the']],
#  ['in', ['he', 'on', 'the', 'of']],
#  ['the', ['on', 'in', 'of', 'this']],
#  ['of', ['in', 'the', 'this', 'been']],
#  ['this', ['the', 'of', 'been', 'to']],
#  ['been', ['of', 'this', 'to', 'but']],
#  ['to', ['this', 'been', 'but', 'that']],
#  ['but', ['been', 'to', 'that', 'is']],
#  ['that', ['to', 'but', 'is', 'a']],
#  ['is', ['but', 'that', 'a', 'he']],
#  ['a', ['that', 'is', 'he', 'in']],
#  ['he', ['is', 'a', 'in', 'he']],
#  ['in', ['a', 'he', 'he', 'wrote']],
#  ['he', ['he', 'in', 'wrote']],
#  ['wrote', ['in', 'he', 'in']],
#  ['in', ['wrote', 'he', 'in']],
#  ['he', ['in', 'in', 'he']],
#  ['in', ['in', 'he', 'he', 'on']],
#  ['he', ['he', 'in', 'on', 'for']],
#  ['on', ['in', 'he', 'for', 'he']],
#  ['for', ['he', 'on', 'he', 'was']],
#  ['he', ['on', 'for', 'was', 'by']],
#  ['was', ['for', 'he', 'by', 'and']],
#  ['by', ['he', 'was', 'and']],
#  ['and', ['was', 'by']],
#  ['in', ['for', 'of']],
#  ...]

# %%
avg_mrr = calculate_mrr_for_dataset(test_try, embedding_matrix, word_index)
print(f"Mean Reciprocal Rank for test data: {avg_mrr:.4f}")
# Out:
# ['is', ['an', 'television']]
# ['an', ['is', 'television', 'and']]
# ['television', ['is', 'an', 'and']]
# ['and', ['an', 'television', 'he']]
# ['he', ['and', 'had', 'a']]
# ['had', ['he', 'a', 'role']]
# ['a', ['he', 'had', 'role', 'on']]
# ['role', ['had', 'a', 'on', 'the']]
# ['on', ['a', 'role', 'the', 'television']]
# ['the', ['role', 'on', 'television', 'series']]
# ['television', ['on', 'the', 'series', 'the']]
# ['series', ['the', 'television', 'the', 'in']]
# ['the', ['television', 'series', 'in', 'this']]
# ['in', ['series', 'the', 'this', 'was']]
# ['this', ['the', 'in', 'was', 'by']]
# ['was', ['in', 'this', 'by', 'a']]
# ['by', ['this', 'was', 'a', 'role']]
# ['a', ['was', 'by', 'role', 'in']]
# ['role', ['by', 'a', 'in', 'the']]
# ['in', ['a', 'role', 'the', 'by']]
# ['the', ['role', 'in', 'by', 'which']]
# ['by', ['in', 'the', 'which', 'was']]
# ['which', ['the', 'by', 'was', 'in']]
# ['was', ['by', 'which', 'in', 'at']]
# ['in', ['which', 'was', 'at', 'the']]
# ['at', ['was', 'in', 'the']]
# ['the', ['in', 'at', 'he']]
# ['he', ['the', 'had', 'a']]
# ['had', ['he', 'a', 'role']]
# ['a', ['he', 'had', 'role', 'in']]
# ['role', ['had', 'a', 'in', 'the']]
# ['in', ['a', 'role', 'the', 'television']]
# ['the', ['role', 'in', 'television', 'series']]
# ['television', ['in', 'the', 'series', 'in']]
# ['series', ['the', 'television', 'in', 'in']]
# ['in', ['television', 'series', 'in']]
# ['in', ['series', 'in', 'a']]
# ['a', ['in', 'role', 'as']]
# ['role', ['a', 'as', 'in']]
# ['as', ['a', 'role', 'in', 'the']]
# ['in', ['role', 'as', 'the', 's']]
# ['the', ['as', 'in', 's', 'of']]
# ['s', ['in', 'the', 'of', 'the']]
# ['of', ['the', 's', 'the', 'television']]
# ['the', ['s', 'of', 'television', 'series']]
# ['television', ['of', 'the', 'series', 'the']]
# ['series', ['the', 'television', 'the', 'he']]
# ['the', ['television', 'series', 'he']]
# ['he', ['series', 'the', 'and']]
# ['and', ['he', 'he', 'was']]
# ['he', ['and', 'was', 'in']]
# ['was', ['and', 'he', 'in', 'the']]
# ['in', ['he', 'was', 'the']]
# ['the', ['was', 'in', 'of']]
# ['of', ['the', 'the', 'which']]
# ['the', ['of', 'which', 'was']]
# ['which', ['of', 'the', 'was', 'at']]
# ['was', ['the', 'which', 'at', 'the']]
# ['at', ['which', 'was', 'the']]
# ['the', ['was', 'at', 'in']]
# ['in', ['the', 'and', 'the']]
# ['and', ['in', 'the', 'in']]
# ['the', ['in', 'and', 'in', 'he']]
# ['in', ['and', 'the', 'he', 'was']]
# ['he', ['the', 'in', 'was', 'by']]
# ['was', ['in', 'he', 'by', 'and']]
# ['by', ['he', 'was', 'and']]
# ['and', ['was', 'by', 'and']]
# ['and', ['and', 'in']]
# ['in', ['and']]
# ['in', ['the', 'by']]
# ['the', ['in', 'by', 'he']]
# ['by', ['in', 'the', 'he', 'on']]
# ['he', ['the', 'by', 'on', 'a']]
# ['on', ['by', 'he', 'a', 'of']]
# ['a', ['he', 'on', 'of', 'the']]
# ['of', ['on', 'a', 'the', 'television']]
# ['the', ['a', 'of', 'television', 'series']]
# ['television', ['of', 'the', 'series', 'by']]
# ['series', ['the', 'television', 'by', 'a']]
# ['by', ['television', 'series', 'a', 'role']]
# ['a', ['series', 'by', 'role', 'in']]
# ['role', ['by', 'a', 'in', 'the']]
# ['in', ['a', 'role', 'the']]
# ['the', ['role', 'in', 'of']]
# ['of', ['the', 'to', 'by']]
# ['to', ['of', 'by', 'to']]
# ['by', ['of', 'to', 'to', 'was']]
# ['to', ['to', 'by', 'was', 'at']]
# ['was', ['by', 'to', 'at']]
# ['at', ['to', 'was', 'in']]
# ['in', ['at', 'the', 'of']]
# ['the', ['in', 'of', 'and']]
# ['of', ['in', 'the', 'and']]
# ['and', ['the', 'of']]
# ['in', ['two', 'in']]
# ['two', ['in', 'in', 'by']]
# ['in', ['in', 'two', 'by', 'and']]
# ['by', ['two', 'in', 'and', 'by']]
# ['and', ['in', 'by', 'by', 'in']]
# ['by', ['by', 'and', 'in']]
# ['in', ['and', 'by', 'a']]
# ['a', ['in', 'on', 'a']]
# ['on', ['a', 'a', 'two']]
# ['a', ['a', 'on', 'two', 'of']]
# ['two', ['on', 'a', 'of', 'the']]
# ['of', ['a', 'two', 'the', 'television']]
# ['the', ['two', 'of', 'television', 'series']]
# ['television', ['of', 'the', 'series', 'the']]
# ['series', ['the', 'television', 'the', 'by']]
# ['the', ['television', 'series', 'by', 'an']]
# ['by', ['series', 'the', 'an', 'on']]
# ['an', ['the', 'by', 'on', 'the']]
# ['on', ['by', 'an', 'the', 'television']]
# ['the', ['an', 'on', 'television', 'series']]
# ['television', ['on', 'the', 'series', 'in']]
# ['series', ['the', 'television', 'in', 'he']]
# ['in', ['television', 'series', 'he', 'had']]
# ['he', ['series', 'in', 'had', 'a']]
# ['had', ['in', 'he', 'a', 'role']]
# ['a', ['he', 'had', 'role', 'in']]
# ['role', ['had', 'a', 'in', 'of']]
# ['in', ['a', 'role', 'of', 'the']]
# ['of', ['role', 'in', 'the', 'television']]
# ['the', ['in', 'of', 'television', 'series']]
# ['television', ['of', 'the', 'series', 'in']]
# ['series', ['the', 'television', 'in', 'as']]
# ['in', ['television', 'series', 'as']]
# ['as', ['series', 'in']]
# ['in', ['the', 'by']]
# ['the', ['in', 'by', 'in']]
# ['by', ['in', 'the', 'in']]
# ['in', ['the', 'by', 'had']]
# ['had', ['in', 'a', 'role']]
# ['a', ['had', 'role', 'on']]
# ['role', ['had', 'a', 'on', 'the']]
# ['on', ['a', 'role', 'the', 'television']]
# ['the', ['role', 'on', 'television', 'series']]
# ['television', ['on', 'the', 'series', 'the']]
# ['series', ['the', 'television', 'the', 'he']]
# ['the', ['television', 'series', 'he', 'in']]
# ['he', ['series', 'the', 'in', 'the']]
# ['in', ['the', 'he', 'the', 'in']]
# ['the', ['he', 'in', 'in']]
# ['in', ['in', 'the']]
# ['as', ['in', 'the']]
# ['in', ['as', 'the', 'by']]
# ['the', ['as', 'in', 'by', 'which']]
# ['by', ['in', 'the', 'which', 'was']]
# ['which', ['the', 'by', 'was', 'in']]
# ['was', ['by', 'which', 'in', 'at']]
# ['in', ['which', 'was', 'at', 'the']]
# ['at', ['was', 'in', 'the']]
# ['the', ['in', 'at', 'a']]
# ['a', ['the', 'of']]
# ['of', ['a', 's']]
# ['s', ['of', 'in', 'the']]
# ['in', ['s', 'the', 'on']]
# ['the', ['s', 'in', 'on', 'as']]
# ['on', ['in', 'the', 'as', 'in']]
# ['as', ['the', 'on', 'in', 'the']]
# ['in', ['on', 'as', 'the', 'role']]
# ['the', ['as', 'in', 'role', 'and']]
# ['role', ['in', 'the', 'and', 'he']]
# ['and', ['the', 'role', 'he', 'in']]
# ['he', ['role', 'and', 'in', 'the']]
# ['in', ['and', 'he', 'the', 'and']]
# ['the', ['he', 'in', 'and', 'he']]
# ['and', ['in', 'the', 'he', 'in']]
# ['he', ['the', 'and', 'in', 'the']]
# ['in', ['and', 'he', 'the', 'television']]
# ['the', ['he', 'in', 'television', 'series']]
# ['television', ['in', 'the', 'series', 'in']]
# ['series', ['the', 'television', 'in', 'as']]
# ['in', ['television', 'series', 'as', 'in']]
# ['as', ['series', 'in', 'in', 'the']]
# ['in', ['in', 'as', 'the', 'and']]
# ['the', ['as', 'in', 'and', 'had']]
# ['and', ['in', 'the', 'had', 'a']]
# ['had', ['the', 'and', 'a', 'role']]
# ['a', ['and', 'had', 'role', 'as']]
# ['role', ['had', 'a', 'as', 'a']]
# ['as', ['a', 'role', 'a', 'on']]
# ['a', ['role', 'as', 'on', 'the']]
# ['on', ['as', 'a', 'the', 'he']]
# ['the', ['a', 'on', 'he', 'had']]
# ['he', ['on', 'the', 'had', 'a']]
# ['had', ['the', 'he', 'a', 'role']]
# ['a', ['he', 'had', 'role', 'in']]
# ['role', ['had', 'a', 'in', 'on']]
# ['in', ['a', 'role', 'on', 'two']]
# ['on', ['role', 'in', 'two', 'of']]
# ['two', ['in', 'on', 'of', 'the']]
# ['of', ['on', 'two', 'the', 'as']]
# ['the', ['two', 'of', 'as', 'in']]
# ['as', ['of', 'the', 'in']]
# ['in', ['the', 'as', 'a']]
# ['a', ['in', 'role', 'as']]
# ['role', ['a', 'as', 'in']]
# ['as', ['a', 'role', 'in', 'the']]
# ['in', ['role', 'as', 'the', 's']]
# ['the', ['as', 'in', 's', 'of']]
# ['s', ['in', 'the', 'of', 'the']]
# ['of', ['the', 's', 'the', 'television']]
# ['the', ['s', 'of', 'television', 'series']]
# ['television', ['of', 'the', 'series', 'the']]
# ['series', ['the', 'television', 'the', 'he']]
# ['the', ['television', 'series', 'he']]
# ['he', ['series', 'the', 'and']]
# ['and', ['he']]
# ['as', ['in', 'the']]
# ['in', ['as', 'the']]
# ['the', ['as', 'in', 'of']]
# ['of', ['the', 'the', 'it']]
# ['the', ['of', 'it', 'was']]
# ['it', ['of', 'the', 'was', 'at']]
# ['was', ['the', 'it', 'at', 'the']]
# ['at', ['it', 'was', 'the']]
# ['the', ['was', 'at', 'in']]
# ['in', ['the', 'and', 'the']]
# ['and', ['in', 'the', 'in']]
# ['the', ['in', 'and', 'in', 'he']]
# ['in', ['and', 'the', 'he', 'was']]
# ['he', ['the', 'in', 'was', 'by']]
# ['was', ['in', 'he', 'by', 'and']]
# ['by', ['he', 'was', 'and']]
# ['and', ['was', 'by', 'and']]
# ['and', ['and', 'a']]
# ['a', ['and', 'in', 'the']]
# ['in', ['a', 'the', 'the']]
# ['the', ['a', 'in', 'the', 'is']]
# ['the', ['in', 'the', 'is', 'with']]
# ['is', ['the', 'the', 'with', 'from']]
# ['with', ['the', 'is', 'from', 'from']]
# ['from', ['is', 'with', 'from', 'his']]
# ['from', ['with', 'from', 'his', 'as']]
# ['his', ['from', 'from', 'as', 's']]
# ['as', ['from', 'his', 's']]
# ['s', ['his', 'as', 'and']]
# ['and', ['s', 'the', 'and']]
# ['the', ['and', 'and']]
# ['and', ['and', 'the', 'the']]
# ['the', ['and', 'in']]
# ['in', ['the']]
# ['in', ['the', 'by']]
# ['the', ['in', 'by', 'the']]
# ['by', ['in', 'the', 'the', 'was']]
# ['the', ['the', 'by', 'was', 'of']]
# ['was', ['by', 'the', 'of', 'a']]
# ['of', ['the', 'was', 'a', 'series']]
# ['a', ['was', 'of', 'series', 'which']]
# ['series', ['of', 'a', 'which', 'in']]
# ['which', ['a', 'series', 'in', 'a']]
# ['in', ['series', 'which', 'a']]
# ['a', ['which', 'in', 'as']]
# ['as', ['a', 'one', 'of']]
# ['one', ['as', 'of', 'his']]
# ['of', ['as', 'one', 'his', 'with']]
# ['his', ['one', 'of', 'with', 'a']]
# ['with', ['of', 'his', 'a']]
# ['a', ['his', 'with', 'who']]
# ['who', ['a', 'was', 'in']]
# ['was', ['who', 'in', 'the']]
# ['in', ['who', 'was', 'the', 'of']]
# ['the', ['was', 'in', 'of', 'and']]
# ['of', ['in', 'the', 'and', 'at']]
# ['and', ['the', 'of', 'at', 'the']]
# ['at', ['of', 'and', 'the', 'he']]
# ['the', ['and', 'at', 'he', 'in']]
# ['he', ['at', 'the', 'in', 'he']]
# ['in', ['the', 'he', 'he', 'on']]
# ['he', ['he', 'in', 'on', 'the']]
# ['on', ['in', 'he', 'the', 'of']]
# ['the', ['he', 'on', 'of', 'the']]
# ['of', ['on', 'the', 'the', 'television']]
# ['the', ['the', 'of', 'television', 'series']]
# ['television', ['of', 'the', 'series']]
# ['series', ['the', 'television']]
# ['as', ['in', 'the']]
# ['in', ['as', 'the', 'of']]
# ['the', ['as', 'in', 'of', 'to']]
# ['of', ['in', 'the', 'to', 'by']]
# ['to', ['the', 'of', 'by', 'to']]
# ['by', ['of', 'to', 'to', 'was']]
# ['to', ['to', 'by', 'was', 'at']]
# ['was', ['by', 'to', 'at']]
# ['at', ['to', 'was', 'in']]
# ['in', ['at', 'the', 'of']]
# ['the', ['in', 'of', 'and']]
# ['of', ['in', 'the', 'and', 'in']]
# ['and', ['the', 'of', 'in', 'a']]
# ['in', ['of', 'and', 'a', 'of']]
# ['a', ['and', 'in', 'of', 'the']]
# ['of', ['in', 'a', 'the', 'for']]
# ['the', ['a', 'of', 'for', 'the']]
# ['for', ['of', 'the', 'the']]
# ['the', ['the', 'for']]
# ['a', ['to', 'the']]
# ['to', ['a', 'the', 'as']]
# ['the', ['a', 'to', 'as']]
# ['as', ['to', 'the']]
# ['in', ['two', 'in']]
# ['two', ['in', 'in', 'by']]
# ['in', ['in', 'two', 'by', 'and']]
# ['by', ['two', 'in', 'and', 'by']]
# ['and', ['in', 'by', 'by']]
# ['by', ['by', 'and', 'a']]
# ['a', ['by', 'in', 'who']]
# ['in', ['a', 'who', 'with']]
# ['who', ['a', 'in', 'with', 'as']]
# ['with', ['in', 'who', 'as', 'the']]
# ['as', ['who', 'with', 'the', 'who']]
# ['the', ['with', 'as', 'who', 'it']]
# ['who', ['as', 'the', 'it', 'with']]
# ['it', ['the', 'who', 'with']]
# ['with', ['who', 'it']]
# ['on', ['a', 'two']]
# ['a', ['on', 'two', 'in']]
# ['two', ['on', 'a', 'in', 'of']]
# ['in', ['a', 'two', 'of', 'the']]
# ['of', ['two', 'in', 'the', 'television']]
# ['the', ['in', 'of', 'television', 'series']]
# ['television', ['of', 'the', 'series', 'the']]
# ['series', ['the', 'television', 'the', 'as']]
# ['the', ['television', 'series', 'as', 'he']]
# ['as', ['series', 'the', 'he', 'on']]
# ['he', ['the', 'as', 'on', 'the']]
# ['on', ['as', 'he', 'the', 'television']]
# ['the', ['he', 'on', 'television', 'series']]
# ['television', ['on', 'the', 'series', 'as']]
# ['series', ['the', 'television', 'as', 'in']]
# ['as', ['television', 'series', 'in', 'he']]
# ['in', ['series', 'as', 'he', 'had']]
# ['he', ['as', 'in', 'had', 'a']]
# ['had', ['in', 'he', 'a', 'role']]
# ['a', ['he', 'had', 'role', 'in']]
# ['role', ['had', 'a', 'in', 'of']]
# ['in', ['a', 'role', 'of', 'the']]
# ['of', ['role', 'in', 'the', 'television']]
# ['the', ['in', 'of', 'television', 'series']]
# ['television', ['of', 'the', 'series', 'in']]
# ['series', ['the', 'television', 'in', 'as']]
# ['in', ['television', 'series', 'as', 'he']]
# ['as', ['series', 'in', 'he', 'an']]
# ['he', ['in', 'as', 'an', 'for']]
# ['an', ['as', 'he', 'for', 'a']]
# ['for', ['he', 'an', 'a', 'he']]
# ['a', ['an', 'for', 'he', 'on']]
# ['he', ['for', 'a', 'on', 'the']]
# ['on', ['a', 'he', 'the', 'in']]
# ['the', ['he', 'on', 'in', 'a']]
# ['in', ['on', 'the', 'a', 'on']]
# ['a', ['the', 'in', 'on', 'television']]
# ['on', ['in', 'a', 'television', 'a']]
# ['television', ['a', 'on', 'a', 'is']]
# ['a', ['on', 'television', 'is', 'a']]
# ['is', ['television', 'a', 'a', 'is']]
# ['a', ['a', 'is', 'is', 'but']]
# ['is', ['is', 'a', 'but', 'are']]
# ['but', ['a', 'is', 'are', 'on']]
# ['are', ['is', 'but', 'on', 'who']]
# ['on', ['but', 'are', 'who', 'are']]
# ['who', ['are', 'on', 'are', 'at']]
# ['are', ['on', 'who', 'at', 'and']]
# ['at', ['who', 'are', 'and', 'the']]
# ['and', ['are', 'at', 'the', 'to']]
# ['the', ['at', 'and', 'to', 'and']]
# ['to', ['and', 'the', 'and']]
# ['and', ['the', 'to']]
# ['in', ['the', 'by']]
# ['the', ['in', 'by', 'television']]
# ['by', ['in', 'the', 'television']]
# ['television', ['the', 'by']]
# ['was', ['a']]
# ['a', ['was']]
# ['of', ['the', 'with']]
# ['the', ['of', 'with', 'he']]
# ['with', ['of', 'the', 'he', 'is']]
# ['he', ['the', 'with', 'is', 'the']]
# ['is', ['with', 'he', 'the', 'of']]
# ['the', ['he', 'is', 'of', 'the']]
# ['of', ['is', 'the', 'the']]
# ['the', ['the', 'of', 'his']]
# ['his', ['the', 'was', 'to']]
# ['was', ['his', 'to', 'his']]
# ['to', ['his', 'was', 'his', 'as']]
# ['his', ['was', 'to', 'as', 'a']]
# ['as', ['to', 'his', 'a', 'but']]
# ['a', ['his', 'as', 'but', 'he']]
# ['but', ['as', 'a', 'he', 'to']]
# ['he', ['a', 'but', 'to', 'the']]
# ['to', ['but', 'he', 'the', 'his']]
# ['the', ['he', 'to', 'his', 'life']]
# ['his', ['to', 'the', 'life', 'the']]
# ['life', ['the', 'his', 'the', 'was']]
# ['the', ['his', 'life', 'was', 'by']]
# ['was', ['life', 'the', 'by', 'the']]
# ['by', ['the', 'was', 'the', 'an']]
# ['the', ['was', 'by', 'an', 'of']]
# ['an', ['by', 'the', 'of', 'and']]
# ['of', ['the', 'an', 'and', 'his']]
# ['and', ['an', 'of', 'his', 'years']]
# ['his', ['of', 'and', 'years', 'a']]
# ['years', ['and', 'his', 'a', 'time']]
# ['a', ['his', 'years', 'time', 'of']]
# ['time', ['years', 'a', 'of', 'he']]
# ['of', ['a', 'time', 'he', 'was']]
# ['he', ['time', 'of', 'was', 'to']]
# ['was', ['of', 'he', 'to', 'his']]
# ['to', ['he', 'was', 'his', 'works']]
# ['his', ['was', 'to', 'works', 'to']]
# ['works', ['to', 'his', 'to', 'be']]
# ['to', ['his', 'works', 'be', 'in']]
# ['be', ['works', 'to', 'in']]
# ['in', ['to', 'be', 'and']]
# ['and', ['in', 'of', 'his']]
# ['of', ['and', 'his']]
# ['his', ['and', 'of', 'have']]
# ['have', ['his', 'been', 'the']]
# ['been', ['have', 'the', 'he']]
# ['the', ['have', 'been', 'he', 'been']]
# ['he', ['been', 'the', 'been', 'the']]
# ['been', ['the', 'he', 'the']]
# ['the', ['he', 'been', 'and']]
# ['and', ['the', 'the']]
# ['the', ['and', 'by']]
# ['by', ['the', 'the']]
# ['the', ['by', 'of', 'his']]
# ['of', ['the', 'his', 'to']]
# ['his', ['the', 'of', 'to', 'be']]
# ['to', ['of', 'his', 'be', 'to']]
# ['be', ['his', 'to', 'to', 'as']]
# ['to', ['to', 'be', 'as', 'the']]
# ['as', ['be', 'to', 'the']]
# ['the', ['to', 'as', 'or']]
# ['or', ['the', 'life']]
# ['life', ['or', 'the']]
# ['the', ['life', 'life', 'of']]
# ['life', ['the', 'of', 'the']]
# ['of', ['the', 'life', 'the', 'a']]
# ['the', ['life', 'of', 'a', 'a']]
# ['a', ['of', 'the', 'a', 'which']]
# ['a', ['the', 'a', 'which', 'to']]
# ['which', ['a', 'a', 'to', 'the']]
# ['to', ['a', 'which', 'the', 'that']]
# ['the', ['which', 'to', 'that']]
# ['that', ['to', 'the', 'and']]
# ['and', ['that', 'of']]
# ['of', ['and']]
# ['s', ['and']]
# ['and', ['s', 'this', 'is']]
# ['this', ['and', 'is', 'by']]
# ['is', ['and', 'this', 'by', 'the']]
# ['by', ['this', 'is', 'the']]
# ['the', ['is', 'by', 'is']]
# ['is', ['the', 'that']]
# ['that', ['is']]
# ['are', ['that', 'be']]
# ['that', ['are', 'be', 'but']]
# ['be', ['are', 'that', 'but', 'which']]
# ['but', ['that', 'be', 'which', 'an']]
# ['which', ['be', 'but', 'an', 'be']]
# ['an', ['but', 'which', 'be', 'to']]
# ['be', ['which', 'an', 'to', 'for']]
# ['to', ['an', 'be', 'for', 'the']]
# ['for', ['be', 'to', 'the', 'the']]
# ['the', ['to', 'for', 'the', 'time']]
# ['the', ['for', 'the', 'time', 'the']]
# ['time', ['the', 'the', 'the', 'and']]
# ['the', ['the', 'time', 'and', 'the']]
# ['and', ['time', 'the', 'the', 'in']]
# ['the', ['the', 'and', 'in', 'the']]
# ['in', ['and', 'the', 'the', 'the']]
# ['the', ['the', 'in', 'the', 'are']]
# ['the', ['in', 'the', 'are', 'to']]
# ['are', ['the', 'the', 'to', 'it']]
# ['to', ['the', 'are', 'it', 'and']]
# ['it', ['are', 'to', 'and', 'the']]
# ['and', ['to', 'it', 'the', 'be']]
# ['the', ['it', 'and', 'be', 'that']]
# ['be', ['and', 'the', 'that', 'the']]
# ['that', ['the', 'be', 'the', 'or']]
# ['the', ['be', 'that', 'or', 'to']]
# ['or', ['that', 'the', 'to', 'it']]
# ['to', ['the', 'or', 'it', 'a']]
# ['it', ['or', 'to', 'a', 'to']]
# ['a', ['to', 'it', 'to']]
# ['to', ['it', 'a']]
# ['that', ['the', 'of']]
# ['the', ['that', 'of', 'the']]
# ['of', ['that', 'the', 'the']]
# ['the', ['the', 'of', 's']]
# ['s', ['the', 'of', 'his']]
# ['of', ['s', 'his', 'life']]
# ['his', ['s', 'of', 'life', 'the']]
# ['life', ['of', 'his', 'the', 'for']]
# ['the', ['his', 'life', 'for', 'years']]
# ['for', ['life', 'the', 'years', 'of']]
# ['years', ['the', 'for', 'of', 'is']]
# ['of', ['for', 'years', 'is', 'of']]
# ['is', ['years', 'of', 'of']]
# ['of', ['of', 'is']]
# ['s', ['life', 'from']]
# ['life', ['s', 'from', 'his']]
# ['from', ['s', 'life', 'his']]
# ['his', ['life', 'from', 'his']]
# ['his', ['his', 'was']]
# ['was', ['his', 'a']]
# ['a', ['was', 'and']]
# ['and', ['a', 'the']]
# ['the', ['and', 'of']]
# ['of', ['the']]
# ['was', ['in', 'the']]
# ['in', ['was', 'the', 'is']]
# ['the', ['was', 'in', 'is', 'that']]
# ['is', ['in', 'the', 'that', 'it']]
# ['that', ['the', 'is', 'it', 'was']]
# ['it', ['is', 'that', 'was', 'is']]
# ['was', ['that', 'it', 'is', 'a']]
# ['is', ['it', 'was', 'a', 'in']]
# ['a', ['was', 'is', 'in', 'life']]
# ['in', ['is', 'a', 'life', 'he']]
# ['life', ['a', 'in', 'he', 'to']]
# ['he', ['in', 'life', 'to', 'to']]
# ['to', ['life', 'he', 'to', 'the']]
# ['to', ['he', 'to', 'the', 'of']]
# ['the', ['to', 'to', 'of', 'an']]
# ['of', ['to', 'the', 'an', 'of']]
# ['an', ['the', 'of', 'of', 'the']]
# ['of', ['of', 'an', 'the']]
# ['the', ['an', 'of']]
# ['s', ['he', 'was']]
# ['he', ['s', 'was', 'and']]
# ['was', ['s', 'he', 'and', 'he']]
# ['and', ['he', 'was', 'he', 'was']]
# ['he', ['was', 'and', 'was', 'by']]
# ['was', ['and', 'he', 'by', 'his']]
# ['by', ['he', 'was', 'his', 'he']]
# ['his', ['was', 'by', 'he', 'had']]
# ['he', ['by', 'his', 'had', 'an']]
# ['had', ['his', 'he', 'an', 'who']]
# ['an', ['he', 'had', 'who', 'he']]
# ['who', ['had', 'an', 'he', 'had']]
# ['he', ['an', 'who', 'had', 'and']]
# ['had', ['who', 'he', 'and', 'one']]
# ['and', ['he', 'had', 'one', 'to']]
# ['one', ['had', 'and', 'to', 'he']]
# ['to', ['and', 'one', 'he', 'in']]
# ['he', ['one', 'to', 'in', 'his']]
# ['in', ['to', 'he', 'his']]
# ['his', ['he', 'in', 'he']]
# ['he', ['his', 'his', 'the']]
# ['his', ['he', 'the', 'of']]
# ['the', ['he', 'his', 'of', 'a']]
# ['of', ['his', 'the', 'a', 'his']]
# ['a', ['the', 'of', 'his', 'was']]
# ['his', ['of', 'a', 'was', 'on']]
# ['was', ['a', 'his', 'on', 'the']]
# ['on', ['his', 'was', 'the', 'of']]
# ['the', ['was', 'on', 'of', 'a']]
# ['of', ['on', 'the', 'a', 'and']]
# ['a', ['the', 'of', 'and', 'of']]
# ['and', ['of', 'a', 'of', 'the']]
# ['of', ['a', 'and', 'the', 'of']]
# ['the', ['and', 'of', 'of', 'and']]
# ['of', ['of', 'the', 'and', 'he']]
# ['and', ['the', 'of', 'he', 'to']]
# ['he', ['of', 'and', 'to', 'have']]
# ['to', ['and', 'he', 'have']]
# ['have', ['he', 'to', 'by']]
# ['by', ['have', 'his', 'but']]
# ['his', ['by', 'but', 'have']]
# ['but', ['by', 'his', 'have', 'been']]
# ['have', ['his', 'but', 'been', 'in']]
# ['been', ['but', 'have', 'in', 'the']]
# ['in', ['have', 'been', 'the', 's']]
# ['the', ['been', 'in', 's', 'he']]
# ['s', ['in', 'the', 'he', 'in']]
# ['he', ['the', 's', 'in', 'the']]
# ['in', ['s', 'he', 'the', 'his']]
# ['the', ['he', 'in', 'his', 'a']]
# ['his', ['in', 'the', 'a', 'is']]
# ['a', ['the', 'his', 'is', 'to']]
# ['is', ['his', 'a', 'to', 'from']]
# ['to', ['a', 'is', 'from', 'the']]
# ['from', ['is', 'to', 'the', 'of']]
# ['the', ['to', 'from', 'of', 'this']]
# ['of', ['from', 'the', 'this', 'in']]
# ['this', ['the', 'of', 'in', 'that']]
# ['in', ['of', 'this', 'that', 'he']]
# ['that', ['this', 'in', 'he', 'the']]
# ['he', ['in', 'that', 'the', 'in']]
# ['the', ['that', 'he', 'in', 'an']]
# ['in', ['he', 'the', 'an', 'he']]
# ['an', ['the', 'in', 'he', 'to']]
# ['he', ['in', 'an', 'to', 'his']]
# ['to', ['an', 'he', 'his', 'and']]
# ['his', ['he', 'to', 'and', 'that']]
# ['and', ['to', 'his', 'that', 'of']]
# ['that', ['his', 'and', 'of', 'of']]
# ['of', ['and', 'that', 'of', 'that']]
# ['of', ['that', 'of', 'that', 'he']]
# ['that', ['of', 'of', 'he', 'his']]
# ['he', ['of', 'that', 'his', 'at']]
# ['his', ['that', 'he', 'at', 'the']]
# ['at', ['he', 'his', 'the', 'time']]
# ['the', ['his', 'at', 'time', 'was']]
# ['time', ['at', 'the', 'was', 'and']]
# ['was', ['the', 'time', 'and', 'his']]
# ['and', ['time', 'was', 'his', 'to']]
# ['his', ['was', 'and', 'to', 'in']]
# ['to', ['and', 'his', 'in', 'the']]
# ['in', ['his', 'to', 'the', 'have']]
# ['the', ['to', 'in', 'have', 'been']]
# ['have', ['in', 'the', 'been', 'to']]
# ['been', ['the', 'have', 'to', 'this']]
# ['to', ['have', 'been', 'this', 'he']]
# ['this', ['been', 'to', 'he', 'to']]
# ['he', ['to', 'this', 'to', 'this']]
# ['to', ['this', 'he', 'this', 'time']]
# ['this', ['he', 'to', 'time', 'and']]
# ['time', ['to', 'this', 'and', 'his']]
# ['and', ['this', 'time', 'his']]
# ['his', ['time', 'and']]
# ['have', ['been', 'to']]
# ['been', ['have', 'to', 'the']]
# ['to', ['have', 'been', 'the', 'of']]
# ['the', ['been', 'to', 'of', 'his']]
# ['of', ['to', 'the', 'his', 's']]
# ['his', ['the', 'of', 's', 'but']]
# ['s', ['of', 'his', 'but', 'he']]
# ['but', ['his', 's', 'he', 'is']]
# ['he', ['s', 'but', 'is', 'to']]
# ['is', ['but', 'he', 'to', 'have']]
# ['to', ['he', 'is', 'have', 'the']]
# ['have', ['is', 'to', 'the', 'in']]
# ['the', ['to', 'have', 'in', 'of']]
# ['in', ['have', 'the', 'of', 'one']]
# ['of', ['the', 'in', 'one', 'of']]
# ['one', ['in', 'of', 'of', 'his']]
# ['of', ['of', 'one', 'his', 'he']]
# ['his', ['one', 'of', 'he', 'the']]
# ['he', ['of', 'his', 'the', 'years']]
# ['the', ['his', 'he', 'years', 'in']]
# ['years', ['he', 'the', 'in', 'the']]
# ['in', ['the', 'years', 'the', 'his']]
# ['the', ['years', 'in', 'his', 'in']]
# ['his', ['in', 'the', 'in', 'in']]
# ['in', ['the', 'his', 'in', 'the']]
# ['in', ['his', 'in', 'the', 'of']]
# ['the', ['in', 'in', 'of', 'he']]
# ['of', ['in', 'the', 'he', 'for']]
# ['he', ['the', 'of', 'for', 'the']]
# ['for', ['of', 'he', 'the', 'time']]
# ['the', ['he', 'for', 'time', 'and']]
# ['time', ['for', 'the', 'and', 'the']]
# ['and', ['the', 'time', 'the', 'two']]
# ['the', ['time', 'and', 'two', 'a']]
# ['two', ['and', 'the', 'a', 'this']]
# ['a', ['the', 'two', 'this', 'as']]
# ['this', ['two', 'a', 'as', 'the']]
# ['as', ['a', 'this', 'the', 'in']]
# ['the', ['this', 'as', 'in']]
# ['in', ['as', 'the']]
# ['s', ['it', 'a']]
# ['it', ['s', 'a', 'of']]
# ['a', ['s', 'it', 'of', 'the']]
# ['of', ['it', 'a', 'the']]
# ['the', ['a', 'of', 'life']]
# ['life', ['the', 'to', 'which']]
# ['to', ['life', 'which', 'he']]
# ['which', ['life', 'to', 'he', 'was']]
# ['he', ['to', 'which', 'was', 'his']]
# ['was', ['which', 'he', 'his', 'in']]
# ['his', ['he', 'was', 'in', 'the']]
# ['in', ['was', 'his', 'the', 'the']]
# ['the', ['his', 'in', 'the', 'was']]
# ['the', ['in', 'the', 'was', 'one']]
# ['was', ['the', 'the', 'one']]
# ['one', ['the', 'was']]
# ['was', ['by', 'years']]
# ['by', ['was', 'years', 'the']]
# ['years', ['was', 'by', 'the', 'was']]
# ['the', ['by', 'years', 'was', 'a']]
# ['was', ['years', 'the', 'a', 'have']]
# ['a', ['the', 'was', 'have']]
# ['have', ['was', 'a', 'to']]
# ['to', ['have', 'or', 'from']]
# ['or', ['to', 'from', 'the']]
# ['from', ['to', 'or', 'the']]
# ['the', ['or', 'from', 'but']]
# ['but', ['the', 'one', 'in']]
# ['one', ['but', 'in', 'the']]
# ['in', ['but', 'one', 'the', 'in']]
# ['the', ['one', 'in', 'in', 'in']]
# ['in', ['in', 'the', 'in', 'he']]
# ['in', ['the', 'in', 'he', 'to']]
# ['he', ['in', 'in', 'to', 'the']]
# ['to', ['in', 'he', 'the', 'in']]
# ['the', ['he', 'to', 'in', 'an']]
# ['in', ['to', 'the', 'an', 'to']]
# ['an', ['the', 'in', 'to', 'his']]
# ['to', ['in', 'an', 'his', 'he']]
# ['his', ['an', 'to', 'he', 'the']]
# ['he', ['to', 'his', 'the', 'a']]
# ['the', ['his', 'he', 'a', 'time']]
# ['a', ['he', 'the', 'time', 'the']]
# ['time', ['the', 'a', 'the', 'but']]
# ['the', ['a', 'time', 'but', 'all']]
# ['but', ['time', 'the', 'all', 'the']]
# ['all', ['the', 'but', 'the', 'by']]
# ['the', ['but', 'all', 'by', 'the']]
# ['by', ['all', 'the', 'the', 'in']]
# ['the', ['the', 'by', 'in', 'to']]
# ['in', ['by', 'the', 'to', 'the']]
# ['to', ['the', 'in', 'the', 'of']]
# ['the', ['in', 'to', 'of', 'he']]
# ['of', ['to', 'the', 'he', 'the']]
# ['he', ['the', 'of', 'the', 'the']]
# ['the', ['of', 'he', 'the', 'in']]
# ['the', ['he', 'the', 'in', 'and']]
# ['in', ['the', 'the', 'and', 'in']]
# ['and', ['the', 'in', 'in', 'he']]
# ['in', ['in', 'and', 'he', 'and']]
# ['he', ['and', 'in', 'and', 'by']]
# ['and', ['in', 'he', 'by', 'the']]
# ['by', ['he', 'and', 'the', 'had']]
# ['the', ['and', 'by', 'had', 'had']]
# ['had', ['by', 'the', 'had', 'and']]
# ['had', ['the', 'had', 'and', 'two']]
# ['and', ['had', 'had', 'two', 'but']]
# ['two', ['had', 'and', 'but', 'one']]
# ['but', ['and', 'two', 'one', 'of']]
# ['one', ['two', 'but', 'of', 'the']]
# ['of', ['but', 'one', 'the', 'in']]
# ['the', ['one', 'of', 'in', 'in']]
# ['in', ['of', 'the', 'in', 'from']]
# ['in', ['the', 'in', 'from', 'he']]
# ['from', ['in', 'in', 'he', 'to']]
# ['he', ['in', 'from', 'to', 'have']]
# ['to', ['from', 'he', 'have', 'the']]
# ['have', ['he', 'to', 'the', 'of']]
# ['the', ['to', 'have', 'of', 'a']]
# ['of', ['have', 'the', 'a', 'series']]
# ['a', ['the', 'of', 'series', 'of']]
# ['series', ['of', 'a', 'of', 'which']]
# ['of', ['a', 'series', 'which', 'for']]
# ['which', ['series', 'of', 'for', 'the']]
# ['for', ['of', 'which', 'the', 'of']]
# ['the', ['which', 'for', 'of', 'his']]
# ['of', ['for', 'the', 'his', 'life']]
# ['his', ['the', 'of', 'life', 'it']]
# ['life', ['of', 'his', 'it', 'was']]
# ['it', ['his', 'life', 'was', 'in']]
# ['was', ['life', 'it', 'in', 'that']]
# ['in', ['it', 'was', 'that', 'that']]
# ['that', ['was', 'in', 'that']]
# ['that', ['in', 'that']]
# ['was', ['to', 'his']]
# ['to', ['was', 'his', 'to']]
# ['his', ['was', 'to', 'to', 'the']]
# ['to', ['to', 'his', 'the', 'of']]
# ['the', ['his', 'to', 'of', 'a']]
# ['of', ['to', 'the', 'a', 'by']]
# ['a', ['the', 'of', 'by', 'in']]
# ['by', ['of', 'a', 'in', 'the']]
# ['in', ['a', 'by', 'the', 'in']]
# ['the', ['by', 'in', 'in', 'he']]
# ['in', ['in', 'the', 'he', 'an']]
# ['he', ['the', 'in', 'an', 'as']]
# ['an', ['in', 'he', 'as', 'of']]
# ['as', ['he', 'an', 'of', 'the']]
# ['of', ['an', 'as', 'the', 's']]
# ['the', ['as', 'of', 's', 'of']]
# ['s', ['of', 'the', 'of', 'the']]
# ['of', ['the', 's', 'the', 's']]
# ['the', ['s', 'of', 's', 'this']]
# ['s', ['of', 'the', 'this', 'was']]
# ['this', ['the', 's', 'was', 'a']]
# ['was', ['s', 'this', 'a', 'in']]
# ['a', ['this', 'was', 'in', 'it']]
# ['in', ['was', 'a', 'it', 'have']]
# ['it', ['a', 'in', 'have', 'been']]
# ['have', ['in', 'it', 'been', 'at']]
# ['been', ['it', 'have', 'at', 'the']]
# ['at', ['have', 'been', 'the', 'of']]
# ['the', ['been', 'at', 'of', 'an']]
# ['of', ['at', 'the', 'an', 'he']]
# ['an', ['the', 'of', 'he', 'had']]
# ['he', ['of', 'an', 'had', 'the']]
# ['had', ['an', 'he', 'the', 'was']]
# ['the', ['he', 'had', 'was', 'by']]
# ['was', ['had', 'the', 'by', 'the']]
# ['by', ['the', 'was', 'the', 'an']]
# ['the', ['was', 'by', 'an', 'in']]
# ['an', ['by', 'the', 'in', 'and']]
# ['in', ['the', 'an', 'and', 'was']]
# ['and', ['an', 'in', 'was', 'for']]
# ['was', ['in', 'and', 'for', 'years']]
# ['for', ['and', 'was', 'years', 'it']]
# ['years', ['was', 'for', 'it', 'to']]
# ['it', ['for', 'years', 'to']]
# ['to', ['years', 'it', 'the']]
# ['the', ['to', 'of', 'but']]
# ['of', ['the', 'but', 'years']]
# ['but', ['the', 'of', 'years', 'the']]
# ['years', ['of', 'but', 'the', 'the']]
# ['the', ['but', 'years', 'the', 'been']]
# ['the', ['years', 'the', 'been', 'or']]
# ['been', ['the', 'the', 'or', 'this']]
# ['or', ['the', 'been', 'this', 'time']]
# ['this', ['been', 'or', 'time']]
# ['time', ['or', 'this']]
# ['a', ['life', 'by']]
# ['life', ['a', 'by', 'and']]
# ['by', ['a', 'life', 'and', 'this']]
# ['and', ['life', 'by', 'this', 'of']]
# ['this', ['by', 'and', 'of', 'was']]
# ['of', ['and', 'this', 'was', 'the']]
# ['was', ['this', 'of', 'the', 'of']]
# ['the', ['of', 'was', 'of']]
# ['of', ['was', 'the']]
# ['as', ['a']]
# ['a', ['as', 'that']]
# ['that', ['a', 'he', 'the']]
# ['he', ['that', 'the', 'of']]
# ['the', ['that', 'he', 'of', 'his']]
# ['of', ['he', 'the', 'his', 'and']]
# ['his', ['the', 'of', 'and', 'he']]
# ['and', ['of', 'his', 'he', 'and']]
# ['he', ['his', 'and', 'and', 'he']]
# ['and', ['and', 'he', 'he', 'for']]
# ['he', ['he', 'and', 'for', 'or']]
# ['for', ['and', 'he', 'or', 'from']]
# ['or', ['he', 'for', 'from', 'the']]
# ['from', ['for', 'or', 'the', 'of']]
# ['the', ['or', 'from', 'of', 'the']]
# ['of', ['from', 'the', 'the', 'of']]
# ['the', ['the', 'of', 'of', 'his']]
# ['of', ['of', 'the', 'his', 'he']]
# ['his', ['the', 'of', 'he', 'of']]
# ['he', ['of', 'his', 'of', 'the']]
# ['of', ['his', 'he', 'the', 'of']]
# ['the', ['he', 'of', 'of', 'his']]
# ['of', ['of', 'the', 'his', 'he']]
# ['his', ['the', 'of', 'he', 'to']]
# ['he', ['of', 'his', 'to', 'the']]
# ['to', ['his', 'he', 'the', 'of']]
# ['the', ['he', 'to', 'of', 'in']]
# ['of', ['to', 'the', 'in', 'his']]
# ['in', ['the', 'of', 'his', 'of']]
# ['his', ['of', 'in', 'of', 'his']]
# ['of', ['in', 'his', 'his']]
# ['his', ['his', 'of']]
# ['wrote', ['on', 'have']]
# ['on', ['wrote', 'have', 'the']]
# ['have', ['wrote', 'on', 'the', 'be']]
# ['the', ['on', 'have', 'be', 'by']]
# ['be', ['have', 'the', 'by', 'the']]
# ['by', ['the', 'be', 'the', 'in']]
# ['the', ['be', 'by', 'in', 'was']]
# ['in', ['by', 'the', 'was', 'to']]
# ['was', ['the', 'in', 'to', 'the']]
# ['to', ['in', 'was', 'the', 'and']]
# ['the', ['was', 'to', 'and']]
# ['and', ['to', 'the']]
# ['who', ['had', 'been']]
# ['had', ['who', 'been', 'from']]
# ['been', ['who', 'had', 'from', 'the']]
# ['from', ['had', 'been', 'the', 'his']]
# ['the', ['been', 'from', 'his', 'to']]
# ['his', ['from', 'the', 'to', 'a']]
# ['to', ['the', 'his', 'a', 'of']]
# ['a', ['his', 'to', 'of', 'and']]
# ['of', ['to', 'a', 'and', 'to']]
# ['and', ['a', 'of', 'to', 'the']]
# ['to', ['of', 'and', 'the', 'of']]
# ['the', ['and', 'to', 'of', 'the']]
# ['of', ['to', 'the', 'the', 'but']]
# ['the', ['the', 'of', 'but', 'he']]
# ['but', ['of', 'the', 'he', 'was']]
# ['he', ['the', 'but', 'was', 'by']]
# ['was', ['but', 'he', 'by', 'the']]
# ['by', ['he', 'was', 'the', 'and']]
# ['the', ['was', 'by', 'and', 'to']]
# ['and', ['by', 'the', 'to', 'an']]
# ['to', ['the', 'and', 'an', 'in']]
# ['an', ['and', 'to', 'in', 'the']]
# ['in', ['to', 'an', 'the', 'his']]
# ['the', ['an', 'in', 'his']]
# ['his', ['in', 'the', 'was']]
# ['was', ['his', 'this', 'time']]
# ['this', ['was', 'time']]
# ['time', ['was', 'this']]
# ['is', ['to', 'have']]
# ['to', ['is', 'have', 'he']]
# ['have', ['is', 'to', 'he', 'from']]
# ['he', ['to', 'have', 'from', 'an']]
# ['from', ['have', 'he', 'an', 'the']]
# ['an', ['he', 'from', 'the', 'and']]
# ['the', ['from', 'an', 'and', 'was']]
# ['and', ['an', 'the', 'was', 'he']]
# ['was', ['the', 'and', 'he', 'the']]
# ['he', ['and', 'was', 'the', 'in']]
# ['the', ['was', 'he', 'in', 'this']]
# ['in', ['he', 'the', 'this', 'to']]
# ['this', ['the', 'in', 'to', 'the']]
# ['to', ['in', 'this', 'the', 'but']]
# ['the', ['this', 'to', 'but', 'was']]
# ['but', ['to', 'the', 'was']]
# ['was', ['the', 'but']]
# ['s', ['to', 'to']]
# ['to', ['s', 'to', 'of']]
# ['to', ['s', 'to', 'of', 'it']]
# ['of', ['to', 'to', 'it', 'he']]
# ['it', ['to', 'of', 'he', 'for']]
# ['he', ['of', 'it', 'for', 'by']]
# ['for', ['it', 'he', 'by', 'the']]
# ['by', ['he', 'for', 'the', 'of']]
# ['the', ['for', 'by', 'of', 'his']]
# ['of', ['by', 'the', 'his', 'and']]
# ['his', ['the', 'of', 'and', 'on']]
# ['and', ['of', 'his', 'on', 'a']]
# ['on', ['his', 'and', 'a', 'he']]
# ['a', ['and', 'on', 'he', 'was']]
# ['he', ['on', 'a', 'was', 'but']]
# ['was', ['a', 'he', 'but', 'was']]
# ['but', ['he', 'was', 'was', 'in']]
# ['was', ['was', 'but', 'in', 'he']]
# ['in', ['but', 'was', 'he', 'was']]
# ['he', ['was', 'in', 'was', 'to']]
# ['was', ['in', 'he', 'to', 'his']]
# ['to', ['he', 'was', 'his', 'in']]
# ['his', ['was', 'to', 'in', 'but']]
# ['in', ['to', 'his', 'but', 'he']]
# ['but', ['his', 'in', 'he', 'the']]
# ['he', ['in', 'but', 'the', 'and']]
# ['the', ['but', 'he', 'and', 'on']]
# ['and', ['he', 'the', 'on', 'he']]
# ['on', ['the', 'and', 'he', 'to']]
# ['he', ['and', 'on', 'to', 'an']]
# ['to', ['on', 'he', 'an', 'with']]
# ['an', ['he', 'to', 'with', 'the']]
# ['with', ['to', 'an', 'the', 'by']]
# ['the', ['an', 'with', 'by', 'his']]
# ['by', ['with', 'the', 'his', 'to']]
# ['his', ['the', 'by', 'to', 'be']]
# ['to', ['by', 'his', 'be', 'and']]
# ['be', ['his', 'to', 'and', 'in']]
# ['and', ['to', 'be', 'in', 'the']]
# ['in', ['be', 'and', 'the', 'of']]
# ['the', ['and', 'in', 'of', 'he']]
# ['of', ['in', 'the', 'he', 'was']]
# ['he', ['the', 'of', 'was', 'to']]
# ['was', ['of', 'he', 'to', 'a']]
# ['to', ['he', 'was', 'a', 'as']]
# ['a', ['was', 'to', 'as', 'of']]
# ['as', ['to', 'a', 'of', 'in']]
# ['of', ['a', 'as', 'in', 'the']]
# ['in', ['as', 'of', 'the', 'was']]
# ['the', ['of', 'in', 'was', 'to']]
# ['was', ['in', 'the', 'to', 'his']]
# ['to', ['the', 'was', 'his', 'in']]
# ['his', ['was', 'to', 'in', 'one']]
# ['in', ['to', 'his', 'one', 'he']]
# ['one', ['his', 'in', 'he', 'wrote']]
# ['he', ['in', 'one', 'wrote', 'to']]
# ['wrote', ['one', 'he', 'to', 'in']]
# ['to', ['he', 'wrote', 'in', 'the']]
# ['in', ['wrote', 'to', 'the', 'to']]
# ['the', ['to', 'in', 'to', 'on']]
# ['to', ['in', 'the', 'on', 'he']]
# ['on', ['the', 'to', 'he', 'on']]
# ['he', ['to', 'on', 'on', 'in']]
# ['on', ['on', 'he', 'in', 'the']]
# ['in', ['he', 'on', 'the', 'of']]
# ['the', ['on', 'in', 'of', 'this']]
# ['of', ['in', 'the', 'this', 'been']]
# ['this', ['the', 'of', 'been', 'to']]
# ['been', ['of', 'this', 'to', 'but']]
# ['to', ['this', 'been', 'but', 'that']]
# ['but', ['been', 'to', 'that', 'is']]
# ['that', ['to', 'but', 'is', 'a']]
# ['is', ['but', 'that', 'a', 'he']]
# ['a', ['that', 'is', 'he', 'in']]
# ['he', ['is', 'a', 'in', 'he']]
# ['in', ['a', 'he', 'he', 'wrote']]
# ['he', ['he', 'in', 'wrote']]
# ['wrote', ['in', 'he', 'in']]
# ['in', ['wrote', 'he', 'in']]
# ['he', ['in', 'in', 'he']]
# ['in', ['in', 'he', 'he', 'on']]
# ['he', ['he', 'in', 'on', 'for']]
# ['on', ['in', 'he', 'for', 'he']]
# ['for', ['he', 'on', 'he', 'was']]
# ['he', ['on', 'for', 'was', 'by']]
# ['was', ['for', 'he', 'by', 'and']]
# ['by', ['he', 'was', 'and']]
# ['and', ['was', 'by']]
# ['in', ['for', 'of']]
# ['for', ['in', 'of', 'the']]
# ['of', ['in', 'for', 'the', 'years']]
# ['the', ['for', 'of', 'years', 'by']]
# ['years', ['of', 'the', 'by', 'the']]
# ['by', ['the', 'years', 'the', 'of']]
# ['the', ['years', 'by', 'of', 'that']]
# ['of', ['by', 'the', 'that', 'he']]
# ['that', ['the', 'of', 'he', 'was']]
# ['he', ['of', 'that', 'was', 'in']]
# ['was', ['that', 'he', 'in', 'and']]
# ['in', ['he', 'was', 'and']]
# ['and', ['was', 'in', 'to']]
# ['to', ['and', 'he', 'was']]
# ['he', ['to', 'was', 'by']]
# ['was', ['to', 'he', 'by', 'a']]
# ['by', ['he', 'was', 'a', 'and']]
# ['a', ['was', 'by', 'and', 'who']]
# ['and', ['by', 'a', 'who', 'was']]
# ['who', ['a', 'and', 'was', 'at']]
# ['was', ['and', 'who', 'at', 'his']]
# ['at', ['who', 'was', 'his', 'this']]
# ['his', ['was', 'at', 'this', 'was']]
# ['this', ['at', 'his', 'was', 'one']]
# ['was', ['his', 'this', 'one', 'of']]
# ['one', ['this', 'was', 'of', 'the']]
# ['of', ['was', 'one', 'the', 'and']]
# ['the', ['one', 'of', 'and', 'of']]
# ['and', ['of', 'the', 'of', 'his']]
# ['of', ['the', 'and', 'his', 'life']]
# ['his', ['and', 'of', 'life', 'of']]
# ['life', ['of', 'his', 'of']]
# ['of', ['his', 'life', 's']]
# ['s', ['of', 'from']]
# ['from', ['s', 'this', 'are']]
# ['this', ['from', 'are', 'of']]
# ['are', ['from', 'this', 'of', 'his']]
# ['of', ['this', 'are', 'his', 'life']]
# ['his', ['are', 'of', 'life', 'at']]
# ['life', ['of', 'his', 'at', 'in']]
# ['at', ['his', 'life', 'in', 'he']]
# ['in', ['life', 'at', 'he', 'the']]
# ['he', ['at', 'in', 'the', 'to']]
# ['the', ['in', 'he', 'to', 'a']]
# ['to', ['he', 'the', 'a', 'but']]
# ['a', ['the', 'to', 'but', 'he']]
# ['but', ['to', 'a', 'he', 'in']]
# ['he', ['a', 'but', 'in', 'he']]
# ['in', ['but', 'he', 'he', 'was']]
# ['he', ['he', 'in', 'was', 'an']]
# ['was', ['in', 'he', 'an', 'to']]
# ['an', ['he', 'was', 'to', 'who']]
# ['to', ['was', 'an', 'who', 'was']]
# ['who', ['an', 'to', 'was', 'in']]
# ['was', ['to', 'who', 'in', 'the']]
# ['in', ['who', 'was', 'the', 'years']]
# ['the', ['was', 'in', 'years', 'the']]
# ['years', ['in', 'the', 'the', 'of']]
# ['the', ['the', 'years', 'of', 'his']]
# ['of', ['years', 'the', 'his', 'was']]
# ['his', ['the', 'of', 'was', 'by']]
# ['was', ['of', 'his', 'by', 'in']]
# ['by', ['his', 'was', 'in', 'the']]
# ['in', ['was', 'by', 'the', 'of']]
# ['the', ['by', 'in', 'of', 'and']]
# ['of', ['in', 'the', 'and', 'in']]
# ['and', ['the', 'of', 'in', 'the']]
# ['in', ['of', 'and', 'the', 'of']]
# ['the', ['and', 'in', 'of']]
# ['of', ['in', 'the']]
# ['and', ['his', 'the']]
# ['his', ['and', 'the', 'with']]
# ['the', ['and', 'his', 'with', 'the']]
# ['with', ['his', 'the', 'the', 'of']]
# ['the', ['the', 'with', 'of', 'by']]
# ['of', ['with', 'the', 'by', 'his']]
# ['by', ['the', 'of', 'his', 'by']]
# ['his', ['of', 'by', 'by', 'this']]
# ['by', ['by', 'his', 'this', 'time']]
# ['this', ['his', 'by', 'time', 'he']]
# ['time', ['by', 'this', 'he', 'was']]
# ['he', ['this', 'time', 'was', 'from']]
# ['was', ['time', 'he', 'from', 'and']]
# ['from', ['he', 'was', 'and', 'in']]
# ['and', ['was', 'from', 'in', 'to']]
# ['in', ['from', 'and', 'to', 'his']]
# ['to', ['and', 'in', 'his', 'in']]
# ['his', ['in', 'to', 'in', 'in']]
# ['in', ['to', 'his', 'in', 'is']]
# ['in', ['his', 'in', 'is', 'at']]
# ['is', ['in', 'in', 'at', 'the']]
# ['at', ['in', 'is', 'the', 'to']]
# ['the', ['is', 'at', 'to', 'the']]
# ['to', ['at', 'the', 'the', 'for']]
# ['the', ['the', 'to', 'for', 'two']]
# ['for', ['to', 'the', 'two', 'years']]
# ['two', ['the', 'for', 'years', 'from']]
# ['years', ['for', 'two', 'from', 'this']]
# ['from', ['two', 'years', 'this', 'was']]
# ['this', ['years', 'from', 'was']]
# ['was', ['from', 'this']]
# ['s', ['and', 'he']]
# ['and', ['s', 'he', 'wrote']]
# ['he', ['s', 'and', 'wrote']]
# ['wrote', ['and', 'he', 'in']]
# ['in', ['wrote', 'his', 'in']]
# ['his', ['in', 'in', 'of']]
# ['in', ['in', 'his', 'of', 'the']]
# ['of', ['his', 'in', 'the', 'he']]
# ['the', ['in', 'of', 'he']]
# ['he', ['of', 'the']]
# ['and', ['as', 'his']]
# ['as', ['and', 'his', 'in']]
# ['his', ['and', 'as', 'in', 'he']]
# ['in', ['as', 'his', 'he', 'his']]
# ['he', ['his', 'in', 'his', 'and']]
# ['his', ['in', 'he', 'and', 'as']]
# ['and', ['he', 'his', 'as', 'as']]
# ['as', ['his', 'and', 'as', 'he']]
# ['as', ['and', 'as', 'he', 'in']]
# ['he', ['as', 'as', 'in', 'in']]
# ['in', ['as', 'he', 'in', 'or']]
# ['in', ['he', 'in', 'or', 'in']]
# ['or', ['in', 'in', 'in', 'his']]
# ['in', ['in', 'or', 'his', 'he']]
# ['his', ['or', 'in', 'he', 'was']]
# ['he', ['in', 'his', 'was', 'by']]
# ['was', ['his', 'he', 'by', 'his']]
# ['by', ['he', 'was', 'his', 'and']]
# ['his', ['was', 'by', 'and', 'two']]
# ['and', ['by', 'his', 'two', 'who']]
# ['two', ['his', 'and', 'who', 'in']]
# ['who', ['and', 'two', 'in', 'the']]
# ['in', ['two', 'who', 'the', 'for']]
# ['the', ['who', 'in', 'for', 'years']]
# ['for', ['in', 'the', 'years', 'at']]
# ['years', ['the', 'for', 'at', 'his']]
# ['at', ['for', 'years', 'his', 'is']]
# ['his', ['years', 'at', 'is', 'a']]
# ['is', ['at', 'his', 'a', 'who']]
# ['a', ['his', 'is', 'who', 'a']]
# ['who', ['is', 'a', 'a', 'for']]
# ['a', ['a', 'who', 'for', 'the']]
# ['for', ['who', 'a', 'the']]
# ['the', ['a', 'for', 'from']]
# ['from', ['the', 'in', 'his']]
# ['in', ['from', 'his', 'life']]
# ['his', ['from', 'in', 'life', 'by']]
# ['life', ['in', 'his', 'by', 'that']]
# ['by', ['his', 'life', 'that', 'he']]
# ['that', ['life', 'by', 'he', 'to']]
# ['he', ['by', 'that', 'to', 'be']]
# ['to', ['that', 'he', 'be', 'a']]
# ['be', ['he', 'to', 'a', 'an']]
# ['a', ['to', 'be', 'an', 'a']]
# ['an', ['be', 'a', 'a', 'a']]
# ['a', ['a', 'an', 'a', 'a']]
# ['a', ['an', 'a', 'a', 'a']]
# ['a', ['a', 'a', 'a', 'and']]
# ['a', ['a', 'a', 'and', 'a']]
# ['and', ['a', 'a', 'a', 'is']]
# ['a', ['a', 'and', 'is', 'an']]
# ['is', ['and', 'a', 'an', 'of']]
# ['an', ['a', 'is', 'of', 'one']]
# ['of', ['is', 'an', 'one', 'of']]
# ['one', ['an', 'of', 'of']]
# ['of', ['of', 'one']]
# ['s', ['works', 'to']]
# ['works', ['s', 'to']]
# ['to', ['s', 'works']]
# ['in', ['the', 'it']]
# ['the', ['in', 'it', 'the']]
# ['it', ['in', 'the', 'the', 'of']]
# ['the', ['the', 'it', 'of', 'a']]
# ['of', ['it', 'the', 'a', 'which']]
# ['a', ['the', 'of', 'which', 'was']]
# ['which', ['of', 'a', 'was', 'to']]
# ['was', ['a', 'which', 'to', 'to']]
# ['to', ['which', 'was', 'to', 'the']]
# ['to', ['was', 'to', 'the', 'works']]
# ['the', ['to', 'to', 'works', 'of']]
# ['works', ['to', 'the', 'of']]
# ['of', ['the', 'works']]
# ['s', ['works', 'on']]
# ['works', ['s', 'on', 'his']]
# ['on', ['s', 'works', 'his', 'of']]
# ['his', ['works', 'on', 'of', 'his']]
# ['of', ['on', 'his', 'his', 'and']]
# ['his', ['his', 'of', 'and', 'his']]
# ['and', ['of', 'his', 'his', 'the']]
# ['his', ['his', 'and', 'the', 'have']]
# ['the', ['and', 'his', 'have']]
# ['have', ['his', 'the']]
# ['the', ['the']]
# ['the', ['the', 'of', 'his']]
# ['of', ['the', 'his']]
# ['his', ['the', 'of', 'are']]
# ['are', ['his', 'on', 'or']]
# ['on', ['are', 'or', 'the']]
# ['or', ['are', 'on', 'the', 'and']]
# ['the', ['on', 'or', 'and', 'of']]
# ['and', ['or', 'the', 'of', 'the']]
# ['of', ['the', 'and', 'the', 'or']]
# ['the', ['and', 'of', 'or', 'the']]
# ['or', ['of', 'the', 'the']]
# ['the', ['the', 'or', 'of']]
# ['of', ['the', 'which', 'he']]
# ['which', ['of', 'he', 'wrote']]
# ['he', ['of', 'which', 'wrote', 'to']]
# ['wrote', ['which', 'he', 'to', 'the']]
# ['to', ['he', 'wrote', 'the', 'he']]
# ['the', ['wrote', 'to', 'he', 'wrote']]
# ['he', ['to', 'the', 'wrote', 'the']]
# ['wrote', ['the', 'he', 'the', 'of']]
# ['the', ['he', 'wrote', 'of', 'the']]
# ['of', ['wrote', 'the', 'the', 'in']]
# ['the', ['the', 'of', 'in', 'which']]
# ['in', ['of', 'the', 'which', 'he']]
# ['which', ['the', 'in', 'he', 'on']]
# ['he', ['in', 'which', 'on', 'and']]
# ['on', ['which', 'he', 'and', 'on']]
# ['and', ['he', 'on', 'on', 'the']]
# ['on', ['on', 'and', 'the', 'of']]
# ['the', ['and', 'on', 'of', 'as']]
# ['of', ['on', 'the', 'as', 'this']]
# ['as', ['the', 'of', 'this', 'is']]
# ['this', ['of', 'as', 'is', 'of']]
# ['is', ['as', 'this', 'of', 'a']]
# ['of', ['this', 'is', 'a', 'in']]
# ['a', ['is', 'of', 'in', 'the']]
# ['in', ['of', 'a', 'the', 'of']]
# ['the', ['a', 'in', 'of', 'the']]
# ['of', ['in', 'the', 'the']]
# ['the', ['the', 'of']]
# ['s', ['are', 'on']]
# ['are', ['s', 'on', 'his']]
# ['on', ['s', 'are', 'his', 'have']]
# ['his', ['are', 'on', 'have', 'been']]
# ['have', ['on', 'his', 'been', 'as']]
# ['been', ['his', 'have', 'as', 'all']]
# ['as', ['have', 'been', 'all', 'be']]
# ['all', ['been', 'as', 'be', 'all']]
# ['be', ['as', 'all', 'all', 'are']]
# ['all', ['all', 'be', 'are', 'to']]
# ['are', ['be', 'all', 'to', 'his']]
# ['to', ['all', 'are', 'his', 'to']]
# ['his', ['are', 'to', 'to', 'with']]
# ['to', ['to', 'his', 'with', 'his']]
# ['with', ['his', 'to', 'his', 'his']]
# ['his', ['to', 'with', 'his', 'as']]
# ['his', ['with', 'his', 'as', 'the']]
# ['as', ['his', 'his', 'the', 'of']]
# ['the', ['his', 'as', 'of']]
# ['of', ['as', 'the', 'a']]
# ['a', ['of', 'of']]
# ['of', ['a', 'is']]
# ['is', ['of', 'that', 'of']]
# ['that', ['is', 'of']]
# ['of', ['is', 'that', 'a']]
# ['a', ['of', 'to', 'the']]
# ['to', ['a', 'the', 'one']]
# ['the', ['a', 'to', 'one', 'of']]
# ['one', ['to', 'the', 'of', 'the']]
# ['of', ['the', 'one', 'the', 'works']]
# ['the', ['one', 'of', 'works', 'the']]
# ['works', ['of', 'the', 'the', 'of']]
# ['the', ['the', 'works', 'of', 'the']]
# ['of', ['works', 'the', 'the', 'from']]
# ['the', ['the', 'of', 'from', 'to']]
# ['from', ['of', 'the', 'to', 'the']]
# ['to', ['the', 'from', 'the', 'of']]
# ['the', ['from', 'to', 'of', 'a']]
# ['of', ['to', 'the', 'a', 'in']]
# ['a', ['the', 'of', 'in', 'the']]
# ['in', ['of', 'a', 'the', 'and']]
# ['the', ['a', 'in', 'and', 'a']]
# ['and', ['in', 'the', 'a', 'of']]
# ['a', ['the', 'and', 'of', 'are']]
# ['of', ['and', 'a', 'are', 'in']]
# ['are', ['a', 'of', 'in']]
# ['in', ['of', 'are', 'on']]
# ['on', ['in', 'the', 'of']]
# ['the', ['on', 'of', 'and']]
# ['of', ['on', 'the', 'and', 'by']]
# ['and', ['the', 'of', 'by']]
# ['by', ['of', 'and']]
# ['his', ['life']]
# ['life', ['his']]
# ['s', ['to', 'his']]
# ['to', ['s', 'his', 'the']]
# ['his', ['s', 'to', 'the', 'of']]
# ['the', ['to', 'his', 'of', 'an']]
# ['of', ['his', 'the', 'an', 'all']]
# ['an', ['the', 'of', 'all', 'that']]
# ['all', ['of', 'an', 'that', 'his']]
# ['that', ['an', 'all', 'his', 'in']]
# ['his', ['all', 'that', 'in', 'and']]
# ['in', ['that', 'his', 'and', 'as']]
# ['and', ['his', 'in', 'as', 'an']]
# ['as', ['in', 'and', 'an', 'he']]
# ['an', ['and', 'as', 'he', 'to']]
# ['he', ['as', 'an', 'to', 'the']]
# ['to', ['an', 'he', 'the', 'by']]
# ['the', ['he', 'to', 'by', 'it']]
# ['by', ['to', 'the', 'it', 'to']]
# ['it', ['the', 'by', 'to', 'his']]
# ['to', ['by', 'it', 'his']]
# ['his', ['it', 'to']]
# ['s', ['for', 'and']]
# ['for', ['s', 'and', 'for']]
# ['and', ['s', 'for', 'for', 'was']]
# ['for', ['for', 'and', 'was', 'of']]
# ['was', ['and', 'for', 'of', 'his']]
# ['of', ['for', 'was', 'his', 'of']]
# ['his', ['was', 'of', 'of', 'the']]
# ['of', ['of', 'his', 'the', 'of']]
# ['the', ['his', 'of', 'of', 'he']]
# ['of', ['of', 'the', 'he', 'works']]
# ['he', ['the', 'of', 'works', 'to']]
# ['works', ['of', 'he', 'to', 'which']]
# ['to', ['he', 'works', 'which', 'had']]
# ['which', ['works', 'to', 'had', 'been']]
# ['had', ['to', 'which', 'been', 'for']]
# ['been', ['which', 'had', 'for', 'wrote']]
# ['for', ['had', 'been', 'wrote', 'that']]
# ['wrote', ['been', 'for', 'that', 'for']]
# ['that', ['for', 'wrote', 'for']]
# ['for', ['wrote', 'that']]
# ['in', ['this', 'is']]
# ['this', ['in', 'is']]
# ['is', ['in', 'this', 'wrote']]
# ['wrote', ['is', 'on', 'as']]
# ['on', ['wrote', 'as', 'life']]
# ['as', ['wrote', 'on', 'life', 'and']]
# ['life', ['on', 'as', 'and']]
# ['and', ['as', 'life']]
# ['s', ['is', 'all']]
# ['is', ['s', 'all', 'for']]
# ['all', ['s', 'is', 'for']]
# ['for', ['is', 'all', 'the']]
# ['the', ['for', 'a', 'to']]
# ['a', ['the', 'to', 'of']]
# ['to', ['the', 'a', 'of', 'was']]
# ['of', ['a', 'to', 'was', 'the']]
# ['was', ['to', 'of', 'the', 'to']]
# ['the', ['of', 'was', 'to', 'the']]
# ['to', ['was', 'the', 'the', 'of']]
# ['the', ['the', 'to', 'of']]
# ['of', ['to', 'the']]
# ['s', ['in', 'that']]
# ['in', ['s', 'that', 'his']]
# ['that', ['s', 'in', 'his', 'in']]
# ['his', ['in', 'that', 'in', 'his']]
# ['in', ['that', 'his', 'his', 'which']]
# ['his', ['his', 'in', 'which', 'had']]
# ['which', ['in', 'his', 'had', 'he']]
# ['had', ['his', 'which', 'he', 'all']]
# ['he', ['which', 'had', 'all', 'the']]
# ['all', ['had', 'he', 'the', 'of']]
# ['the', ['he', 'all', 'of']]
# ['of', ['all', 'the', 'that']]
# ['that', ['of', 'in', 'he']]
# ['in', ['that', 'he', 'or']]
# ['he', ['that', 'in', 'or', 'his']]
# ['or', ['in', 'he', 'his']]
# ['his', ['he', 'or', 'a']]
# ['a', ['his', 'of', 'from']]
# ['of', ['a', 'from', 'the']]
# ['from', ['a', 'of', 'the', 'and']]
# ['the', ['of', 'from', 'and', 'to']]
# ['and', ['from', 'the', 'to', 'the']]
# ['to', ['the', 'and', 'the', 'and']]
# ['the', ['and', 'to', 'and', 'this']]
# ['and', ['to', 'the', 'this', 'is']]
# ['this', ['the', 'and', 'is', 'works']]
# ['is', ['and', 'this', 'works', 'the']]
# ['works', ['this', 'is', 'the', 'and']]
# ['the', ['is', 'works', 'and', 'in']]
# ['and', ['works', 'the', 'in']]
# ['in', ['the', 'and', 'which']]
# ['which', ['in', 'the']]
# ['the', ['which', 'to']]
# ['to', ['the', 'of', 'a']]
# ['of', ['to', 'a', 'the']]
# ['a', ['to', 'of', 'the', 'as']]
# ['the', ['of', 'a', 'as', 'the']]
# ['as', ['a', 'the', 'the', 'in']]
# ['the', ['the', 'as', 'in']]
# ['in', ['as', 'the']]
# ['is', ['for', 'on']]
# ['for', ['is', 'on', 'and']]
# ['on', ['is', 'for', 'and', 'of']]
# ['and', ['for', 'on', 'of', 'his']]
# ['of', ['on', 'and', 'his', 'time']]
# ['his', ['and', 'of', 'time', 'he']]
# ['time', ['of', 'his', 'he', 'wrote']]
# ['he', ['his', 'time', 'wrote']]
# ['wrote', ['time', 'he', 'on']]
# ['on', ['wrote']]
# ['s', ['on', 'the']]
# ['on', ['s', 'the', 'of']]
# ['the', ['s', 'on', 'of', 'a']]
# ['of', ['on', 'the', 'a', 'that']]
# ['a', ['the', 'of', 'that', 'to']]
# ['that', ['of', 'a', 'to', 'the']]
# ['to', ['a', 'that', 'the', 'the']]
# ['the', ['that', 'to', 'the', 'of']]
# ['the', ['to', 'the', 'of', 'his']]
# ['of', ['the', 'the', 'his', 'as']]
# ['his', ['the', 'of', 'as', 'he']]
# ['as', ['of', 'his', 'he', 'his']]
# ['he', ['his', 'as', 'his', 'and']]
# ['his', ['as', 'he', 'and', 'to']]
# ['and', ['he', 'his', 'to', 'his']]
# ['to', ['his', 'and', 'his', 'to']]
# ['his', ['and', 'to', 'to', 'his']]
# ['to', ['to', 'his', 'his', 'works']]
# ['his', ['his', 'to', 'works', 'are']]
# ['works', ['to', 'his', 'are', 'in']]
# ['are', ['his', 'works', 'in', 'a']]
# ['in', ['works', 'are', 'a', 'but']]
# ['a', ['are', 'in', 'but', 'he']]
# ['but', ['in', 'a', 'he', 'his']]
# ['he', ['a', 'but', 'his', 'in']]
# ['his', ['but', 'he', 'in', 'the']]
# ['in', ['he', 'his', 'the', 'years']]
# ['the', ['his', 'in', 'years', 'of']]
# ['years', ['in', 'the', 'of', 'the']]
# ['of', ['the', 'years', 'the', 'on']]
# ['the', ['years', 'of', 'on', 'the']]
# ['on', ['of', 'the', 'the', 'of']]
# ['the', ['the', 'on', 'of', 'the']]
# ['of', ['on', 'the', 'the']]
# ['the', ['the', 'of', 'which']]
# ['which', ['the', 'the', 'the']]
# ['the', ['which', 'the', 'works']]
# ['the', ['which', 'the', 'works', 'from']]
# ['works', ['the', 'the', 'from', 'his']]
# ['from', ['the', 'works', 'his', 'are']]
# ['his', ['works', 'from', 'are', 'the']]
# ['are', ['from', 'his', 'the']]
# ['the', ['his', 'are', 'from']]
# ['from', ['the', 'the', 'have']]
# ['the', ['from', 'have', 'a']]
# ['have', ['from', 'the', 'a', 'and']]
# ['a', ['the', 'have', 'and', 'of']]
# ['and', ['have', 'a', 'of', 'he']]
# ['of', ['a', 'and', 'he', 'wrote']]
# ['he', ['and', 'of', 'wrote', 'in']]
# ['wrote', ['of', 'he', 'in', 'all']]
# ['in', ['he', 'wrote', 'all']]
# ['all', ['wrote', 'in']]
# ['is', ['for', 'his']]
# ['for', ['is', 'his', 'a']]
# ['his', ['is', 'for', 'a', 'of']]
# ['a', ['for', 'his', 'of', 'with']]
# ['of', ['his', 'a', 'with', 'on']]
# ['with', ['a', 'of', 'on', 'and']]
# ['on', ['of', 'with', 'and', 'for']]
# ['and', ['with', 'on', 'for', 'two']]
# ['for', ['on', 'and', 'two', 'of']]
# ['two', ['and', 'for', 'of']]
# ['of', ['for', 'two']]
# ['s', ['works', 'are']]
# ['works', ['s', 'are', 'in']]
# ['are', ['s', 'works', 'in', 'this']]
# ['in', ['works', 'are', 'this', 'and']]
# ['this', ['are', 'in', 'and', 'he']]
# ['and', ['in', 'this', 'he', 'is']]
# ['he', ['this', 'and', 'is', 'to']]
# ['is', ['and', 'he', 'to', 'be']]
# ['to', ['he', 'is', 'be', 'his']]
# ['be', ['is', 'to', 'his', 'the']]
# ['his', ['to', 'be', 'the', 'by']]
# ['the', ['be', 'his', 'by', 'the']]
# ['by', ['his', 'the', 'the', 'to']]
# ['the', ['the', 'by', 'to', 'as']]
# ['to', ['by', 'the', 'as', 'that']]
# ['as', ['the', 'to', 'that', 'it']]
# ['that', ['to', 'as', 'it', 'is']]
# ['it', ['as', 'that', 'is', 'that']]
# ['is', ['that', 'it', 'that']]
# ['that', ['it', 'is', 'is']]
# ['is', ['that', 'to', 'a']]
# ['to', ['is', 'a', 'in']]
# ['a', ['is', 'to', 'in', 'a']]
# ['in', ['to', 'a', 'a', 'to']]
# ['a', ['a', 'in', 'to', 'the']]
# ['to', ['in', 'a', 'the']]
# ['the', ['a', 'to']]
# ['s', ['are', 'by']]
# ['are', ['s', 'by', 'to']]
# ['by', ['s', 'are', 'to', 'be']]
# ['to', ['are', 'by', 'be', 'the']]
# ['be', ['by', 'to', 'the', 'of']]
# ['the', ['to', 'be', 'of', 'all']]
# ['of', ['be', 'the', 'all', 'time']]
# ['all', ['the', 'of', 'time', 'and']]
# ['time', ['of', 'all', 'and', 'it']]
# ['and', ['all', 'time', 'it', 'his']]
# ['it', ['time', 'and', 'his', 'of']]
# ['his', ['and', 'it', 'of', 'all']]
# ['of', ['it', 'his', 'all', 'the']]
# ['all', ['his', 'of', 'the', 'of']]
# ['the', ['of', 'all', 'of', 'a']]
# ['of', ['all', 'the', 'a', 'and']]
# ['a', ['the', 'of', 'and', 'of']]
# ['and', ['of', 'a', 'of', 'all']]
# ['of', ['a', 'and', 'all', 'the']]
# ['all', ['and', 'of', 'the', 'of']]
# ['the', ['of', 'all', 'of', 'the']]
# ['of', ['all', 'the', 'the', 'that']]
# ['the', ['the', 'of', 'that', 'in']]
# ['that', ['of', 'the', 'in', 'his']]
# ['in', ['the', 'that', 'his', 'and']]
# ['his', ['that', 'in', 'and', 'his']]
# ['and', ['in', 'his', 'his']]
# ['his', ['his', 'and']]
# ['was', ['in', 'this']]
# ['in', ['was', 'this', 'be']]
# ['this', ['was', 'in', 'be', 'to']]
# ['be', ['in', 'this', 'to', 'his']]
# ['to', ['this', 'be', 'his', 'and']]
# ['his', ['be', 'to', 'and', 'of']]
# ['and', ['to', 'his', 'of', 'which']]
# ['of', ['his', 'and', 'which', 'are']]
# ['which', ['and', 'of', 'are', 'and']]
# ['are', ['of', 'which', 'and', 'by']]
# ['and', ['which', 'are', 'by']]
# ['by', ['are', 'and', 'are']]
# ['are', ['by', 'to']]
# ['to', ['are', 'from']]
# ['from', ['to', 'and', 'in']]
# ['and', ['from', 'in', 'of']]
# ['in', ['from', 'and', 'of', 'but']]
# ['of', ['and', 'in', 'but', 'as']]
# ['but', ['in', 'of', 'as', 'a']]
# ['as', ['of', 'but', 'a', 'of']]
# ['a', ['but', 'as', 'of', 'or']]
# ['of', ['as', 'a', 'or']]
# ['or', ['a', 'of']]
# ['is', ['in', 'of']]
# ['in', ['is', 'of', 'as']]
# ['of', ['is', 'in', 'as', 'he']]
# ['as', ['in', 'of', 'he', 'is']]
# ['he', ['of', 'as', 'is', 'the']]
# ['is', ['as', 'he', 'the']]
# ['the', ['he', 'is']]
# ['with', ['time', 'and']]
# ['time', ['with', 'and', 'his']]
# ['and', ['with', 'time', 'his', 'works']]
# ['his', ['time', 'and', 'works', 'to']]
# ['works', ['and', 'his', 'to', 'in']]
# ['to', ['his', 'works', 'in', 'in']]
# ['in', ['works', 'to', 'in', 'the']]
# ['in', ['to', 'in', 'the', 'from']]
# ['the', ['in', 'in', 'from', 'who']]
# ['from', ['in', 'the', 'who', 'the']]
# ['who', ['the', 'from', 'the', 'of']]
# ['the', ['from', 'who', 'of', 'of']]
# ['of', ['who', 'the', 'of']]
# ['of', ['the', 'of']]
# ['s', ['works', 'he']]
# ['works', ['s', 'he', 'in']]
# ['he', ['s', 'works', 'in', 'a']]
# ['in', ['works', 'he', 'a', 'of']]
# ['a', ['he', 'in', 'of', 'the']]
# ['of', ['in', 'a', 'the']]
# ['the', ['a', 'of', 'and']]
# ['and', ['the', 'from', 'who']]
# ['from', ['and', 'who', 'wrote']]
# ['who', ['and', 'from', 'wrote', 'a']]
# ['wrote', ['from', 'who', 'a']]
# ['a', ['who', 'wrote']]
# ['and', ['on', 'from']]
# ['on', ['and', 'from', 'the']]
# ['from', ['and', 'on', 'the', 'of']]
# ['the', ['on', 'from', 'of']]
# ['of', ['from', 'the']]
# ['in', ['by', 'the']]
# ['by', ['in', 'the', 'of']]
# ['the', ['in', 'by', 'of', 'the']]
# ['of', ['by', 'the', 'the', 'the']]
# ['the', ['the', 'of', 'the', 'of']]
# ['the', ['of', 'the', 'of', 'his']]
# ['of', ['the', 'the', 'his', 'in']]
# ['his', ['the', 'of', 'in', 'it']]
# ['in', ['of', 'his', 'it', 'was']]
# ['it', ['his', 'in', 'was', 'in']]
# ['was', ['in', 'it', 'in', 'the']]
# ['in', ['it', 'was', 'the', 'the']]
# ['the', ['was', 'in', 'the', 'that']]
# ['the', ['in', 'the', 'that']]
# ['that', ['the', 'the']]
# ['s', ['in', 'this']]
# ['in', ['s', 'this', 'a']]
# ['this', ['s', 'in', 'a', 'of']]
# ['a', ['in', 'this', 'of', 'in']]
# ['of', ['this', 'a', 'in', 'which']]
# ['in', ['a', 'of', 'which', 'and']]
# ['which', ['of', 'in', 'and']]
# ['and', ['in', 'which']]
# ['to', ['be', 'as']]
# ['be', ['to', 'as', 'the']]
# ['as', ['to', 'be', 'the', 'and']]
# ['the', ['be', 'as', 'and', 'of']]
# ['and', ['as', 'the', 'of']]
# ['of', ['the', 'and', 'at']]
# ['at', ['of', 'the', 'time']]
# ['the', ['at', 'time', 'the']]
# ['time', ['at', 'the', 'the', 'of']]
# ['the', ['the', 'time', 'of', 'that']]
# ['of', ['time', 'the', 'that']]
# ['that', ['the', 'of']]
# ['as', ['the', 'this']]
# ['the', ['as', 'this', 'he']]
# ['this', ['as', 'the', 'he', 'wrote']]
# ['he', ['the', 'this', 'wrote', 'that']]
# ['wrote', ['this', 'he', 'that']]
# ['that', ['he', 'wrote']]
# ['was', ['all', 'his']]
# ['all', ['was', 'his', 'he']]
# ['his', ['was', 'all', 'he', 'for']]
# ['he', ['all', 'his', 'for', 'the']]
# ['for', ['his', 'he', 'the', 'of']]
# ['the', ['he', 'for', 'of', 'a']]
# ['of', ['for', 'the', 'a', 'his']]
# ['a', ['the', 'of', 'his', 'his']]
# ['his', ['of', 'a', 'his', 'was']]
# ['his', ['a', 'his', 'was', 'by']]
# ['was', ['his', 'his', 'by', 'his']]
# ['by', ['his', 'was', 'his', 'to']]
# ['his', ['was', 'by', 'to', 'by']]
# ['to', ['by', 'his', 'by', 'his']]
# ['by', ['his', 'to', 'his', 'to']]
# ['his', ['to', 'by', 'to', 'the']]
# ['to', ['by', 'his', 'the', 'his']]
# ['the', ['his', 'to', 'his', 'for']]
# ['his', ['to', 'the', 'for', 'the']]
# ['for', ['the', 'his', 'the', 'to']]
# ['the', ['his', 'for', 'to', 'his']]
# ['to', ['for', 'the', 'his', 'by']]
# ['his', ['the', 'to', 'by', 'his']]
# ['by', ['to', 'his', 'his', 'the']]
# ['his', ['his', 'by', 'the', 'of']]
# ['the', ['by', 'his', 'of', 'the']]
# ['of', ['his', 'the', 'the', 's']]
# ['the', ['the', 'of', 's', 'of']]
# ['s', ['of', 'the', 'of']]
# ['of', ['the', 's']]
# ['s', ['to', 'the']]
# ['to', ['s', 'the', 'and']]
# ['the', ['s', 'to', 'and', 'for']]
# ['and', ['to', 'the', 'for', 'the']]
# ['for', ['the', 'and', 'the', 'have']]
# ['the', ['and', 'for', 'have', 'been']]
# ['have', ['for', 'the', 'been', 'as']]
# ['been', ['the', 'have', 'as', 'and']]
# ['as', ['have', 'been', 'and', 'and']]
# ['and', ['been', 'as', 'and', 'he']]
# ['and', ['as', 'and', 'he', 'been']]
# ['he', ['and', 'and', 'been', 'for']]
# ['been', ['and', 'he', 'for', 'his']]
# ['for', ['he', 'been', 'his', 'of']]
# ['his', ['been', 'for', 'of', 's']]
# Mean Reciprocal Rank for test data: 0.0861
